# %% [markdown]
# Ex 2A

# %%
# !git clone https://github.com/Zainab1317/FASDH25-portfolio2.git
# Out:
# Cloning into 'FASDH25-portfolio2'...
# remote: Enumerating objects: 4427, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 4427 (delta 4), reused 2 (delta 2), pack-reused 4415 (from 3)
# Receiving objects: 100% (4427/4427), 19.37 MiB | 15.22 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
import re #imports regular expression to find text patterns
import os # imports to enable interaction with file system
import pandas as pd #imports to hadle tabular data and export tsv file

def write_tsv(rows, column_list, path): # function writes a list of data rows intotsv file using panadas
    df = pd.DataFrame(rows, columns=column_list) #list of rows is converted into panads DataFrame
    df.to_csv(path, sep="\t", index=False) #DataFrame is written into tsv

#Setup paths
repo_path = "FASDH25-portfolio2" #define path to repository
folder = "FASDH25-portfolio2/articles" #defining folder where articles are present
gazetteer_path = "FASDH25-portfolio2/gazetteers/geonames_gaza_selection.tsv" #define path and load gazetteer from the tsv file having place names and alternate names

#Read Gazetteer File
with open(gazetteer_path, encoding="utf-8") as file:
    data = file.read()

patterns = {} #an empty dictionary is created for each place names and a count for matches
rows = data.split("\n") #split gazetteer data in new lines to get eeach row on file

for row in rows[1:]:  # Skip header because the pattern starts from next row
    columns = row.split("\t") #seprates each column in tsv by tabs
    asciiname = columns[0] #ensures that first column has names for the place
    name_variants = [asciiname] #lists name variants consisting of the standard name
    alternate_names = columns[5].strip() #gets the alternate names from the 6th column which is counted as the 5th column, if present

    if alternate_names:
      alternate_list = alternate_names.split(",") #splits the alternate names with comma and gets list of other names
      for name in alternate_list: #loops through each alternate name in the list
        name_variants.append(name.strip()) #.strip will remove whitespace from alternate names and .append will add alternate names to the list if prenest

# build a regex pattern that will work to find all names and match diffrent varianats of the place names aswell
    regex_pattern = "|".join (re.escape(name) for name in name_variants) #using re.escape to escape any special characters in place names and "|" is used for alternation
    patterns[asciiname] = {"pattern": regex_pattern, "count": 0} #includes all names and their variants with numbers

mentions_per_month = {} #dictionary stores how many times each name was mentioned
war_start_date = "2023-10-07" #set the date to filt

for filename in os.listdir(folder):
    date_str = filename.split("_")[0]
    if date_str < war_start_date:
        continue

    file_path = f"{folder}/{filename}"
    with open(file_path, encoding="utf-8") as file:
        text = file.read()

    for place in patterns:
        pattern = patterns[place]["pattern"]
        matches = re.findall(pattern, text, re.IGNORECASE)
        count = len(matches)
        patterns[place]["count"] += count

        month_str = date_str[:7]

        if place not in mentions_per_month:
            mentions_per_month[place] = {}
        if month_str not in mentions_per_month[place]:
            mentions_per_month[place][month_str] = 0

        mentions_per_month[place][month_str] += count

#Print Output
for place in mentions_per_month:
    print(f'"{place}": {{')
    month_list = list(mentions_per_month[place].keys())
    for month in month_list:
        count = mentions_per_month[place][month]
        if month != month_list[-1]:
            print(f'    "{month}": {count},')
        else:
            print(f'    "{month}": {count}')
    print("},")

#Prepare Rows and Write TSV
output_rows = []
for place in mentions_per_month:
    for month in mentions_per_month[place]:
        count = mentions_per_month[place][month]
        output_rows.append((place, month, count))

write_tsv(output_rows, ["place", "month", "count"], "regex_counts.tsv")
# Out:
# "Jabalya": {
#     "2023-10": 37,
#     "2024-02": 7,
#     "2023-12": 46,
#     "2024-01": 12,
#     "2023-11": 103,
#     "2024-04": 3,
#     "2024-03": 8
# },
# "Bayt Lahya": {
#     "2023-10": 11,
#     "2024-02": 3,
#     "2023-12": 8,
#     "2024-01": 2,
#     "2023-11": 14,
#     "2024-04": 2,
#     "2024-03": 1
# },
# "Jabalia": {
#     "2023-10": 33,
#     "2024-02": 7,
#     "2023-12": 44,
#     "2024-01": 12,
#     "2023-11": 102,
#     "2024-04": 2,
#     "2024-03": 8
# },
# "Bayt Hanun": {
#     "2023-10": 19,
#     "2024-02": 3,
#     "2023-12": 4,
#     "2024-01": 1,
#     "2023-11": 17,
#     "2024-04": 10,
#     "2024-03": 7
# },
# "Khan Younis": {
#     "2023-10": 74,
#     "2024-02": 63,
#     "2023-12": 173,
#     "2024-01": 74,
#     "2023-11": 132,
#     "2024-04": 25,
#     "2024-03": 40
# },
# "An Nusayrat": {
#     "2023-10": 22,
#     "2024-02": 6,
#     "2023-12": 26,
#     "2024-01": 11,
#     "2023-11": 16,
#     "2024-04": 8,
#     "2024-03": 9
# },
# "Al Burayj": {
#     "2023-10": 3,
#     "2024-02": 2,
#     "2023-12": 17,
#     "2024-01": 5,
#     "2023-11": 15,
#     "2024-04": 0,
#     "2024-03": 5
# },
# "Rafah": {
#     "2023-10": 182,
#     "2024-02": 498,
#     "2023-12": 201,
#     "2024-01": 41,
#     "2023-11": 150,
#     "2024-04": 81,
#     "2024-03": 253
# },
# "Bani Suhayla": {
#     "2023-10": 1,
#     "2024-02": 0,
#     "2023-12": 1,
#     "2024-01": 2,
#     "2023-11": 1,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Nuseirat": {
#     "2023-10": 22,
#     "2024-02": 6,
#     "2023-12": 26,
#     "2024-01": 11,
#     "2023-11": 16,
#     "2024-04": 8,
#     "2024-03": 9
# },
# "Bureij": {
#     "2023-10": 3,
#     "2024-02": 2,
#     "2023-12": 17,
#     "2024-01": 5,
#     "2023-11": 15,
#     "2024-04": 0,
#     "2024-03": 5
# },
# "Al Qararah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 1,
#     "2023-11": 1,
#     "2024-04": 0,
#     "2024-03": 1
# },
# "Abasan al Kabirah": {
#     "2023-10": 4,
#     "2024-02": 1,
#     "2023-12": 4,
#     "2024-01": 0,
#     "2023-11": 5,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Az Zuwaydah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Maghazi": {
#     "2023-10": 15,
#     "2024-02": 2,
#     "2023-12": 49,
#     "2024-01": 9,
#     "2023-11": 28,
#     "2024-04": 0,
#     "2024-03": 3
# },
# "Shukat as Sufi": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Khuza'ah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Mughraqah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Deir El-Balah": {
#     "2023-10": 38,
#     "2024-02": 31,
#     "2023-12": 45,
#     "2024-01": 19,
#     "2023-11": 51,
#     "2024-04": 12,
#     "2024-03": 30
# },
# "An Nasr": {
#     "2023-10": 12,
#     "2024-02": 6,
#     "2023-12": 3,
#     "2024-01": 14,
#     "2023-11": 25,
#     "2024-04": 3,
#     "2024-03": 3
# },
# "Abasan al Jadidah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Fukhkhari": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Wadi as Salqa": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Juhr ad Dik": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Umm an Nasr": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Musaddar": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Mawasi": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 1,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 1
# },
# "Al-Shifa Hospital": {
#     "2023-10": 31,
#     "2024-02": 15,
#     "2023-12": 23,
#     "2024-01": 3,
#     "2023-11": 245,
#     "2024-04": 13,
#     "2024-03": 32
# },
# "Umm Jarrah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Musabbih": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Ard Rafah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Qubbah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Junaynah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Ghabah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Filahah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Abu Himar": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Abu 'Awdah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Arab al Qila'i": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Abu Mu'ammar": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Umm al Kilab": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Saknat az Zarqa'": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Rafiah Yam": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Qizan an Najjar": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Qa' al Qurayn": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Nahal Qatif": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Umm Kamil": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "An Nazlah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Mashahirah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Qa' al Kharabah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Daribat ash Shaykh Hammuda": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Izbat Bayt Hanun": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Arab Maslakh Bayt Lahya": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Madinat al 'Awdah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "As Surayij": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Az-Zawayda": {
#     "2023-10": 1,
#     "2024-02": 1,
#     "2023-12": 1,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 1,
#     "2024-03": 0
# },
# "Khuza'a": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "al Fukhari": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Shokat as-Sufi": {
#     "2023-10": 1,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al-Mughraqa": {
#     "2023-10": 1,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 1,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Bani Suhela": {
#     "2023-10": 3,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 5,
#     "2024-04": 0,
#     "2024-03": 2
# },
# "Abasan al-Saghira": {
#     "2023-10": 1,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 2,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al-Zahra'": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 1,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Khirbat al-Adas": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Qaryah as Suwaydiyah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Katibah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Amal": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 1,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 1
# },
# "Atatra": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Remal": {
#     "2023-10": 14,
#     "2024-02": 0,
#     "2023-12": 5,
#     "2024-01": 0,
#     "2023-11": 3,
#     "2024-04": 2,
#     "2024-03": 3
# },
# "At Turkman": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Az Zaytun": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "As Sabra": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Fawayidah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Ash Shaykh 'Ijlin": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Midan Filastin": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Ar Rimal al Janubi": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Ar Rimal ash Shamali": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "An Nasr ash Sharqi": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "An Nasr al Gharbi": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Ash Shaykh Radwan": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Ad Daraj": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "At Tuffah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Jadidah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Maydan ash Shuja'iyah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Madinah al Qadimah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Mu'tarid": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Mintaqah as Sina'iyah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Ar Rasm": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Mattayin": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Harah ash Sharqiyah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Abu Asad": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Abu Sittah": {
#     "2023-10": 1,
#     "2024-02": 0,
#     "2023-12": 4,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 4,
#     "2024-03": 0
# },
# "Hamadah": {
#     "2023-10": 0,
#     "2024-02": 1,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Tunis": {
#     "2023-10": 14,
#     "2024-02": 2,
#     "2023-12": 6,
#     "2024-01": 5,
#     "2023-11": 41,
#     "2024-04": 19,
#     "2024-03": 2
# },
# "Al Masihi": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al 'Amrah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Brawk": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Abu Fayyad": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Umran": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Qata'ah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Hakar": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Hadabah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Farsh": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Umm al 'Azban": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Abu 'Arif": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Bisharah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Qa'ud": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Baldah al Qadimah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Mu'askar": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 1,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Ash Shaykh Nasir": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Markaz al Madinah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 1,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Batn as Samin": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Jurat al Lut": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Ma'n": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Qa' al Qarin": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Manarah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Qizan": {
#     "2023-10": 1,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Abu Rashwan": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Hijazi": {
#     "2023-10": 2,
#     "2024-02": 0,
#     "2023-12": 1,
#     "2024-01": 1,
#     "2023-11": 2,
#     "2024-04": 2,
#     "2024-03": 0
# },
# "Tall az Zu'rub": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Hawd Ji": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Hawd Waw": {
#     "2023-10": 1,
#     "2024-02": 1,
#     "2023-12": 2,
#     "2024-01": 0,
#     "2023-11": 1,
#     "2024-04": 1,
#     "2024-03": 0
# },
# "Yibna": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Qishtah": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al Barazil": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "As Salam": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al-Azhar University": {
#     "2023-10": 2,
#     "2024-02": 0,
#     "2023-12": 2,
#     "2024-01": 1,
#     "2023-11": 1,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Al-Aqsa University": {
#     "2023-10": 1,
#     "2024-02": 2,
#     "2023-12": 0,
#     "2024-01": 2,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Bi'r Zawalan": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Bi'r Abu Thabit": {
#     "2023-10": 0,
#     "2024-02": 0,
#     "2023-12": 0,
#     "2024-01": 0,
#     "2023-11": 0,
#     "2024-04": 0,
#     "2024-03": 0
# },
# "Gaza": {
#     "2023-10": 4208,
#     "2024-02": 1896,
#     "2023-12": 2892,
#     "2024-01": 1966,
#     "2023-11": 4552,
#     "2024-04": 1002,
#     "2024-03": 2206
# },
# "Gaza Strip": {
#     "2023-10": 4208,
#     "2024-02": 1896,
#     "2023-12": 2892,
#     "2024-01": 1966,
#     "2023-11": 4552,
#     "2024-04": 1002,
#     "2024-03": 2206
# },
# "Gaza City": {
#     "2023-10": 4218,
#     "2024-02": 1904,
#     "2023-12": 2915,
#     "2024-01": 1973,
#     "2023-11": 4568,
#     "2024-04": 1005,
#     "2024-03": 2218
# },

# %% [markdown]
# Ex 2B

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.10.1-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (5.29.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.4.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3.0->stanza)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)
# Downloading stanza-1.10.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 50.8 MB/s eta 0:00:00
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 36.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, emoji, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed emoji-2.14.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stanza-1.10.1

# %%
import stanza
# Download the language model:
stanza.download("en")

# Create the NLP pipeline for tokenization,multi-word token expansion and named entity recognition and specifying the language:
nlp = stanza.Pipeline(lang="en", processors='tokenize,mwt,ner')

#import additional necessary libraries
import os
import pandas as pd
import re



#setting path to folder that contains required text articles
folder = "/content/FASDH25-portfolio2/articles"

#empty variable for jan 2024 articles
jan_articles=0
# Dictionary to store place name counts
place_counts = {}
# loop through the entities in the folder:
for filename in os.listdir(folder):
  # loop through files from Jan 2024 make sure that the articles end with .txt
  if "2024-01" in filename:
    jan_articles += 1
    # make path
    path = os.path.join(folder, filename)
    #open and read files
    with open(path, encoding="utf-8") as file:
        text = file.read()
#Using the pipeline for named entities focusing on Geopolitical entities and place based entities
# 1) Chatgpt corrected code, varable consistency
    doc = nlp(text)
    for sentence in doc.sentences:
      for entity in sentence.ents:
        #specifying the type of named entites we want (geographic/place-based entities)
        if entity.type in ["GPE", "LOC"]:
          place = entity.text.strip()
          # Increment the count for each place
          place_counts[place] = place_counts.get(place, 0) + 1

#cleaning the named entities
# 2) Help taken from Chatgpt to fix error
# Dictionary to store cleaned and normalized place names with counts
clean_counts = {}

for place, count in place_counts.items():
    #Removes possessive endings like 's
    place = re.sub(r"['`]s\b", "", place)
    #Removes punctuation from entites
    place = re.sub(r"[^\w\s]", "", place)
    #removes "the" from entities
    place = re.sub(r"^the\s+", "", place, flags=re.IGNORECASE)
    # Combine counts for places with equivalent cleaned names
    clean_counts[place] = clean_counts.get(place, 0) + count

# printing normalized place names with their total counts
print(clean_counts)

filename = "ner_counts.tsv"
# write results to a TSV file with columns "place" and "count"
with open("ner_counts.tsv", mode= "w", encoding= "utf-8") as file:
  # create a header of the tsv files:
  header = "place\tcount\n"
  file.write(header)
  # loop through the places dictionary, creating a row for all items in the dictionary
  for place, count in clean_counts.items():
    row = f"{place}\t{count}\n"
    file.write(row)

#open file and print normalised results
with open("/content/ner_counts.tsv", encoding="utf-8") as file:
  print(file.read())
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: en (English) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.10.0/models/default.zip:   0%|          | …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: en (English):
# =========================================
# | Processor | Package                   |
# -----------------------------------------
# | tokenize  | combined                  |
# | mwt       | combined                  |
# | ner       | ontonotes-ww-multi_charlm |
# =========================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!
# {'Morocco': 13, 'Israel': 1594, 'Gaza': 1605, 'Rabat': 3, 'United States': 160, 'United Arab Emirates': 14, 'UAE': 7, 'Bahrain': 11, 'Sudan': 3, 'US': 717, 'Western Sahara': 4, 'Washington': 60, 'Tel Aviv': 49, 'Algeria': 7, 'Marrakesh': 1, 'Moroccos': 1, 'Maghreb': 1, 'Ukraine': 47, 'Saudi Arabia': 39, 'California': 3, 'West Bank': 160, 'Dena': 1, 'Israels': 31, 'Oakland': 1, 'South Africa': 200, 'Jordan': 42, 'Jerusalem': 26, 'East Jerusalem': 23, 'Egypt': 43, 'Qatar': 64, 'Kuala Lumpur': 4, 'Malaysia': 8, 'Palestine': 124, 'Indonesias': 1, 'Jakarta': 2, 'Johannesburg': 4, 'London': 17, 'Paris': 8, 'Vienna': 1, 'Berlin': 5, 'Amman': 6, 'Washington DC': 7, 'UK': 95, 'Manchester': 1, 'Yemen': 182, 'India': 50, 'Hyderabad': 1, 'Colombos Kollupitiya': 1, 'Namibia': 10, 'Germany': 31, 'Palestinian Territories': 1, 'Sweden': 3, 'Iran': 206, 'Kerman': 6, 'Lebanon': 175, 'Bethlehem': 4, 'Nairoukh': 1, 'China': 28, 'Italy': 10, 'Spain': 7, 'Turkey': 25, 'Shawawra': 1, 'Hague': 39, 'South Africas': 8, 'Gaza Strip': 156, 'Khan Younis': 23, 'Syria': 83, 'Mazzeh': 2, 'Damascus': 17, 'Houthis': 3, 'Red Sea': 250, 'BabelMandeb Strait': 1, 'Gulf of Aden': 27, 'Sanaa': 15, 'United Kingdom': 43, 'Hodeidah': 5, 'Taiz': 2, 'Dhamar': 1, 'alBayda': 1, 'Saada': 3, 'Arabian Sea': 6, 'Bab alMandeb Strait': 9, 'Asia': 18, 'Europe': 30, 'Kuwait': 2, 'Middle East': 102, 'Ankara': 7, 'West': 24, 'Tehran': 25, 'South Carolina': 4, 'New York City': 1, 'Gazas': 19, 'Gaza City': 31, 'Rafah': 40, 'Strip': 15, 'Istanbul': 2, 'Greece': 8, 'Crete': 2, 'Washingtons': 2, 'Iraq': 62, 'Gulf': 10, 'alDabshah': 1, 'Khirbet Selm': 1, 'Bint Jbeil': 1, 'Beirut': 84, 'Ibil El Saqi': 1, 'alTawils': 1, 'alKhader': 1, 'Bekaa Valley': 1, 'Litani River': 1, 'Netherlands': 14, 'Malta': 2, 'Gulf of Oman': 2, 'Davos': 7, 'Switzerland': 9, 'Deir elBalah': 14, 'Maghazi': 5, 'Nuseirat': 11, 'Manchester City': 1, 'Barcelona': 1, 'Bab elMandeb strait': 1, 'Djibouti': 4, 'Southern Red Sea': 1, 'Africas Cape of Good Hope': 1, 'alShifa': 2, 'Gretna': 2, 'Louisiana': 3, 'New Orleans': 5, 'MirandaCleland': 1, 'France': 13, 'majedalansari': 1, 'Kan': 1, 'alMawasi district': 2, 'Mediterranean': 11, 'Africa': 29, 'Jenin': 19, 'Thameen Darby': 1, 'Nakba Layer': 1, 'Russia': 43, 'Canada': 42, 'Mercator': 1, 'Alaska': 1, 'Mexico': 5, 'South America': 2, 'AsiaPacific': 1, 'Golan Heights': 3, 'Crimea': 4, 'South China Sea': 2, 'Philippines': 4, 'Vietnam': 1, 'Pakistan': 24, 'Kashmir': 4, 'New Delhi': 6, 'Islamabad': 3, 'Darbys Nakba': 1, 'State of Israel': 7, 'Hebron': 10, 'Lama Khater': 1, 'Kiryat Arba': 2, 'Bureij': 2, 'alMahatta': 1, 'Belgium': 15, 'alMazraa': 1, 'Mediterranean Sea': 2, 'Ajaq': 1, 'Silwad': 1, 'Cairo': 6, 'Yemens': 6, 'Australia': 12, 'Denmark': 3, 'New Zealand': 2, 'South Korea': 1, 'Norway': 11, 'Hamass': 6, 'Yaroun': 3, 'Lebanons Nabatieh': 1, 'Yiron': 1, 'Avivim': 1, 'Israels Goren': 1, 'Shatila': 3, 'Dahiyeh': 6, 'DC': 14, 'Doha': 19, 'Lisbon': 1, 'Portugal': 3, 'Walla': 2, 'Somalia': 1, 'Yemens Red Sea': 1, 'Yemens coast': 2, 'Lebanons': 3, 'Seychelles': 1, 'Bab alMandeb strait': 3, 'North Africa': 5, 'Marib': 3, 'Gaza strip': 1, 'Gaza Strips': 3, 'Khreiss': 1, 'Northern Gaza': 1, 'Hong Kong': 2, 'State of Palestine': 1, 'Bolivia': 4, 'Bangladesh': 2, 'Comoros': 2, 'Myanmar': 6, 'northGaza': 1, 'Erbil': 13, 'Pakistans Balochistan province': 2, 'Irans SistanBaluchestan province': 2, 'Irans': 3, 'Afghanistan': 7, 'Rask': 1, 'SistanBaluchestan': 1, 'Strait of Hormuz': 3, 'Persian Gulf': 1, 'Balochistan': 1, 'La France': 1, 'WestBank': 2, 'Entebbe': 1, 'Uganda': 11, 'Montreal': 1, 'Milton Ontario': 1, 'Jabalia': 11, 'Ottawa': 3, 'Toronto': 1, 'Calgary': 1, 'New York': 4, 'Belarus': 1, 'Munich': 2, 'Haifa': 8, 'Sidon': 3, 'Salamehs': 1, 'Beiruts': 3, 'Gazas Deir elBalah': 3, 'alMughraqa': 1, 'alMaghazi': 1, 'Maghazi Roads': 1, 'Deir alBalah': 1, 'Islamic Republic': 5, 'Nur Shams': 1, 'Tulkarem': 2, 'Naqoura': 2, 'America': 4, 'Frances': 1, 'El Arish': 3, 'Al Jazeeras': 1, 'al ...
# place	count
# Morocco	13
# Israel	1594
# Gaza	1605
# Rabat	3
# United States	160
# United Arab Emirates	14
# UAE	7
# Bahrain	11
# Sudan	3
# US	717
# Western Sahara	4
# Washington	60
# Tel Aviv	49
# Algeria	7
# Marrakesh	1
# Moroccos	1
# Maghreb	1
# Ukraine	47
# Saudi Arabia	39
# California	3
# West Bank	160
# Dena	1
# Israels	31
# Oakland	1
# South Africa	200
# Jordan	42
# Jerusalem	26
# East Jerusalem	23
# Egypt	43
# Qatar	64
# Kuala Lumpur	4
# Malaysia	8
# Palestine	124
# Indonesias	1
# Jakarta	2
# Johannesburg	4
# London	17
# Paris	8
# Vienna	1
# Berlin	5
# Amman	6
# Washington DC	7
# UK	95
# Manchester	1
# Yemen	182
# India	50
# Hyderabad	1
# Colombos Kollupitiya	1
# Namibia	10
# Germany	31
# Palestinian Territories	1
# Sweden	3
# Iran	206
# Kerman	6
# Lebanon	175
# Bethlehem	4
# Nairoukh	1
# China	28
# Italy	10
# Spain	7
# Turkey	25
# Shawawra	1
# Hague	39
# South Africas	8
# Gaza Strip	156
# Khan Younis	23
# Syria	83
# Mazzeh	2
# Damascus	17
# Houthis	3
# Red Sea	250
# BabelMandeb Strait	1
# Gulf of Aden	27
# Sanaa	15
# United Kingdom	43
# Hodeidah	5
# Taiz	2
# Dhamar	1
# alBayda	1
# Saada	3
# Arabian Sea	6
# Bab alMandeb Strait	9
# Asia	18
# Europe	30
# Kuwait	2
# Middle East	102
# Ankara	7
# West	24
# Tehran	25
# South Carolina	4
# New York City	1
# Gazas	19
# Gaza City	31
# Rafah	40
# Strip	15
# Istanbul	2
# Greece	8
# Crete	2
# Washingtons	2
# Iraq	62
# Gulf	10
# alDabshah	1
# Khirbet Selm	1
# Bint Jbeil	1
# Beirut	84
# Ibil El Saqi	1
# alTawils	1
# alKhader	1
# Bekaa Valley	1
# Litani River	1
# Netherlands	14
# Malta	2
# Gulf of Oman	2
# Davos	7
# Switzerland	9
# Deir elBalah	14
# Maghazi	5
# Nuseirat	11
# Manchester City	1
# Barcelona	1
# Bab elMandeb strait	1
# Djibouti	4
# Southern Red Sea	1
# Africas Cape of Good Hope	1
# alShifa	2
# Gretna	2
# Louisiana	3
# New Orleans	5
# MirandaCleland	1
# France	13
# majedalansari	1
# Kan	1
# alMawasi district	2
# Mediterranean	11
# Africa	29
# Jenin	19
# Thameen Darby	1
# Nakba Layer	1
# Russia	43
# Canada	42
# Mercator	1
# Alaska	1
# Mexico	5
# South America	2
# AsiaPacific	1
# Golan Heights	3
# Crimea	4
# South China Sea	2
# Philippines	4
# Vietnam	1
# Pakistan	24
# Kashmir	4
# New Delhi	6
# Islamabad	3
# Darbys Nakba	1
# State of Israel	7
# Hebron	10
# Lama Khater	1
# Kiryat Arba	2
# Bureij	2
# alMahatta	1
# Belgium	15
# alMazraa	1
# Mediterranean Sea	2
# Ajaq	1
# Silwad	1
# Cairo	6
# Yemens	6
# Australia	12
# Denmark	3
# New Zealand	2
# South Korea	1
# Norway	11
# Hamass	6
# Yaroun	3
# Lebanons Nabatieh	1
# Yiron	1
# Avivim	1
# Israels Goren	1
# Shatila	3
# Dahiyeh	6
# DC	14
# Doha	19
# Lisbon	1
# Portugal	3
# Walla	2
# Somalia	1
# Yemens Red Sea	1
# Yemens coast	2
# Lebanons	3
# Seychelles	1
# Bab alMandeb strait	3
# North Africa	5
# Marib	3
# Gaza strip	1
# Gaza Strips	3
# Khreiss	1
# Northern Gaza	1
# Hong Kong	2
# State of Palestine	1
# Bolivia	4
# Bangladesh	2
# Comoros	2
# Myanmar	6
# northGaza	1
# Erbil	13
# Pakistans Balochistan province	2
# Irans SistanBaluchestan province	2
# Irans	3
# Afghanistan	7
# Rask	1
# SistanBaluchestan	1
# Strait of Hormuz	3
# Persian Gulf	1
# Balochistan	1
# La France	1
# WestBank	2
# Entebbe	1
# Uganda	11
# Montreal	1
# Milton Ontario	1
# Jabalia	11
# Ottawa	3
# Toronto	1
# Calgary	1
# New York	4
# Belarus	1
# Munich	2
# Haifa	8
# Sidon	3
# Salamehs	1
# Beiruts	3
# Gazas Deir elBalah	3
# alMughraqa	1
# alMaghazi	1
# Maghazi Roads	1
# Deir alBalah	1
# Islamic Republic	5
# Nur Shams	1
# Tulkarem	2
# Naqoura	2
# America	4
# Frances	1
# El Arish	3
# Al Jazeeras	1
# alMawasi	3
# Beiruts Shatila	1
# AlFukhari	1
# Zeitoun	4
# alFukhari	2
# Britain	14
# Republic of Yemen	1
# Hajjah	2
# Ramallah	24
# Abwein	1
# Nablus	5
# Qalqilya	2
# Jericho	1
# Ein alHilweh	1
# Basel	3
# Ofer	1
# Jordan Valley	5
# Area C	6
# Kadris	1
# alJiftlik	1
# Farsiya	1
# Makhoul	1
# Tubas	1
# Areas A	1
# Japan	9
# Silicon Valley	3
# Netanyahus	7
# West Jerusalem	1
# Brussels	5
# League of Arab States	1
# West Beirut	9
# Beiruts Hamra	1
# Hamras	1
# Hamra	2
# West Beirutis	1
# Dabbouch	1
# East Beirut	1
# Austria	3
# Finland	3
# Iceland	1
# Romania	4
# Melbourne Australia	1
# Melbourne	5
# Sandridge Beach	1
# ZIM Ganges	5
# Australias	1
# Sydney	1
# Brisbane	1
# Rawaas	1
# Middle East Eye	1
# Near East	3
# Kyiv	5
# Houthi	3
# Aqaba	1
# Marshall Islands	1
# Aden	3
# Sabra	1
# Farhana	1
# Abudaqa	2
# IsraelPalestine	2
# Shujayea	3
# Khan Yunis	1
# Mawasi	1
# Wadi Gaza	3
# Bosnia	3
# Sri Lanka	2
# Republic of South Africa	1
# Columbia	3
# Chile	4
# Chiles	1
# Santiago	1
# Taiz province	1
# AlBayda	1
# Ashdod	2
# Hebrew	1
# X
# Spain	1
# Madrid	1
# Oman	1
# Charleston	1
# Geneva	2
# AlAqsa	1
# Zawayda	1
# Beit Hanoon	1
# Serbia	3
# BosniaHerzegovina	1
# Srebrenica	1
# Bani Suheila	2
# Caesarea	2
# Kefar Sava	1
# Rehovot	1
# Beersheba	1
# Kiryat Shmona	1
# Blue Line	1
# Baghdad	8
# Middle Eastern	3
# Welchs	1
# Global South	2
# NaksBilal	1
# Beit Lahiya	2
# El Amal City Hospital	1
# Iraqs	2
# Maroun El Ras	1
# Rmeish	1
# Miraj	1
# Tal alHawa	1
# zarahsultana	1
# Gisha	1
# Bani Naim	1
# Raanana	1
# Sderot	2
# Nir Am	1
# Mefalsim	1
# Hanita	1
# Mattat	1
# Margaliot	1
# Adamit	1
# Zarit	1
# Malkia	1
# Herzegovina	1
# Montenegro	1
# Yugoslavia	2
# Moscow	4
# Pretoria	8
# Mozambique	1
# Bulgaria	1
# Shadis	1
# Ebel elSaqi	1
# Panjgur	1
# SistanBaluchestan province	1
# Islamic Republic of Iran	1
# Ocean Jazz	1
# Cape of Good Hope	12
# alWalaja	5
# Gilo	1
# Har Gilo	1
# Singapore	2
# Ras Issa	1
# Hodeidah province	1
# Dearborn	12
# Michigan	12
# Mackinac Island	1
# Great Lakes	1
# Lake Michigan	1
# Texas	3
# Beit Nabala	1
# Idlib	3
# Riyadh	5
# Alborz	4
# Southern Africa	2
# Bab alMandeb	2
# Venezuela	1
# Hormuz	1
# Arabian Gulf	1
# Dublin	3
# Al Rayyan	1
# Qatars	1
# Cape Town	2
# South Africansfrom	1
# Africa4Palestine	1
# Western Cape province	1
# Chicago	2
# Cyprus	9
# Akrotiri	12
# Limassol	1
# Pashias	1
# Anadolu	1
# Nevatim	1
# Republic of Cyprus	2
# Dhekelia	1
# USA	2
# alSaftawi	1
# Detroit	1
# Southeast Michigan	1
# Arab America	1
# Jarrah	1
# Wayne County	1
# Minnesota	1
# Scotland	2
# Ireland	3
# October7	2
# Entebbe Uganda	1
# Sierra Leone	1
# DRC	1
# adoniaayebare	1
# Dahiyeb	1
# Aroura	2
# alArouri	2
# Salem	1
# Copenhagen	1
# Tunisia	2
# Syrias Aleppo	1
# Mariupol	1
# Indian Ocean	2
# Kanaker	1
# Sarit	1
# Aleppo	2
# Jordans	1
# alTanf	1
# Hashemite Kingdom of Jordan	1
# Jordan River	1
# Palestine_UN	1
# Indias Basmati	1
# North America	2
# Central Gaza Strip	2
# Earth	1
# alAmal	4
# alNasser	1
# alKatiba	1
# Tel Avivs	2
# Rohtak	6
# Haryana	3
# Uttar Pradesh	1
# Lucknow	1
# UP	1
# Bihar	4
# West Bengal	1
# Benarasiyaa	1
# Haryanas Panipat	1
# Thailand	2
# Haryanas Jind	1
# Al Maniya	1
# Egypts	1
# Bab al	1
# Mandeb Strait	1
# alMazraa Asharqiya	2
# Harvey	1
# Tawfiq	1
# Hamoud	1
# Taalbaya	1
# Rashidiya	1
# Karem Abu Salem	1
# Kerem Shalom	1
# Estonia	1
# Indonesia	2
# Kampala	5
# Ugandas	1
# Peru	1
# Colombia	1
# South Sudan	1
# Swaziland	1
# RedSea	1
# Chinas	2
# Bern	1
# Zurich	1
# Arura	2
# Beruit	1
# Hezbollahs	1
# Deir Qaddis	1
# MoTaz	1
# azaizamotaz9	1
# Israels Haifa	1
# Dubai	1
# Yemens southern coast	1
# Egypts Sinai Peninsula	1
# Philadelphi	1
# Dahiya	1
# Jamaa Islamiya	2
# Cameroon	1
# alAhli	1
# Des Moines	7
# Iowa	12
# Cedar Rapids	5
# Iowa City	5
# South Asia	1
# Florida	1
# New Yorks Ellis Island	1
# Ohio	1
# Czech Republic	1
# Hungary	1
# Slovenia	1
# carogennez	1
# Belgiums	1
# Flanders	1
# Wallonia	1
# Gaza city	1
# West Banks	2
# Supernova	1
# Syrias Damascus	1
# Syrias	1
# Borj el Barajneh	1
# Tel Israels	1
# Libya	3
# Rwanda	1
# East Timor	1
# Kabul	1
# azZahra	1
# Hamad	1
# State of Qatar	1
# QFFD	1
# Aizawl	6
# Manipur	8
# Kangpokpi	1
# Mizoram	7
# Mizorams	1
# Kingdom of Judah	1
# Bnei Menashe	3
# Kolasib	1
# Beit Shemesh	1
# Santa Clara	1
# Moldova	1
# Ansarallah	1
# Mediterraneans	1
# Eurasia	1
# Heliopolis	1
# alFawakhir	1
# Levant	1
# Gaza Citys Zeitoun	1
# Old City of Gaza	1
# Mecca	1
# Gazas Daraj	1
# AlMasjid alOmari alKabir	1
# Byzantium	1
# Via Maris	2
# Anthedon	1
# Balakhiyah	1
# Tida	1
# Tell elAjjul	1
# Calves Hill	1
# Daraj	1
# Ahmadiyyah Zawiya	1
# Eastern Mediterranean	1
# TomWhiteGaza	1
# Netivot	1
# BabelMandeb strait	1
# Eilat	2
# Dead Sea	1
# Eastern Mediterranean region	1
# alKarama	1
# Paltel	1
# Jawwal	1
# Syrias Golan Heights	1
# Kurdistan	1
# Panjgur Pakistans Balochistan province	1
# Bahaa elDin Abu Ras	1
# Dura	2
# Bahaas	1
# Maldives	1
# RepJayapal	1
# RepCori	1
# BasedMikeLee	1
# Republic of Korea	1
# Kosovo	1
# PA	1
# Oslo	2

# %% [markdown]
# Ex 3

# %%
# !pip install stanza
# Out:
# Requirement already satisfied: stanza in /usr/local/lib/python3.11/dist-packages (1.10.1)
# Requirement already satisfied: emoji in /usr/local/lib/python3.11/dist-packages (from stanza) (2.14.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (5.29.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.4.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)

# %%
import requests
import time

geonames_username = "zainab128"

def get_coordinates(place, username=geonames_username, fuzzy=0, timeout=1):

  # wait a short while, so that we don't overload the server:
  time.sleep(timeout)
  # make the API call:
  url = "http://api.geonames.org/searchJSON?"
  params = {"q": place, "username": username, "fuzzy": fuzzy, "maxRows": 1, "isNameRequired": True}
  response = requests.get(url, params=params)
  # convert the response into a dictionary:
  results = response.json()
  print(results)
  # get the first result:
  try:
    result = results["geonames"][0]
    return {"latitude": result["lat"], "longitude": result["lng"]}
  except (IndexError, KeyError):
    print("No results found for your API call", response.request.url)

import csv

filename = "ner_gazetteer.tsv"

with open(filename, mode="w", encoding="utf-8") as file:
  header = "place\tlatitude\tlongitude\n"
  file.write(header)
  with open("ner_counts.tsv", encoding="utf-8") as infile:
    reader = csv.DictReader(infile, delimiter='\t')
    for row in reader:
      place_name = row['place']
      coordinates = get_coordinates(place_name)
      if coordinates:
        latitude = coordinates["latitude"]
        longitude = coordinates["longitude"]
        row_data = f"{place_name}\t{latitude}\t{longitude}\n"
        file.write(row_data)
      else:
           row_data = f"{place_name}\tNA\tNA\n"
           file.write(row_data)
# Out:
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '00', 'lng': '-10', 'geonameId': 2542007, 'toponymName': 'Kingdom of Morocco', 'countryId': '2542007', 'fcl': 'A', 'population': 36029138, 'countryCode': 'MA', 'name': 'Morocco', 'fclName': 'country, state, region,...', 'countryName': 'Morocco', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '28.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 33, 'geonames': [{'adminCode1': '00', 'lng': '34.75', 'geonameId': 294640, 'toponymName': 'State of Israel', 'countryId': '294640', 'fcl': 'A', 'population': 8883800, 'countryCode': 'IL', 'name': 'Israel', 'fclName': 'country, state, region,...', 'countryName': 'Israel', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '31.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 40, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.46672', 'geonameId': 281133, 'toponymName': 'Gaza', 'countryId': '6254930', 'fcl': 'P', 'population': 410000, 'countryCode': 'PS', 'name': 'Gaza', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.50161', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 96, 'geonames': [{'adminCode1': '04', 'lng': '-6.83255', 'geonameId': 2538475, 'toponymName': 'Rabat', 'countryId': '2542007', 'fcl': 'P', 'population': 1655753, 'countryCode': 'MA', 'name': 'Rabat', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '04'}, 'countryName': 'Morocco', 'fcodeName': 'capital of a political entity', 'adminName1': 'Rabat-Salé-Kénitra', 'lat': '34.01325', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 209, 'geonames': [{'adminCode1': '00', 'lng': '-98.5', 'geonameId': 6252001, 'toponymName': 'United States', 'countryId': '6252001', 'fcl': 'A', 'population': 327167434, 'countryCode': 'US', 'name': 'United States', 'fclName': 'country, state, region,...', 'countryName': 'United States', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '39.76', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 531, 'geonames': [{'adminCode1': '00', 'lng': '54.5', 'geonameId': 290557, 'toponymName': 'United Arab Emirates', 'countryId': '290557', 'fcl': 'A', 'population': 9630959, 'countryCode': 'AE', 'name': 'United Arab Emirates', 'fclName': 'country, state, region,...', 'countryName': 'United Arab Emirates', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '23.75', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 4, 'geonames': [{'adminCode1': '00', 'lng': '-14.7', 'geonameId': 2368892, 'toponymName': 'Uaè', 'countryId': '2372248', 'fcl': 'P', 'population': 0, 'countryCode': 'GW', 'name': 'Uaè', 'fclName': 'city, village,...', 'countryName': 'Guinea-Bissau', 'fcodeName': 'populated place', 'adminName1': '', 'lat': '12.26667', 'fcode': 'PPL'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': '00', 'lng': '50.55', 'geonameId': 290291, 'toponymName': 'Kingdom of Bahrain', 'countryId': '290291', 'fcl': 'A', 'population': 1569439, 'countryCode': 'BH', 'name': 'Bahrain', 'fclName': 'country, state, region,...', 'countryName': 'Bahrain', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '26.03333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 36, 'geonames': [{'adminCode1': '00', 'lng': '30', 'geonameId': 366755, 'toponymName': 'Republic of the Sudan', 'countryId': '366755', 'fcl': 'A', 'population': 41801533, 'countryCode': 'SD', 'name': 'Sudan', 'fclName': 'country, state, region,...', 'countryName': 'Sudan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '16', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '11', 'lng': '1.96667', 'geonameId': 2971316, 'toponymName': 'Us', 'countryId': '3017382', 'fcl': 'P', 'population': 1248, 'countryCode': 'FR', 'name': 'Us', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'IDF'}, 'countryName': 'France', 'fcodeName': 'populated place', 'adminName1': 'Île-de-France', 'lat': '49.1', 'fcode': 'PPL'}]}
# {'totalResultsCount': 715, 'geonames': [{'adminCode1': '00', 'lng': '105.83224', 'geonameId': 11497302, 'toponymName': 'Western Region', 'countryId': '1562822', 'fcl': 'L', 'population': 17080000, 'countryCode': 'VN', 'name': 'Western Region', 'fclName': 'parks,area, ...', 'countryName': 'Vietnam', 'fcodeName': 'region', 'adminName1': '', 'lat': '10.01211', 'fcode': 'RGN'}]}
# {'totalResultsCount': 425, 'geonames': [{'adminCode1': 'WA', 'lng': '-120.50147', 'geonameId': 5815135, 'toponymName': 'Washington', 'countryId': '6252001', 'fcl': 'A', 'population': 6271775, 'countryCode': 'US', 'name': 'Washington', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'WA'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Washington', 'lat': '47.50012', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 325, 'geonames': [{'adminCode1': '05', 'lng': '34.78057', 'geonameId': 293397, 'toponymName': 'Tel Aviv', 'countryId': '294640', 'fcl': 'P', 'population': 432892, 'countryCode': 'IL', 'name': 'Tel Aviv', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'TA'}, 'countryName': 'Israel', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Tel Aviv', 'lat': '32.08088', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '3', 'geonameId': 2589581, 'toponymName': "People's Democratic Republic of Algeria", 'countryId': '2589581', 'fcl': 'A', 'population': 42228429, 'countryCode': 'DZ', 'name': 'Algeria', 'fclName': 'country, state, region,...', 'countryName': 'Algeria', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '28', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '07', 'lng': '-7.99994', 'geonameId': 2542997, 'toponymName': 'Marrakesh', 'countryId': '2542007', 'fcl': 'P', 'population': 995871, 'countryCode': 'MA', 'name': 'Marrakesh', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '07'}, 'countryName': 'Morocco', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Marrakesh-Safi', 'lat': '31.63416', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Moroccos&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 4, 'geonames': [{'lng': '5', 'geonameId': 2219875, 'name': 'Arab Maghreb', 'fclName': 'parks,area, ...', 'toponymName': 'Al Maghrib', 'fcodeName': 'region', 'adminName1': '', 'lat': '30', 'fcl': 'L', 'fcode': 'RGN', 'population': 76800000}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '00', 'lng': '32', 'geonameId': 690791, 'toponymName': 'Ukraine', 'countryId': '690791', 'fcl': 'A', 'population': 44622516, 'countryCode': 'UA', 'name': 'Ukraine', 'fclName': 'country, state, region,...', 'countryName': 'Ukraine', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '49', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '00', 'lng': '45', 'geonameId': 102358, 'toponymName': 'Kingdom of Saudi Arabia', 'countryId': '102358', 'fcl': 'A', 'population': 33699947, 'countryCode': 'SA', 'name': 'Saudi Arabia', 'fclName': 'country, state, region,...', 'countryName': 'Saudi Arabia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 338, 'geonames': [{'adminCode1': 'CA', 'lng': '-119.75126', 'geonameId': 5332921, 'toponymName': 'California', 'countryId': '6252001', 'fcl': 'A', 'population': 39512223, 'countryCode': 'US', 'name': 'California', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'CA'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'California', 'lat': '37.25022', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 2604, 'geonames': [{'adminCode1': '10375968', 'lng': '-81.39281', 'geonameId': 3580477, 'toponymName': 'West Bay', 'countryId': '3580718', 'fcl': 'P', 'population': 15335, 'countryCode': 'KY', 'name': 'West Bay', 'fclName': 'city, village,...', 'countryName': 'Cayman Islands', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'West Bay', 'lat': '19.38197', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 19, 'geonames': [{'adminCode1': '14', 'lng': '90.28327', 'geonameId': 10274676, 'toponymName': 'Dena', 'countryId': '1814991', 'fcl': 'L', 'population': 0, 'countryCode': 'CN', 'name': 'Dena', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'XZ'}, 'countryName': 'China', 'fcodeName': 'grazing area', 'adminName1': 'Tibet', 'lat': '28.44289', 'fcode': 'GRAZ'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': 'VA', 'lng': '-78.69724', 'geonameId': 4766212, 'toponymName': 'Israel Gap', 'countryId': '6252001', 'fcl': 'T', 'population': 0, 'countryCode': 'US', 'name': 'Israel Gap', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'VA'}, 'countryName': 'United States', 'fcodeName': 'gap', 'adminName1': 'Virginia', 'lat': '37.97986', 'fcode': 'GAP'}]}
# {'totalResultsCount': 233, 'geonames': [{'adminCode1': 'CA', 'lng': '-122.2708', 'geonameId': 5378538, 'toponymName': 'Oakland', 'countryId': '6252001', 'fcl': 'P', 'population': 419267, 'countryCode': 'US', 'name': 'Oakland', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'CA'}, 'countryName': 'United States', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'California', 'lat': '37.80437', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 2643, 'geonames': [{'adminCode1': 'FL', 'lng': '-81', 'geonameId': 12217087, 'toponymName': 'South Florida', 'countryId': '6252001', 'fcl': 'L', 'population': 8260000, 'countryCode': 'US', 'name': 'South Florida', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'FL'}, 'countryName': 'United States', 'fcodeName': 'economic region', 'adminName1': 'Florida', 'lat': '26.5', 'fcode': 'RGNE'}]}
# {'totalResultsCount': 110, 'geonames': [{'adminCode1': '00', 'lng': '36', 'geonameId': 248816, 'toponymName': 'Hashemite Kingdom of Jordan', 'countryId': '248816', 'fcl': 'A', 'population': 9956011, 'countryCode': 'JO', 'name': 'Jordan', 'fclName': 'country, state, region,...', 'countryName': 'Jordan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '31', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 108, 'geonames': [{'adminCode1': '06', 'lng': '35.21633', 'geonameId': 281184, 'toponymName': 'Jerusalem', 'countryId': '294640', 'fcl': 'P', 'population': 971800, 'countryCode': 'IL', 'name': 'Jerusalem', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'JM'}, 'countryName': 'Israel', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Jerusalem', 'lat': '31.76904', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 1332, 'geonames': [{'adminCode1': 'WE', 'lng': '35.23388', 'geonameId': 7303419, 'toponymName': 'East Jerusalem', 'countryId': '6254930', 'fcl': 'P', 'population': 428304, 'countryCode': 'PS', 'name': 'East Jerusalem', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'section of populated place', 'adminName1': 'West Bank', 'lat': '31.78336', 'fcode': 'PPLX'}]}
# {'totalResultsCount': 57, 'geonames': [{'adminCode1': '00', 'lng': '30', 'geonameId': 357994, 'toponymName': 'Arab Republic of Egypt', 'countryId': '357994', 'fcl': 'A', 'population': 98423595, 'countryCode': 'EG', 'name': 'Egypt', 'fclName': 'country, state, region,...', 'countryName': 'Egypt', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '27', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 22, 'geonames': [{'adminCode1': '00', 'lng': '51.25', 'geonameId': 289688, 'toponymName': 'State of Qatar', 'countryId': '289688', 'fcl': 'A', 'population': 2781677, 'countryCode': 'QA', 'name': 'Qatar', 'fclName': 'country, state, region,...', 'countryName': 'Qatar', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 715, 'geonames': [{'adminCode1': '14', 'lng': '101.68653', 'geonameId': 1735161, 'toponymName': 'Kuala Lumpur', 'countryId': '1733045', 'fcl': 'P', 'population': 1453975, 'countryCode': 'MY', 'name': 'Kuala Lumpur', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '14'}, 'countryName': 'Malaysia', 'fcodeName': 'capital of a political entity', 'adminName1': 'Kuala Lumpur', 'lat': '3.1412', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '00', 'lng': '112.5', 'geonameId': 1733045, 'toponymName': 'Malaysia', 'countryId': '1733045', 'fcl': 'A', 'population': 31528585, 'countryCode': 'MY', 'name': 'Malaysia', 'fclName': 'country, state, region,...', 'countryName': 'Malaysia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '2.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 49, 'geonames': [{'adminCode1': '00', 'lng': '35.20329', 'geonameId': 6254930, 'toponymName': 'Palestine', 'countryId': '6254930', 'fcl': 'A', 'population': 4569087, 'countryCode': 'PS', 'name': 'Palestine', 'fclName': 'country, state, region,...', 'countryName': 'Palestine', 'fcodeName': 'semi-independent political entity', 'adminName1': '', 'lat': '31.92157', 'fcode': 'PCLS'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Indonesias&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 4, 'geonames': [{'adminCode1': '04', 'lng': '106.84513', 'geonameId': 1642911, 'toponymName': 'Jakarta', 'countryId': '1643084', 'fcl': 'P', 'population': 8540121, 'countryCode': 'ID', 'name': 'Jakarta', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'JK'}, 'countryName': 'Indonesia', 'fcodeName': 'capital of a political entity', 'adminName1': 'Jakarta', 'lat': '-6.21462', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 21, 'geonames': [{'adminCode1': '06', 'lng': '28.04363', 'geonameId': 993800, 'toponymName': 'Johannesburg', 'countryId': '953987', 'fcl': 'P', 'population': 9418183, 'countryCode': 'ZA', 'name': 'Johannesburg', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'GP'}, 'countryName': 'South Africa', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gauteng', 'lat': '-26.20227', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 76, 'geonames': [{'adminCode1': 'ENG', 'lng': '-0.12574', 'geonameId': 2643743, 'toponymName': 'London', 'countryId': '2635167', 'fcl': 'P', 'population': 8961989, 'countryCode': 'GB', 'name': 'London', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'ENG'}, 'countryName': 'United Kingdom', 'fcodeName': 'capital of a political entity', 'adminName1': 'England', 'lat': '51.50853', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 109, 'geonames': [{'adminCode1': '11', 'lng': '2.3488', 'geonameId': 2988507, 'toponymName': 'Paris', 'countryId': '3017382', 'fcl': 'P', 'population': 2138551, 'countryCode': 'FR', 'name': 'Paris', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'IDF'}, 'countryName': 'France', 'fcodeName': 'capital of a political entity', 'adminName1': 'Île-de-France', 'lat': '48.85341', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 44, 'geonames': [{'adminCode1': '09', 'lng': '16.37208', 'geonameId': 2761369, 'toponymName': 'Vienna', 'countryId': '2782113', 'fcl': 'P', 'population': 1691468, 'countryCode': 'AT', 'name': 'Vienna', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '9'}, 'countryName': 'Austria', 'fcodeName': 'capital of a political entity', 'adminName1': 'Vienna', 'lat': '48.20849', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 210, 'geonames': [{'adminCode1': '16', 'lng': '13.41053', 'geonameId': 2950159, 'toponymName': 'Berlin', 'countryId': '2921044', 'fcl': 'P', 'population': 3426354, 'countryCode': 'DE', 'name': 'Berlin', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'BE'}, 'countryName': 'Germany', 'fcodeName': 'capital of a political entity', 'adminName1': 'State of Berlin', 'lat': '52.52437', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 13, 'geonames': [{'adminCode1': '16', 'lng': '35.94503', 'geonameId': 250441, 'toponymName': 'Amman', 'countryId': '248816', 'fcl': 'P', 'population': 1275857, 'countryCode': 'JO', 'name': 'Amman', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'AM'}, 'countryName': 'Jordan', 'fcodeName': 'capital of a political entity', 'adminName1': 'Amman', 'lat': '31.95522', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 1582, 'geonames': [{'adminCode1': 'WA', 'lng': '-120.50147', 'geonameId': 5815135, 'toponymName': 'Washington', 'countryId': '6252001', 'fcl': 'A', 'population': 6271775, 'countryCode': 'US', 'name': 'Washington', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'WA'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Washington', 'lat': '47.50012', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 8, 'geonames': [{'adminCode1': '00', 'lng': '-2.69531', 'geonameId': 2635167, 'toponymName': 'United Kingdom of Great Britain and Northern Ireland', 'countryId': '2635167', 'fcl': 'A', 'population': 66488991, 'countryCode': 'GB', 'name': 'United Kingdom', 'fclName': 'country, state, region,...', 'countryName': 'United Kingdom', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '54.75844', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 110, 'geonames': [{'adminCode1': 'NH', 'lng': '-71.45479', 'geonameId': 5089178, 'toponymName': 'Manchester', 'countryId': '6252001', 'fcl': 'P', 'population': 110229, 'countryCode': 'US', 'name': 'Manchester', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'NH'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'New Hampshire', 'lat': '42.99564', 'fcode': 'PPL'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '00', 'lng': '47.5', 'geonameId': 69543, 'toponymName': 'Republic of Yemen', 'countryId': '69543', 'fcl': 'A', 'population': 28498687, 'countryCode': 'YE', 'name': 'Yemen', 'fclName': 'country, state, region,...', 'countryName': 'Yemen', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '15.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 27, 'geonames': [{'adminCode1': '00', 'lng': '79', 'geonameId': 1269750, 'toponymName': 'Republic of India', 'countryId': '1269750', 'fcl': 'A', 'population': 1352617328, 'countryCode': 'IN', 'name': 'India', 'fclName': 'country, state, region,...', 'countryName': 'India', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '22', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 20, 'geonames': [{'adminCode1': '40', 'lng': '78.45636', 'geonameId': 1269843, 'toponymName': 'Hyderābād', 'countryId': '1269750', 'fcl': 'P', 'population': 6809970, 'countryCode': 'IN', 'name': 'Hyderabad', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'TS'}, 'countryName': 'India', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Telangana', 'lat': '17.38405', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Colombos+Kollupitiya&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': '00', 'lng': '17', 'geonameId': 3355338, 'toponymName': 'Republic of Namibia', 'countryId': '3355338', 'fcl': 'A', 'population': 2448255, 'countryCode': 'NA', 'name': 'Namibia', 'fclName': 'country, state, region,...', 'countryName': 'Namibia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '-22', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 19, 'geonames': [{'adminCode1': '00', 'lng': '10.5', 'geonameId': 2921044, 'toponymName': 'Federal Republic of Germany', 'countryId': '2921044', 'fcl': 'A', 'population': 82927922, 'countryCode': 'DE', 'name': 'Germany', 'fclName': 'country, state, region,...', 'countryName': 'Germany', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '51.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 18, 'geonames': [{'adminCode1': '00', 'lng': '35.20329', 'geonameId': 6254930, 'toponymName': 'Palestine', 'countryId': '6254930', 'fcl': 'A', 'population': 4569087, 'countryCode': 'PS', 'name': 'Palestine', 'fclName': 'country, state, region,...', 'countryName': 'Palestine', 'fcodeName': 'semi-independent political entity', 'adminName1': '', 'lat': '31.92157', 'fcode': 'PCLS'}]}
# {'totalResultsCount': 18, 'geonames': [{'adminCode1': '00', 'lng': '15', 'geonameId': 2661886, 'toponymName': 'Kingdom of Sweden', 'countryId': '2661886', 'fcl': 'A', 'population': 10183175, 'countryCode': 'SE', 'name': 'Sweden', 'fclName': 'country, state, region,...', 'countryName': 'Sweden', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '62', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '00', 'lng': '53', 'geonameId': 130758, 'toponymName': 'Islamic Republic of Iran', 'countryId': '130758', 'fcl': 'A', 'population': 81800269, 'countryCode': 'IR', 'name': 'Iran', 'fclName': 'country, state, region,...', 'countryName': 'Iran', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '32', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 16, 'geonames': [{'adminCode1': '29', 'lng': '57.07879', 'geonameId': 128234, 'toponymName': 'Kerman', 'countryId': '130758', 'fcl': 'P', 'population': 577514, 'countryCode': 'IR', 'name': 'Kerman', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '08'}, 'countryName': 'Iran', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Kerman', 'lat': '30.28321', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 76, 'geonames': [{'adminCode1': '00', 'lng': '35.83333', 'geonameId': 272103, 'toponymName': 'Lebanon', 'countryId': '272103', 'fcl': 'A', 'population': 6848925, 'countryCode': 'LB', 'name': 'Lebanon', 'fclName': 'country, state, region,...', 'countryName': 'Lebanon', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '33.83333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 80, 'geonames': [{'adminCode1': 'PA', 'lng': '-75.37046', 'geonameId': 5180225, 'toponymName': 'Bethlehem', 'countryId': '6252001', 'fcl': 'P', 'population': 74892, 'countryCode': 'US', 'name': 'Bethlehem', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'PA'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'Pennsylvania', 'lat': '40.62593', 'fcode': 'PPL'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Nairoukh&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 123, 'geonames': [{'adminCode1': '00', 'lng': '105', 'geonameId': 1814991, 'toponymName': 'People’s Republic of China', 'countryId': '1814991', 'fcl': 'A', 'population': 1411778724, 'countryCode': 'CN', 'name': 'China', 'fclName': 'country, state, region,...', 'countryName': 'China', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '35', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '00', 'lng': '12.83333', 'geonameId': 3175395, 'toponymName': 'Italian Republic', 'countryId': '3175395', 'fcl': 'A', 'population': 60431283, 'countryCode': 'IT', 'name': 'Italy', 'fclName': 'country, state, region,...', 'countryName': 'Italy', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '42.83333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '-4', 'geonameId': 2510769, 'toponymName': 'Kingdom of Spain', 'countryId': '2510769', 'fcl': 'A', 'population': 46723749, 'countryCode': 'ES', 'name': 'Spain', 'fclName': 'country, state, region,...', 'countryName': 'Spain', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '40', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 23, 'geonames': [{'adminCode1': '00', 'lng': '35', 'geonameId': 298795, 'toponymName': 'Republic of Turkey', 'countryId': '298795', 'fcl': 'A', 'population': 82319724, 'countryCode': 'TR', 'name': 'Türkiye', 'fclName': 'country, state, region,...', 'countryName': 'Türkiye', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '39', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Shawawra&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '11', 'lng': '-106.41859', 'geonameId': 12822709, 'toponymName': 'Hague', 'countryId': '6251999', 'fcl': 'A', 'population': 0, 'countryCode': 'CA', 'name': 'Hague', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'SK'}, 'countryName': 'Canada', 'fcodeName': 'second-order administrative division', 'adminName1': 'Saskatchewan', 'lat': '52.51118', 'fcode': 'ADM2'}]}
# {'totalResultsCount': 1666, 'geonames': [{'adminCode1': 'FL', 'lng': '-81', 'geonameId': 12217087, 'toponymName': 'South Florida', 'countryId': '6252001', 'fcl': 'L', 'population': 8260000, 'countryCode': 'US', 'name': 'South Florida', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'FL'}, 'countryName': 'United States', 'fcodeName': 'economic region', 'adminName1': 'Florida', 'lat': '26.5', 'fcode': 'RGNE'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.46672', 'geonameId': 281133, 'toponymName': 'Gaza', 'countryId': '6254930', 'fcl': 'P', 'population': 410000, 'countryCode': 'PS', 'name': 'Gaza', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.50161', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 287, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.30627', 'geonameId': 281124, 'toponymName': 'Khān Yūnis', 'countryId': '6254930', 'fcl': 'P', 'population': 173183, 'countryCode': 'PS', 'name': 'Khan Yunis', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.34018', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '00', 'lng': '38', 'geonameId': 163843, 'toponymName': 'Syrian Arab Republic', 'countryId': '163843', 'fcl': 'A', 'population': 16906283, 'countryCode': 'SY', 'name': 'Syria', 'fclName': 'country, state, region,...', 'countryName': 'Syria', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '35', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Mazzeh&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 43, 'geonames': [{'adminCode1': '13', 'lng': '36.29128', 'geonameId': 170654, 'toponymName': 'Damascus', 'countryId': '163843', 'fcl': 'P', 'population': 1569394, 'countryCode': 'SY', 'name': 'Damascus', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'DI'}, 'countryName': 'Syria', 'fcodeName': 'capital of a political entity', 'adminName1': 'Dimashq', 'lat': '33.5102', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Houthis&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 1970, 'geonames': [{'adminCode1': '01', 'lng': '-113.802', 'geonameId': 6118158, 'toponymName': 'Red Deer', 'countryId': '6251999', 'fcl': 'P', 'population': 73593, 'countryCode': 'CA', 'name': 'Red Deer', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'AB'}, 'countryName': 'Canada', 'fcodeName': 'populated place', 'adminName1': 'Alberta', 'lat': '52.26682', 'fcode': 'PPL'}]}
# {'totalResultsCount': 12, 'geonames': [{'adminCode1': '09', 'lng': '122.0236', 'geonameId': 1726399, 'toponymName': 'Basilan Strait', 'countryId': '1694008', 'fcl': 'H', 'population': 0, 'countryCode': 'PH', 'name': 'Basilan Strait', 'fclName': 'stream, lake, ...', 'adminCodes1': {'ISO3166_2': '09'}, 'countryName': 'Philippines', 'fcodeName': 'strait', 'adminName1': 'Zamboanga Peninsula', 'lat': '6.8127', 'fcode': 'STRT'}]}
# {'totalResultsCount': 234, 'geonames': [{'lng': '48', 'geonameId': 80303, 'name': 'Gulf of Aden', 'fclName': 'stream, lake, ...', 'toponymName': 'Gulf of Aden', 'fcodeName': 'gulf', 'adminName1': '', 'lat': '12', 'fcl': 'H', 'fcode': 'GULF', 'population': 0}]}
# {'totalResultsCount': 5, 'geonames': [{'adminCode1': '26', 'lng': '44.20667', 'geonameId': 71137, 'toponymName': 'Sanaa', 'countryId': '69543', 'fcl': 'P', 'population': 1937451, 'countryCode': 'YE', 'name': 'Sanaa', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'SA'}, 'countryName': 'Yemen', 'fcodeName': 'capital of a political entity', 'adminName1': 'Amanat Alasimah', 'lat': '15.35472', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 181, 'geonames': [{'adminCode1': '00', 'lng': '-2.69531', 'geonameId': 2635167, 'toponymName': 'United Kingdom of Great Britain and Northern Ireland', 'countryId': '2635167', 'fcl': 'A', 'population': 66488991, 'countryCode': 'GB', 'name': 'United Kingdom', 'fclName': 'country, state, region,...', 'countryName': 'United Kingdom', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '54.75844', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '08', 'lng': '42.95452', 'geonameId': 79415, 'toponymName': 'Al Ḩudaydah', 'countryId': '69543', 'fcl': 'P', 'population': 617871, 'countryCode': 'YE', 'name': 'Al Hudaydah', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'HU'}, 'countryName': 'Yemen', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Al Hudaydah', 'lat': '14.79781', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 4, 'geonames': [{'adminCode1': '25', 'lng': '44.02091', 'geonameId': 70225, 'toponymName': 'Taiz', 'countryId': '69543', 'fcl': 'P', 'population': 615222, 'countryCode': 'YE', 'name': 'Taiz', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'TA'}, 'countryName': 'Yemen', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Ta‘izz', 'lat': '13.57952', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '11', 'lng': '44.40514', 'geonameId': 76184, 'toponymName': 'Dhamār', 'countryId': '69543', 'fcl': 'P', 'population': 160114, 'countryCode': 'YE', 'name': 'Dhamār', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'DH'}, 'countryName': 'Yemen', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Dhamār', 'lat': '14.54274', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '11', 'lng': '42.07078', 'geonameId': 12546159, 'toponymName': 'Al Bayḑā’', 'countryId': '102358', 'fcl': 'P', 'population': 0, 'countryCode': 'SA', 'name': 'Al Bayḑā’', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '14'}, 'countryName': 'Saudi Arabia', 'fcodeName': 'populated place', 'adminName1': "'Asir Region", 'lat': '18.86139', 'fcode': 'PPL'}]}
# {'totalResultsCount': 20, 'geonames': [{'adminCode1': '15', 'lng': '43.76393', 'geonameId': 71334, 'toponymName': "Sa'dah", 'countryId': '69543', 'fcl': 'P', 'population': 51870, 'countryCode': 'YE', 'name': "Sa'dah", 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'SD'}, 'countryName': 'Yemen', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Şa‘dah', 'lat': '16.94021', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 24, 'geonames': [{'adminCode1': '00', 'lng': '45', 'geonameId': 102358, 'toponymName': 'Kingdom of Saudi Arabia', 'countryId': '102358', 'fcl': 'A', 'population': 33699947, 'countryCode': 'SA', 'name': 'Saudi Arabia', 'fclName': 'country, state, region,...', 'countryName': 'Saudi Arabia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 30, 'geonames': [{'adminCode1': '29', 'lng': '56.7175', 'geonameId': 403378, 'toponymName': 'Bab Tangal-e Pā’īn', 'countryId': '130758', 'fcl': 'P', 'population': 0, 'countryCode': 'IR', 'name': 'Bab Tangal-e Pā’īn', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '08'}, 'countryName': 'Iran', 'fcodeName': 'populated place', 'adminName1': 'Kerman', 'lat': '30.73222', 'fcode': 'PPL'}]}
# {'totalResultsCount': 44, 'geonames': [{'lng': '89.29688', 'geonameId': 6255147, 'name': 'Asia', 'fclName': 'parks,area, ...', 'toponymName': 'Asia', 'fcodeName': 'continent', 'adminName1': '', 'lat': '29.84064', 'fcl': 'L', 'fcode': 'CONT', 'population': 3812366000}]}
# {'totalResultsCount': 14, 'geonames': [{'lng': '9.14062', 'geonameId': 6255148, 'name': 'Europe', 'fclName': 'parks,area, ...', 'toponymName': 'Europe', 'fcodeName': 'continent', 'adminName1': '', 'lat': '48.69096', 'fcl': 'L', 'fcode': 'CONT', 'population': 741000000}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': '00', 'lng': '47.75', 'geonameId': 285570, 'toponymName': 'State of Kuwait', 'countryId': '285570', 'fcl': 'A', 'population': 4137309, 'countryCode': 'KW', 'name': 'Kuwait', 'fclName': 'country, state, region,...', 'countryName': 'Kuwait', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '29.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 2622, 'geonames': [{'lng': '35.85869', 'geonameId': 6269133, 'name': 'Middle East', 'fclName': 'parks,area, ...', 'toponymName': 'Middle East', 'fcodeName': 'region', 'adminName1': '', 'lat': '33.13906', 'fcl': 'L', 'fcode': 'RGN', 'population': 371400000}]}
# {'totalResultsCount': 29, 'geonames': [{'adminCode1': '68', 'lng': '32.85427', 'geonameId': 323786, 'toponymName': 'Ankara', 'countryId': '298795', 'fcl': 'P', 'population': 3517182, 'countryCode': 'TR', 'name': 'Ankara', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '06'}, 'countryName': 'Türkiye', 'fcodeName': 'capital of a political entity', 'adminName1': 'Ankara', 'lat': '39.91987', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 54, 'geonames': [{'lng': '-116.9579', 'geonameId': 11887751, 'toponymName': 'West', 'countryId': '6252001', 'fcl': 'L', 'population': 77000000, 'countryCode': 'US', 'name': 'West', 'fclName': 'parks,area, ...', 'countryName': 'United States', 'fcodeName': 'region', 'adminName1': '', 'lat': '42.77268', 'fcode': 'RGN'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '26', 'lng': '51.42151', 'geonameId': 112931, 'toponymName': 'Tehran', 'countryId': '130758', 'fcl': 'P', 'population': 7153309, 'countryCode': 'IR', 'name': 'Tehran', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '23'}, 'countryName': 'Iran', 'fcodeName': 'capital of a political entity', 'adminName1': 'Tehran', 'lat': '35.69439', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 1751, 'geonames': [{'adminCode1': 'SC', 'lng': '-81.00009', 'geonameId': 4597040, 'toponymName': 'South Carolina', 'countryId': '6252001', 'fcl': 'A', 'population': 4229842, 'countryCode': 'US', 'name': 'South Carolina', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'SC'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'South Carolina', 'lat': '34.00043', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 2440, 'geonames': [{'adminCode1': 'NY', 'lng': '-74.00597', 'geonameId': 5128581, 'toponymName': 'New York City', 'countryId': '6252001', 'fcl': 'P', 'population': 8804190, 'countryCode': 'US', 'name': 'New York', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'NY'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'New York', 'lat': '40.71427', 'fcode': 'PPL'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '02', 'lng': '33', 'geonameId': 1046058, 'toponymName': 'Gaza Province', 'countryId': '1036973', 'fcl': 'A', 'population': 1422460, 'countryCode': 'MZ', 'name': 'Gaza Province', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'G'}, 'countryName': 'Mozambique', 'fcodeName': 'first-order administrative division', 'adminName1': 'Gaza Province', 'lat': '-23.5', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 78, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.46672', 'geonameId': 281133, 'toponymName': 'Gaza', 'countryId': '6254930', 'fcl': 'P', 'population': 410000, 'countryCode': 'PS', 'name': 'Gaza', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.50161', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.24357', 'geonameId': 281102, 'toponymName': 'Rafaḩ', 'countryId': '6254930', 'fcl': 'P', 'population': 126305, 'countryCode': 'PS', 'name': 'Rafah', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.29722', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': '03', 'lng': '27.05', 'geonameId': 951808, 'toponymName': 'Strip', 'countryId': '953987', 'fcl': 'S', 'population': 0, 'countryCode': 'ZA', 'name': 'Strip', 'fclName': 'spot, building, farm', 'adminCodes1': {'ISO3166_2': 'FS'}, 'countryName': 'South Africa', 'fcodeName': 'farm', 'adminName1': 'Free State', 'lat': '-27.51667', 'fcode': 'FRM'}]}
# {'totalResultsCount': 5, 'geonames': [{'adminCode1': '34', 'lng': '28.94966', 'geonameId': 745044, 'toponymName': 'Istanbul', 'countryId': '298795', 'fcl': 'P', 'population': 14804116, 'countryCode': 'TR', 'name': 'Istanbul', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '34'}, 'countryName': 'Türkiye', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Istanbul', 'lat': '41.01384', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 5, 'geonames': [{'adminCode1': '00', 'lng': '22', 'geonameId': 390903, 'toponymName': 'Hellenic Republic', 'countryId': '390903', 'fcl': 'A', 'population': 10727668, 'countryCode': 'GR', 'name': 'Greece', 'fclName': 'country, state, region,...', 'countryName': 'Greece', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '39', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 16, 'geonames': [{'adminCode1': 'ESYE43', 'lng': '24.89502', 'geonameId': 6697802, 'toponymName': 'Crete', 'countryId': '390903', 'fcl': 'A', 'population': 617360, 'countryCode': 'GR', 'name': 'Crete', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'M'}, 'countryName': 'Greece', 'fcodeName': 'first-order administrative division', 'adminName1': 'Crete', 'lat': '35.15585', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': 'CA', 'lng': '-123.79979', 'geonameId': 5573385, 'toponymName': 'Washington Flat', 'countryId': '6252001', 'fcl': 'T', 'population': 0, 'countryCode': 'US', 'name': 'Washington Flat', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'CA'}, 'countryName': 'United States', 'fcodeName': 'plain(s)', 'adminName1': 'California', 'lat': '41.88734', 'fcode': 'PLN'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': '00', 'lng': '44', 'geonameId': 99237, 'toponymName': 'Republic of Iraq', 'countryId': '99237', 'fcl': 'A', 'population': 38433600, 'countryCode': 'IQ', 'name': 'Iraq', 'fclName': 'country, state, region,...', 'countryName': 'Iraq', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '33', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '02', 'lng': '145.08545', 'geonameId': 2096633, 'toponymName': 'Gulf Province', 'countryId': '2088628', 'fcl': 'A', 'population': 158197, 'countryCode': 'PG', 'name': 'Gulf Province', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'GPK'}, 'countryName': 'Papua New Guinea', 'fcodeName': 'first-order administrative division', 'adminName1': 'Gulf Province', 'lat': '-7.7246', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=alDabshah&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 54, 'geonames': [{'adminCode1': '07', 'lng': '35.42407', 'geonameId': 272376, 'toponymName': 'Khirbet Selm', 'countryId': '272103', 'fcl': 'P', 'population': 0, 'countryCode': 'LB', 'name': 'Khirbet Selm', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'NA'}, 'countryName': 'Lebanon', 'fcodeName': 'populated place', 'adminName1': 'Nabatîyé', 'lat': '33.22931', 'fcode': 'PPL'}]}
# {'totalResultsCount': 16, 'geonames': [{'adminCode1': '07', 'lng': '35.43333', 'geonameId': 276592, 'toponymName': 'Bent Jbaïl', 'countryId': '272103', 'fcl': 'P', 'population': 0, 'countryCode': 'LB', 'name': 'Bint Jbeil', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'NA'}, 'countryName': 'Lebanon', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'Nabatîyé', 'lat': '33.11944', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '04', 'lng': '35.50157', 'geonameId': 276781, 'toponymName': 'Beirut', 'countryId': '272103', 'fcl': 'P', 'population': 1916100, 'countryCode': 'LB', 'name': 'Beirut', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'BA'}, 'countryName': 'Lebanon', 'fcodeName': 'capital of a political entity', 'adminName1': 'Beyrouth', 'lat': '33.89332', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 15, 'geonames': [{'adminCode1': '07', 'lng': '35.62639', 'geonameId': 273745, 'toponymName': 'Ebel es Saqi', 'countryId': '272103', 'fcl': 'P', 'population': 0, 'countryCode': 'LB', 'name': 'Ebel es Saqi', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'NA'}, 'countryName': 'Lebanon', 'fcodeName': 'populated place', 'adminName1': 'Nabatîyé', 'lat': '33.35667', 'fcode': 'PPL'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=alTawils&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=alKhader&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 138, 'geonames': [{'adminCode1': '08', 'lng': '36', 'geonameId': 280281, 'toponymName': 'Bekaa Valley', 'countryId': '272103', 'fcl': 'T', 'population': 0, 'countryCode': 'LB', 'name': 'Bekaa Valley', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'BI'}, 'countryName': 'Lebanon', 'fcodeName': 'valley', 'adminName1': 'Béqaa', 'lat': '33.83333', 'fcode': 'VAL'}]}
# {'totalResultsCount': 647, 'geonames': [{'adminCode1': '00', 'lng': '-54.1', 'geonameId': 3383695, 'toponymName': 'Litani Rivier', 'countryId': '3382998', 'fcl': 'H', 'population': 0, 'countryCode': 'SR', 'name': 'Litani Rivier', 'fclName': 'stream, lake, ...', 'countryName': 'Suriname', 'fcodeName': 'stream', 'adminName1': '', 'lat': '3.3', 'fcode': 'STM'}]}
# {'totalResultsCount': 8, 'geonames': [{'adminCode1': '00', 'lng': '5.75', 'geonameId': 2750405, 'toponymName': 'Kingdom of the Netherlands', 'countryId': '2750405', 'fcl': 'A', 'population': 17231017, 'countryCode': 'NL', 'name': 'The Netherlands', 'fclName': 'country, state, region,...', 'countryName': 'The Netherlands', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '52.25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 82, 'geonames': [{'adminCode1': '00', 'lng': '14.43333', 'geonameId': 2562770, 'toponymName': 'Republic of Malta', 'countryId': '2562770', 'fcl': 'A', 'population': 483530, 'countryCode': 'MT', 'name': 'Malta', 'fclName': 'country, state, region,...', 'countryName': 'Malta', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '35.91667', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 217, 'geonames': [{'lng': '79', 'geonameId': 1281787, 'name': 'Gulf of Mannar', 'fclName': 'stream, lake, ...', 'toponymName': 'Gulf of Mannar', 'fcodeName': 'gulf', 'adminName1': '', 'lat': '8.5', 'fcl': 'H', 'fcode': 'GULF', 'population': 0}]}
# {'totalResultsCount': 4, 'geonames': [{'adminCode1': 'GR', 'lng': '9.83723', 'geonameId': 2661039, 'toponymName': 'Davos', 'countryId': '2658434', 'fcl': 'P', 'population': 10898, 'countryCode': 'CH', 'name': 'Davos', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'GR'}, 'countryName': 'Switzerland', 'fcodeName': 'populated place', 'adminName1': 'Grisons', 'lat': '46.80429', 'fcode': 'PPL'}]}
# {'totalResultsCount': 15, 'geonames': [{'adminCode1': '00', 'lng': '8.01427', 'geonameId': 2658434, 'toponymName': 'Switzerland', 'countryId': '2658434', 'fcl': 'A', 'population': 8516543, 'countryCode': 'CH', 'name': 'Switzerland', 'fclName': 'country, state, region,...', 'countryName': 'Switzerland', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '47.00016', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 235, 'geonames': [{'adminCode1': '07', 'lng': '40.14084', 'geonameId': 170794, 'toponymName': 'Deir ez-Zor', 'countryId': '163843', 'fcl': 'P', 'population': 271800, 'countryCode': 'SY', 'name': 'Dayr az Zawr', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'DY'}, 'countryName': 'Syria', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Deir ez-Zor', 'lat': '35.33588', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.38501', 'geonameId': 281086, 'toponymName': 'Maghazi', 'countryId': '6254930', 'fcl': 'S', 'population': 15836, 'countryCode': 'PS', 'name': 'Maghazi', 'fclName': 'spot, building, farm', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'refugee camp', 'adminName1': 'Gaza Strip', 'lat': '31.42234', 'fcode': 'CMPRF'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.3925', 'geonameId': 281109, 'toponymName': 'An Nuşayrāt', 'countryId': '6254930', 'fcl': 'P', 'population': 36123, 'countryCode': 'PS', 'name': 'An Nuşayrāt', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'Gaza Strip', 'lat': '31.44861', 'fcode': 'PPL'}]}
# {'totalResultsCount': 304, 'geonames': [{'adminCode1': 'NH', 'lng': '-71.45479', 'geonameId': 5089178, 'toponymName': 'Manchester', 'countryId': '6252001', 'fcl': 'P', 'population': 110229, 'countryCode': 'US', 'name': 'Manchester', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'NH'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'New Hampshire', 'lat': '42.99564', 'fcode': 'PPL'}]}
# {'totalResultsCount': 57, 'geonames': [{'adminCode1': '56', 'lng': '2.15899', 'geonameId': 3128760, 'toponymName': 'Barcelona', 'countryId': '2510769', 'fcl': 'P', 'population': 1620343, 'countryCode': 'ES', 'name': 'Barcelona', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'CT'}, 'countryName': 'Spain', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Catalonia', 'lat': '41.38879', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 42, 'geonames': [{'adminCode1': '04', 'lng': '43.33557', 'geonameId': 54365, 'toponymName': 'Bab el Mandeb', 'countryId': '223816', 'fcl': 'H', 'population': 0, 'countryCode': 'DJ', 'name': 'Bab-el-Mandeb', 'fclName': 'stream, lake, ...', 'adminCodes1': {'ISO3166_2': 'OB'}, 'countryName': 'Djibouti', 'fcodeName': 'strait', 'adminName1': 'Obock', 'lat': '12.60416', 'fcode': 'STRT'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '00', 'lng': '42.5', 'geonameId': 223816, 'toponymName': 'Republic of Djibouti', 'countryId': '223816', 'fcl': 'A', 'population': 958920, 'countryCode': 'DJ', 'name': 'Djibouti', 'fclName': 'country, state, region,...', 'countryName': 'Djibouti', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '11.83333', 'fcode': 'PCLI'}]}
# ...
# {'totalResultsCount': 13653, 'geonames': [{'adminCode1': '16', 'lng': '-79.96472', 'geonameId': 3537906, 'toponymName': 'Santa Clara', 'countryId': '3562981', 'fcl': 'P', 'population': 250512, 'countryCode': 'CU', 'name': 'Santa Clara', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '05'}, 'countryName': 'Cuba', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Villa Clara Province', 'lat': '22.40694', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '00', 'lng': '28.58333', 'geonameId': 617790, 'toponymName': 'Republic of Moldova', 'countryId': '617790', 'fcl': 'A', 'population': 3545883, 'countryCode': 'MD', 'name': 'Moldova', 'fclName': 'country, state, region,...', 'countryName': 'Moldova', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '47.25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Ansarallah&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Mediterraneans&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 1, 'geonames': [{'lng': '80', 'geonameId': 1529682, 'name': 'Eurasia Basin', 'fclName': 'undersea', 'toponymName': 'Eurasia Basin', 'fcodeName': 'basin', 'adminName1': '', 'lat': '87', 'fcl': 'U', 'fcode': 'BSNU', 'population': 0}]}
# {'totalResultsCount': 15, 'geonames': [{'adminCode1': '23', 'lng': '7.44278', 'geonameId': 2493956, 'toponymName': 'Héliopolis', 'countryId': '2589581', 'fcl': 'P', 'population': 40139, 'countryCode': 'DZ', 'name': 'Héliopolis', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '24'}, 'countryName': 'Algeria', 'fcodeName': 'populated place', 'adminName1': 'Guelma', 'lat': '36.50361', 'fcode': 'PPL'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=alFawakhir&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 9, 'geonames': [{'lng': '36', 'geonameId': 305104, 'name': 'Levant', 'fclName': 'parks,area, ...', 'toponymName': 'Levant', 'fcodeName': 'region', 'adminName1': '', 'lat': '34', 'fcl': 'L', 'fcode': 'RGN', 'population': 44990000}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': '07', 'lng': '65.18016', 'geonameId': 1466929, 'toponymName': 'Gazah-ye Zowkhānah', 'countryId': '1149361', 'fcl': 'T', 'population': 0, 'countryCode': 'AF', 'name': 'Gazah-ye Zowkhānah', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'FYB'}, 'countryName': 'Afghanistan', 'fcodeName': 'hill', 'adminName1': 'Faryab', 'lat': '35.65832', 'fcode': 'HLL'}]}
# {'totalResultsCount': 1224, 'geonames': [{'adminCode1': 'UT', 'lng': '-109.49567', 'geonameId': 5544336, 'toponymName': 'Old City Park', 'countryId': '6252001', 'fcl': 'L', 'population': 0, 'countryCode': 'US', 'name': 'Old City Park', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'UT'}, 'countryName': 'United States', 'fcodeName': 'park', 'adminName1': 'Utah', 'lat': '38.53998', 'fcode': 'PRK'}]}
# {'totalResultsCount': 19, 'geonames': [{'adminCode1': '14', 'lng': '39.82563', 'geonameId': 104515, 'toponymName': 'Makkah', 'countryId': '102358', 'fcl': 'P', 'population': 1578722, 'countryCode': 'SA', 'name': 'Makkah', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '02'}, 'countryName': 'Saudi Arabia', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Mecca Region', 'lat': '21.42664', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.33333', 'geonameId': 281132, 'toponymName': 'Gaza Strip', 'countryId': '6254930', 'fcl': 'A', 'population': 2047969, 'countryCode': 'PS', 'name': 'Gaza Strip', 'fclName': 'country, state, region,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.41667', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': '10', 'lng': '36.74545', 'geonameId': 12022656, 'toponymName': 'Al Jamea Alkabir', 'countryId': '163843', 'fcl': 'S', 'population': 0, 'countryCode': 'SY', 'name': 'Al Jamea Alkabir', 'fclName': 'spot, building, farm', 'adminCodes1': {'ISO3166_2': 'HM'}, 'countryName': 'Syria', 'fcodeName': 'mosque', 'adminName1': 'Hama', 'lat': '35.13444', 'fcode': 'MSQE'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '34', 'lng': '28.94966', 'geonameId': 745044, 'toponymName': 'Istanbul', 'countryId': '298795', 'fcl': 'P', 'population': 14804116, 'countryCode': 'TR', 'name': 'Istanbul', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '34'}, 'countryName': 'Türkiye', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Istanbul', 'lat': '41.01384', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 122, 'geonames': [{'adminCode1': '07', 'lng': '27.16671', 'geonameId': 13122226, 'toponymName': 'Via Tănase', 'countryId': '798549', 'fcl': 'L', 'population': 0, 'countryCode': 'RO', 'name': 'Via Tănase', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'BT'}, 'countryName': 'Romania', 'fcodeName': 'locality', 'adminName1': 'Botoșani County', 'lat': '47.87844', 'fcode': 'LCTY'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': 'ESYE24', 'lng': '23.44886', 'geonameId': 8224025, 'toponymName': 'Anthedon', 'countryId': '390903', 'fcl': 'S', 'population': 0, 'countryCode': 'GR', 'name': 'Anthedon', 'fclName': 'spot, building, farm', 'adminCodes1': {'ISO3166_2': 'H'}, 'countryName': 'Greece', 'fcodeName': 'archaeological/prehistoric site', 'adminName1': 'Central Greece', 'lat': '38.49842', 'fcode': 'ANS'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Balakhiyah&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '21', 'lng': '30.83845', 'geonameId': 347313, 'toponymName': 'Tīdah', 'countryId': '357994', 'fcl': 'P', 'population': 0, 'countryCode': 'EG', 'name': 'Tīdah', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'KFS'}, 'countryName': 'Egypt', 'fcodeName': 'populated place', 'adminName1': 'Kafr el-Sheikh', 'lat': '31.24415', 'fcode': 'PPL'}]}
# {'totalResultsCount': 845, 'geonames': [{'adminCode1': '01', 'lng': '40.61373', 'geonameId': 167447, 'toponymName': 'Tall Majdal', 'countryId': '163843', 'fcl': 'T', 'population': 0, 'countryCode': 'SY', 'name': 'Tall Majdal', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'HA'}, 'countryName': 'Syria', 'fcodeName': 'hill', 'adminName1': 'Al-Hasakah', 'lat': '36.53984', 'fcode': 'HLL'}]}
# {'totalResultsCount': 945, 'geonames': [{'adminCode1': 'MA', 'lng': '-71.32284', 'geonameId': 4932377, 'toponymName': 'Carver Hill', 'countryId': '6252001', 'fcl': 'T', 'population': 0, 'countryCode': 'US', 'name': 'Carver Hill', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'MA'}, 'countryName': 'United States', 'fcodeName': 'mountain', 'adminName1': 'Massachusetts', 'lat': '42.27426', 'fcode': 'MT'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': '41', 'lng': '59.54541', 'geonameId': 137940, 'toponymName': 'Dārej', 'countryId': '130758', 'fcl': 'P', 'population': 0, 'countryCode': 'IR', 'name': 'Dārej', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '29'}, 'countryName': 'Iran', 'fcodeName': 'populated place', 'adminName1': 'South Khorasan Province', 'lat': '33.24567', 'fcode': 'PPL'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Ahmadiyyah+Zawiya&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 311, 'geonames': [{'adminCode1': '00', 'lng': '41.23464', 'geonameId': 10922505, 'toponymName': 'Eastern Anatolia Region', 'countryId': '298795', 'fcl': 'L', 'population': 4170000, 'countryCode': 'TR', 'name': 'Eastern Anatolia Region', 'fclName': 'parks,area, ...', 'countryName': 'Türkiye', 'fcodeName': 'region', 'adminName1': '', 'lat': '39.42657', 'fcode': 'RGN'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=TomWhiteGaza&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '01', 'lng': '34.58911', 'geonameId': 294068, 'toponymName': 'Netivot', 'countryId': '294640', 'fcl': 'P', 'population': 43732, 'countryCode': 'IL', 'name': 'Netivot', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'D'}, 'countryName': 'Israel', 'fcodeName': 'populated place', 'adminName1': 'Southern District', 'lat': '31.42305', 'fcode': 'PPL'}]}
# {'totalResultsCount': 12, 'geonames': [{'adminCode1': '09', 'lng': '122.0236', 'geonameId': 1726399, 'toponymName': 'Basilan Strait', 'countryId': '1694008', 'fcl': 'H', 'population': 0, 'countryCode': 'PH', 'name': 'Basilan Strait', 'fclName': 'stream, lake, ...', 'adminCodes1': {'ISO3166_2': '09'}, 'countryName': 'Philippines', 'fcodeName': 'strait', 'adminName1': 'Zamboanga Peninsula', 'lat': '6.8127', 'fcode': 'STRT'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '01', 'lng': '34.94821', 'geonameId': 295277, 'toponymName': 'Eilat', 'countryId': '294640', 'fcl': 'P', 'population': 52299, 'countryCode': 'IL', 'name': 'Eilat', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'D'}, 'countryName': 'Israel', 'fcodeName': 'populated place', 'adminName1': 'Southern District', 'lat': '29.55805', 'fcode': 'PPL'}]}
# {'totalResultsCount': 242, 'geonames': [{'adminCode1': 'NY', 'lng': '-73.62391', 'geonameId': 5114639, 'toponymName': 'Dead Sea', 'countryId': '6252001', 'fcl': 'H', 'population': 0, 'countryCode': 'US', 'name': 'Dead Sea', 'fclName': 'stream, lake, ...', 'adminCodes1': {'ISO3166_2': 'NY'}, 'countryName': 'United States', 'fcodeName': 'lake', 'adminName1': 'New York', 'lat': '44.86777', 'fcode': 'LK'}]}
# {'totalResultsCount': 309, 'geonames': [{'adminCode1': '00', 'lng': '41.23464', 'geonameId': 10922505, 'toponymName': 'Eastern Anatolia Region', 'countryId': '298795', 'fcl': 'L', 'population': 4170000, 'countryCode': 'TR', 'name': 'Eastern Anatolia Region', 'fclName': 'parks,area, ...', 'countryName': 'Türkiye', 'fcodeName': 'region', 'adminName1': '', 'lat': '39.42657', 'fcode': 'RGN'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=alKarama&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 5, 'geonames': [{'adminCode1': '00', 'lng': '35.18388', 'geonameId': 8068847, 'toponymName': 'Al Ittişālāt', 'countryId': '6254930', 'fcl': 'S', 'population': 0, 'countryCode': 'PS', 'name': 'Al Ittişālāt', 'fclName': 'spot, building, farm', 'countryName': 'Palestine', 'fcodeName': 'building(s)', 'adminName1': '', 'lat': '32.08712', 'fcode': 'BLDG'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Jawwal&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': 'AR', 'lng': '-92.26543', 'geonameId': 4133047, 'toponymName': 'Sycamore Heights', 'countryId': '6252001', 'fcl': 'P', 'population': 0, 'countryCode': 'US', 'name': 'Sycamore Heights', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'AR'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'Arkansas', 'lat': '36.28562', 'fcode': 'PPL'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '00', 'lng': '44', 'geonameId': 126585, 'toponymName': 'Kurdistan', 'countryId': '99237', 'fcl': 'L', 'population': 4910000, 'countryCode': 'IQ', 'name': 'Kurdistan', 'fclName': 'parks,area, ...', 'countryName': 'Iraq', 'fcodeName': 'region', 'adminName1': '', 'lat': '37', 'fcode': 'RGN'}]}
# {'totalResultsCount': 8, 'geonames': [{'adminCode1': '68', 'lng': '33.15674', 'geonameId': 8378526, 'toponymName': 'Paphlagonia', 'countryId': '298795', 'fcl': 'A', 'population': 0, 'countryCode': 'TR', 'name': 'Paphlagonia (Roman province)', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': '06'}, 'countryName': 'Türkiye', 'fcodeName': 'historical first-order administrative division', 'adminName1': 'Ankara', 'lat': '41.22825', 'fcode': 'ADM1H'}]}
# {'totalResultsCount': 8, 'geonames': [{'adminCode1': '13', 'lng': '36.31307', 'geonameId': 7642445, 'toponymName': 'Basātīn Abū Jarash', 'countryId': '163843', 'fcl': 'L', 'population': 0, 'countryCode': 'SY', 'name': 'Basātīn Abū Jarash', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'DI'}, 'countryName': 'Syria', 'fcodeName': 'oasis(-es)', 'adminName1': 'Dimashq', 'lat': '33.53699', 'fcode': 'OAS'}]}
# {'totalResultsCount': 34, 'geonames': [{'adminCode1': '00', 'lng': '49.23333', 'geonameId': 285645, 'toponymName': 'Durrah', 'countryId': '285570', 'fcl': 'L', 'population': 0, 'countryCode': 'KW', 'name': 'Durrah', 'fclName': 'parks,area, ...', 'countryName': 'Kuwait', 'fcodeName': 'oilfield', 'adminName1': '', 'lat': '28.8', 'fcode': 'OILF'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Bahaas&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': '00', 'lng': '73', 'geonameId': 1282028, 'toponymName': 'Republic of Maldives', 'countryId': '1282028', 'fcl': 'A', 'population': 515696, 'countryCode': 'MV', 'name': 'Maldives', 'fclName': 'country, state, region,...', 'countryName': 'Maldives', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '3.2', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=RepJayapal&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=RepCori&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=BasedMikeLee&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 212, 'geonames': [{'adminCode1': '00', 'lng': '121', 'geonameId': 1668284, 'toponymName': 'Taiwan', 'countryId': '1668284', 'fcl': 'A', 'population': 23451837, 'countryCode': 'TW', 'name': 'Taiwan', 'fclName': 'country, state, region,...', 'countryName': 'Taiwan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '24', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 42, 'geonames': [{'adminCode1': '00', 'lng': '20.91667', 'geonameId': 831053, 'toponymName': 'Republic of Kosovo', 'countryId': '831053', 'fcl': 'A', 'population': 1845300, 'countryCode': 'XK', 'name': 'Kosovo', 'fclName': 'country, state, region,...', 'countryName': 'Kosovo', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '42.58333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 37, 'geonames': [{'adminCode1': '01', 'lng': '-3.95', 'geonameId': 2356765, 'toponymName': 'Pa', 'countryId': '2361809', 'fcl': 'P', 'population': 15170, 'countryCode': 'BF', 'name': 'Pa', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '01'}, 'countryName': 'Burkina Faso', 'fcodeName': 'populated place', 'adminName1': 'Boucle du Mouhoun', 'lat': '12.66667', 'fcode': 'PPL'}]}
# {'totalResultsCount': 12, 'geonames': [{'adminCode1': '12', 'lng': '10.74609', 'geonameId': 3143244, 'toponymName': 'Oslo', 'countryId': '3144096', 'fcl': 'P', 'population': 1082575, 'countryCode': 'NO', 'name': 'Oslo', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '03'}, 'countryName': 'Norway', 'fcodeName': 'capital of a political entity', 'adminName1': 'Oslo', 'lat': '59.91273', 'fcode': 'PPLC'}]}

# %% [markdown]
# Ex 4a

# %%
# Importing the necessary library
import plotly.express as px
import pandas as pd

# Load frequency data
freq_df = pd.read_csv("regex_counts.tsv", sep="\t")

# Load geocoded coordinates
geo_df = pd.read_csv("ner_gazetteer.tsv", sep="\t")


# merge the two tables, using the common column “place”
merged_df = pd.merge(geo_df, freq_df, on="place")


# Plotly animated geo map
fig = px.scatter_geo(
    merged_df,
    lat="latitude",
    lon="longitude",
    size="count",
    color="place",
    hover_name="place",
    animation_frame="month",
    projection="natural earth",
    size_max=20
)
# Save interactive HTML map
fig.write_html("regex_map.html")
# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0324b31f-6af2-4ed2-bbb3-7e32a059fce0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0324b31f-6af2-4ed2-bbb3-7e32a059fce0")) {                    Plotly.newPlot(                        "0324b31f-6af2-4ed2-bbb3-7e32a059fce0",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Gaza\u003cbr\u003emonth=2023-10\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Gaza","Gaza"],"lat":[31.50161,31.50161],"legendgroup":"Gaza","lon":[34.46672,34.46672],"marker":{"color":"#636efa","size":[4208,4208],"sizemode":"area","sizeref":11.42,"symbol":"circle"},"mode":"markers","name":"Gaza","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Gaza Strip\u003cbr\u003emonth=2023-10\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Gaza Strip","Gaza Strip"],"lat":[31.50161,31.50161],"legendgroup":"Gaza Strip","lon":[34.46672,34.46672],"marker":{"color":"#EF553B","size":[4208,4208],"sizemode":"area","sizeref":11.42,"symbol":"circle"},"mode":"markers","name":"Gaza Strip","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Khan Younis\u003cbr\u003emonth=2023-10\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Khan Younis","Khan Younis"],"lat":[31.34018,31.34018],"legendgroup":"Khan Younis","lon":[34.30627,34.30627],"marker":{"color":"#00cc96","size":[74,74],"sizemode":"area","sizeref":11.42,"symbol":"circle"},"mode":"markers","name":"Khan Younis","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Gaza City\u003cbr\u003emonth=2023-10\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Gaza City","Gaza City"],"lat":[31.50161,31.50161],"legendgroup":"Gaza City","lon":[34.46672,34.46672],"marker":{"color":"#ab63fa","size":[4218,4218],"sizemode":"area","sizeref":11.42,"symbol":"circle"},"mode":"markers","name":"Gaza City","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Rafah\u003cbr\u003emonth=2023-10\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Rafah","Rafah"],"lat":[31.29722,31.29722],"legendgroup":"Rafah","lon":[34.24357,34.24357],"marker":{"color":"#FFA15A","size":[182,182],"sizemode":"area","sizeref":11.42,"symbol":"circle"},"mode":"markers","name":"Rafah","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Maghazi\u003cbr\u003emonth=2023-10\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Maghazi","Maghazi"],"lat":[31.42234,31.42234],"legendgroup":"Maghazi","lon":[34.38501,34.38501],"marker":{"color":"#19d3f3","size":[15,15],"sizemode":"area","sizeref":11.42,"symbol":"circle"},"mode":"markers","name":"Maghazi","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002 ...

# %% [markdown]
# Ex 4b

# %%
# Importing the necessary library
import plotly.express as px
import pandas as pd

# Load NER frequency data (January 2024 only)
ner_df = pd.read_csv("ner_counts.tsv", sep="\t")

# Load geocoded coordinates
geo_df = pd.read_csv("ner_gazetteer.tsv", sep="\t")

# Merge NER data with coordinates
merged_df = pd.merge(ner_df, geo_df, on="place")

# Drop rows where coordinates or counts are missing
merged_df = merged_df.dropna(subset=["latitude", "longitude", "count"])

# Create static and interactive maps
fig = px.scatter_geo(
    merged_df,
    lat="latitude",
    lon="longitude",
    size="count",
    color="place",
    hover_name="place",
    projection="natural earth",
    size_max=20,
    title="NER Place Frequencies - January 2024"
)

# Save interactive HTML map
fig.write_html("ner_map.html")

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="34cc251d-b158-43fe-9e70-ebcf7dd66f04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34cc251d-b158-43fe-9e70-ebcf7dd66f04")) {                    Plotly.newPlot(                        "34cc251d-b158-43fe-9e70-ebcf7dd66f04",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Morocco\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Morocco","Morocco"],"lat":[28.5,28.5],"legendgroup":"Morocco","lon":[-10.0,-10.0],"marker":{"color":"#636efa","size":[13.0,13.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"Morocco","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Israel\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Israel","Israel"],"lat":[31.5,31.5],"legendgroup":"Israel","lon":[34.75,34.75],"marker":{"color":"#EF553B","size":[1594.0,1594.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"Israel","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Gaza\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Gaza","Gaza"],"lat":[31.50161,31.50161],"legendgroup":"Gaza","lon":[34.46672,34.46672],"marker":{"color":"#00cc96","size":[1605.0,1605.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"Gaza","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Rabat\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Rabat","Rabat"],"lat":[34.01325,34.01325],"legendgroup":"Rabat","lon":[-6.83255,-6.83255],"marker":{"color":"#ab63fa","size":[3.0,3.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"Rabat","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=United States\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["United States","United States"],"lat":[39.76,39.76],"legendgroup":"United States","lon":[-98.5,-98.5],"marker":{"color":"#FFA15A","size":[160.0,160.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"United States","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=United Arab Emirates\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["United Arab Emirates","United Arab Emirates"],"lat":[23.75,23.75],"legendgroup":"United Arab Emirates","lon":[54.5,54.5],"marker":{"color":"#19d3f3","size":[14.0,14.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"United Arab Emirates","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=UAE\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cext ...
