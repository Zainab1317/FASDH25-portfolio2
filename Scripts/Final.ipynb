# %% [markdown]
# Ex 2A

# %%
# !git clone https://github.com/Zainab1317/FASDH25-portfolio2.git
# Out:
# fatal: destination path 'FASDH25-portfolio2' already exists and is not an empty directory.

# %%
import re #imports regular expression to find text patterns
import os # imports to enable interaction with file system
import pandas as pd #imports to hadle tabular data and export tsv file

def write_tsv(rows, column_list, path): # function writes a list of data rows intotsv file using panadas
    df = pd.DataFrame(rows, columns=column_list) #list of rows is converted into panads DataFrame
    df.to_csv(path, sep="\t", index=False) #DataFrame is written into tsv

#Setup paths
repo_path = "FASDH25-portfolio2" #define path to repository
folder = "FASDH25-portfolio2/articles" #defining folder where articles are present
gazetteer_path = "FASDH25-portfolio2/gazetteers/geonames_gaza_selection.tsv" #define path and load gazetteer from the tsv file having place names and alternate names

#Read Gazetteer File
with open(gazetteer_path, encoding="utf-8") as file:
    data = file.read()

patterns = {} #an empty dictionary is created for each place names and a count for matches
rows = data.split("\n") #split gazetteer data in new lines to get eeach row on file

for row in rows[1:]:  # Skip header because the pattern starts from next row
    columns = row.split("\t") #seprates each column in tsv by tabs
    asciiname = columns[0] #ensures that first column has names for the place
    name_variants = [asciiname] #lists name variants consisting of the standard name
    alternate_names = columns[5].strip() #gets the alternate names from the 6th column which is counted as the 5th column, if present

    if alternate_names:
      alternate_list = alternate_names.split(",") #splits the alternate names with comma and gets list of other names
      for name in alternate_list: #loops through each alternate name in the list
        name_variants.append(name.strip()) #.strip will remove whitespace from alternate names and .append will add alternate names to the list if prenest

# build a regex pattern that will work to find all names and match diffrent varianats of the place names aswell
    regex_pattern = "|".join (re.escape(name) for name in name_variants) #using re.escape to escape any special characters in place names and "|" is used for alternation
    patterns[asciiname] = {"pattern": regex_pattern, "count": 0} #includes all names and their variants with numbers

mentions_per_month = {} #dictionary stores how many times each name was mentioned
war_start_date = "2023-10-07" #set the date to filt

for filename in os.listdir(folder):
    date_str = filename.split("_")[0]
    if date_str < war_start_date:
        continue

    file_path = f"{folder}/{filename}"
    with open(file_path, encoding="utf-8") as file:
        text = file.read()

    for place in patterns:
        pattern = patterns[place]["pattern"]
        matches = re.findall(pattern, text, re.IGNORECASE)
        count = len(matches)
        patterns[place]["count"] += count

        month_str = date_str[:7]

        if place not in mentions_per_month:
            mentions_per_month[place] = {}
        if month_str not in mentions_per_month[place]:
            mentions_per_month[place][month_str] = 0

        mentions_per_month[place][month_str] += count

#Print Output
for place in mentions_per_month:
    print(f'"{place}": {{')
    month_list = list(mentions_per_month[place].keys())
    for month in month_list:
        count = mentions_per_month[place][month]
        if month != month_list[-1]:
            print(f'    "{month}": {count},')
        else:
            print(f'    "{month}": {count}')
    print("},")

#Prepare Rows and Write TSV
output_rows = []
for place in mentions_per_month:
    for month in mentions_per_month[place]:
        count = mentions_per_month[place][month]
        output_rows.append((place, month, count))

write_tsv(output_rows, ["place", "month", "count"], "regex_counts.tsv")
# Out:
# "Jabalya": {
#     "2024-02": 7,
#     "2023-10": 37,
#     "2023-11": 103,
#     "2023-12": 46,
#     "2024-03": 8,
#     "2024-01": 12,
#     "2024-04": 3
# },
# "Bayt Lahya": {
#     "2024-02": 3,
#     "2023-10": 11,
#     "2023-11": 14,
#     "2023-12": 8,
#     "2024-03": 1,
#     "2024-01": 2,
#     "2024-04": 2
# },
# "Jabalia": {
#     "2024-02": 7,
#     "2023-10": 33,
#     "2023-11": 102,
#     "2023-12": 44,
#     "2024-03": 8,
#     "2024-01": 12,
#     "2024-04": 2
# },
# "Bayt Hanun": {
#     "2024-02": 3,
#     "2023-10": 19,
#     "2023-11": 17,
#     "2023-12": 4,
#     "2024-03": 7,
#     "2024-01": 1,
#     "2024-04": 10
# },
# "Khan Younis": {
#     "2024-02": 63,
#     "2023-10": 74,
#     "2023-11": 132,
#     "2023-12": 173,
#     "2024-03": 40,
#     "2024-01": 74,
#     "2024-04": 25
# },
# "An Nusayrat": {
#     "2024-02": 6,
#     "2023-10": 22,
#     "2023-11": 16,
#     "2023-12": 26,
#     "2024-03": 9,
#     "2024-01": 11,
#     "2024-04": 8
# },
# "Al Burayj": {
#     "2024-02": 2,
#     "2023-10": 3,
#     "2023-11": 15,
#     "2023-12": 17,
#     "2024-03": 5,
#     "2024-01": 5,
#     "2024-04": 0
# },
# "Rafah": {
#     "2024-02": 498,
#     "2023-10": 182,
#     "2023-11": 150,
#     "2023-12": 201,
#     "2024-03": 253,
#     "2024-01": 41,
#     "2024-04": 81
# },
# "Bani Suhayla": {
#     "2024-02": 0,
#     "2023-10": 1,
#     "2023-11": 1,
#     "2023-12": 1,
#     "2024-03": 0,
#     "2024-01": 2,
#     "2024-04": 0
# },
# "Nuseirat": {
#     "2024-02": 6,
#     "2023-10": 22,
#     "2023-11": 16,
#     "2023-12": 26,
#     "2024-03": 9,
#     "2024-01": 11,
#     "2024-04": 8
# },
# "Bureij": {
#     "2024-02": 2,
#     "2023-10": 3,
#     "2023-11": 15,
#     "2023-12": 17,
#     "2024-03": 5,
#     "2024-01": 5,
#     "2024-04": 0
# },
# "Al Qararah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 1,
#     "2023-12": 0,
#     "2024-03": 1,
#     "2024-01": 1,
#     "2024-04": 0
# },
# "Abasan al Kabirah": {
#     "2024-02": 1,
#     "2023-10": 4,
#     "2023-11": 5,
#     "2023-12": 4,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Az Zuwaydah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Maghazi": {
#     "2024-02": 2,
#     "2023-10": 15,
#     "2023-11": 28,
#     "2023-12": 49,
#     "2024-03": 3,
#     "2024-01": 9,
#     "2024-04": 0
# },
# "Shukat as Sufi": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Khuza'ah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Mughraqah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Deir El-Balah": {
#     "2024-02": 31,
#     "2023-10": 38,
#     "2023-11": 51,
#     "2023-12": 45,
#     "2024-03": 30,
#     "2024-01": 19,
#     "2024-04": 12
# },
# "An Nasr": {
#     "2024-02": 6,
#     "2023-10": 12,
#     "2023-11": 25,
#     "2023-12": 3,
#     "2024-03": 3,
#     "2024-01": 14,
#     "2024-04": 3
# },
# "Abasan al Jadidah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Fukhkhari": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Wadi as Salqa": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Juhr ad Dik": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Umm an Nasr": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Musaddar": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Mawasi": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 1,
#     "2024-01": 1,
#     "2024-04": 0
# },
# "Al-Shifa Hospital": {
#     "2024-02": 15,
#     "2023-10": 31,
#     "2023-11": 245,
#     "2023-12": 23,
#     "2024-03": 32,
#     "2024-01": 3,
#     "2024-04": 13
# },
# "Umm Jarrah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Musabbih": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Ard Rafah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Qubbah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Junaynah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Ghabah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Filahah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Abu Himar": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Abu 'Awdah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Arab al Qila'i": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Abu Mu'ammar": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Umm al Kilab": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Saknat az Zarqa'": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Rafiah Yam": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Qizan an Najjar": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Qa' al Qurayn": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Nahal Qatif": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Umm Kamil": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "An Nazlah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Mashahirah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Qa' al Kharabah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Daribat ash Shaykh Hammuda": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Izbat Bayt Hanun": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Arab Maslakh Bayt Lahya": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Madinat al 'Awdah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "As Surayij": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Az-Zawayda": {
#     "2024-02": 1,
#     "2023-10": 1,
#     "2023-11": 0,
#     "2023-12": 1,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 1
# },
# "Khuza'a": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "al Fukhari": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Shokat as-Sufi": {
#     "2024-02": 0,
#     "2023-10": 1,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al-Mughraqa": {
#     "2024-02": 0,
#     "2023-10": 1,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 1,
#     "2024-04": 0
# },
# "Bani Suhela": {
#     "2024-02": 0,
#     "2023-10": 3,
#     "2023-11": 5,
#     "2023-12": 0,
#     "2024-03": 2,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Abasan al-Saghira": {
#     "2024-02": 0,
#     "2023-10": 1,
#     "2023-11": 2,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al-Zahra'": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 1,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Khirbat al-Adas": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Qaryah as Suwaydiyah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Katibah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Amal": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 1,
#     "2024-01": 1,
#     "2024-04": 0
# },
# "Atatra": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Remal": {
#     "2024-02": 0,
#     "2023-10": 14,
#     "2023-11": 3,
#     "2023-12": 5,
#     "2024-03": 3,
#     "2024-01": 0,
#     "2024-04": 2
# },
# "At Turkman": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Az Zaytun": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "As Sabra": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Fawayidah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Ash Shaykh 'Ijlin": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Midan Filastin": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Ar Rimal al Janubi": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Ar Rimal ash Shamali": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "An Nasr ash Sharqi": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "An Nasr al Gharbi": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Ash Shaykh Radwan": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Ad Daraj": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "At Tuffah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Jadidah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Maydan ash Shuja'iyah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Madinah al Qadimah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Mu'tarid": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Mintaqah as Sina'iyah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Ar Rasm": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Mattayin": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Harah ash Sharqiyah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Abu Asad": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Abu Sittah": {
#     "2024-02": 0,
#     "2023-10": 1,
#     "2023-11": 0,
#     "2023-12": 4,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 4
# },
# "Hamadah": {
#     "2024-02": 1,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Tunis": {
#     "2024-02": 2,
#     "2023-10": 14,
#     "2023-11": 41,
#     "2023-12": 6,
#     "2024-03": 2,
#     "2024-01": 5,
#     "2024-04": 19
# },
# "Al Masihi": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al 'Amrah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Brawk": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Abu Fayyad": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Umran": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Qata'ah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Hakar": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Hadabah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Farsh": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Umm al 'Azban": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Abu 'Arif": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Bisharah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Qa'ud": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Baldah al Qadimah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Mu'askar": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 1,
#     "2024-04": 0
# },
# "Ash Shaykh Nasir": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Markaz al Madinah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 1,
#     "2024-04": 0
# },
# "Batn as Samin": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Jurat al Lut": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Ma'n": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Qa' al Qarin": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Manarah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Qizan": {
#     "2024-02": 0,
#     "2023-10": 1,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Abu Rashwan": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Hijazi": {
#     "2024-02": 0,
#     "2023-10": 2,
#     "2023-11": 2,
#     "2023-12": 1,
#     "2024-03": 0,
#     "2024-01": 1,
#     "2024-04": 2
# },
# "Tall az Zu'rub": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Hawd Ji": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Hawd Waw": {
#     "2024-02": 1,
#     "2023-10": 1,
#     "2023-11": 1,
#     "2023-12": 2,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 1
# },
# "Yibna": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Qishtah": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al Barazil": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "As Salam": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Al-Azhar University": {
#     "2024-02": 0,
#     "2023-10": 2,
#     "2023-11": 1,
#     "2023-12": 2,
#     "2024-03": 0,
#     "2024-01": 1,
#     "2024-04": 0
# },
# "Al-Aqsa University": {
#     "2024-02": 2,
#     "2023-10": 1,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 2,
#     "2024-04": 0
# },
# "Bi'r Zawalan": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Bi'r Abu Thabit": {
#     "2024-02": 0,
#     "2023-10": 0,
#     "2023-11": 0,
#     "2023-12": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2024-04": 0
# },
# "Gaza": {
#     "2024-02": 1896,
#     "2023-10": 4208,
#     "2023-11": 4552,
#     "2023-12": 2892,
#     "2024-03": 2206,
#     "2024-01": 1966,
#     "2024-04": 1002
# },
# "Gaza Strip": {
#     "2024-02": 1896,
#     "2023-10": 4208,
#     "2023-11": 4552,
#     "2023-12": 2892,
#     "2024-03": 2206,
#     "2024-01": 1966,
#     "2024-04": 1002
# },
# "Gaza City": {
#     "2024-02": 1904,
#     "2023-10": 4218,
#     "2023-11": 4568,
#     "2023-12": 2915,
#     "2024-03": 2218,
#     "2024-01": 1973,
#     "2024-04": 1005
# },

# %% [markdown]
# Ex 2B

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.10.1-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (5.29.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.4.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3.0->stanza)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)
# Downloading stanza-1.10.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 65.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.7 MB/s eta 0:00:00
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 48.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, emoji, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed emoji-2.14.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stanza-1.10.1

# %%
#import libraries and import language model
import re
import stanza
import os
stanza.download("en")
#create pipeline and specify language
nlp = stanza.Pipeline(lang="en", processors="tokenize,mwt,ner")
#path to the repository
# !git clone https://github.com/Zainab1317/FASDH25-portfolio2.git

corpus = "/content/FASDH25-portfolio2/articles"

files = os.listdir(corpus)

jan_2024_files = []
#loop through the entities putting them in a separate list
for file in files:
    if file.startswith("2024-01"):
       jan_2024_files.append(file)
#opening and reading the file
place_counts = {}
for file in jan_2024_files:
    filepath = f"{corpus}/{file}"
    with open(filepath, encoding="utf8") as file:
        text = file.read()
#isolating required entities (gpes and locs)
    doc = nlp(text)
    for sentence in doc.sentences:
      for entity in sentence.ents:
        if entity.type in ["GPE", "LOC", "FAC"]:
          place = entity.text.strip()
          place_counts[place] = place_counts.get(place, 0) + 1

#cleaning the named entities
clean_counts = {}

for place, count in place_counts.items():
    place = re.sub(r"['`]s\b", "", place)

    place = re.sub(r"[^\w\s]", "", place)

    place = re.sub(r"^the\s+", "", place, flags=re.IGNORECASE)

    clean_counts[place] = clean_counts.get(place, 0) + count

# Write cleaned and sorted data to a TSV file
items = [[place, count] for place, count in clean_counts.items()]

with open("ner_counts.tsv", "w", encoding="utf-8") as file:
    file.write("place\tcount\n")
    for item in items:
        file.write(f"{item[0]}\t{item[1]}\n")

# Read and print the TSV file contents
with open("/content/ner_counts.tsv", encoding="utf-8") as file:
    print(file.read())
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: en (English) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.10.0/models/default.zip:   0%|          | …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: en (English):
# =========================================
# | Processor | Package                   |
# -----------------------------------------
# | tokenize  | combined                  |
# | mwt       | combined                  |
# | ner       | ontonotes-ww-multi_charlm |
# =========================================
#
# INFO:stanza:Using device: cuda
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!
# fatal: destination path 'FASDH25-portfolio2' already exists and is not an empty directory.
# place	count
# West Bank	160
# Dura	2
# Hebron	10
# Tulkarem	2
# Gaza Strip	156
# Israel	1594
# Nablus	5
# Red Sea	250
# United States	160
# United Kingdom	43
# Yemen	182
# Iran	206
# Gaza	1605
# US	717
# Sanaa	15
# Saudi Arabia	39
# Aden	3
# Tel Aviv	49
# UK	95
# Palestine	124
# Suez Canal	26
# Africa	29
# Marib	3
# Middle East	102
# United Arab Emirates	14
# Turkey	25
# Jordan	42
# Qatar	64
# UAE	7
# Charleston	1
# South Carolina	4
# Gaza City	31
# Doha	19
# Hong Kong	2
# Abdullah bin Khalifa Stadium	1
# South Africa	200
# State of Palestine	1
# Lebanon	175
# Hague	39
# Pretoria	8
# Uganda	11
# China	28
# Russia	43
# Kuwait	2
# Gazas	19
# Ukraine	47
# Canada	42
# Montreal	1
# Milton Ontario	1
# Jabalia	11
# Israels	31
# Ottawa	3
# Egypt	43
# Rafah	40
# Toronto	1
# Calgary	1
# Afghanistan	7
# Austria	3
# Australia	12
# Finland	3
# Germany	31
# Italy	10
# Japan	9
# Netherlands	14
# Iceland	1
# Sweden	3
# Switzerland	9
# Romania	4
# Washington DC	7
# Jerusalem	26
# Gretna	2
# Louisiana	3
# New Orleans	5
# Highway 60	3
# MirandaCleland	1
# East Jerusalem	23
# Scotland	2
# Ireland	3
# Norway	11
# October7	2
# Syria	83
# Jenin	19
# Beit Iksa	1
# Ramallah	24
# Abwein	1
# Qalqilya	2
# Jericho	1
# Yemens	6
# Bahrain	11
# Denmark	3
# New Zealand	2
# South Korea	1
# Spain	7
# France	13
# Belgium	15
# Czech Republic	1
# Hungary	1
# Berlin	5
# Paris	8
# Slovenia	1
# Brussels	5
# carogennez	1
# Belgiums	1
# Flanders	1
# Wallonia	1
# Ein alHilweh	1
# Basel	3
# Ofer	1
# Jordan Valley	5
# Area C	6
# Kadris	1
# alJiftlik	1
# Farsiya	1
# Makhoul	1
# Tubas	1
# Umm Zuka	1
# Areas A	1
# Beirut	84
# Washington	60
# Kerman	6
# Islamic Republic	5
# Nur Shams	1
# Naqoura	2
# Deir elBalah	15
# Nuseirat	11
# DC	14
# America	4
# Strip	15
# West	24
# Tel Avivs	3
# London	17
# Tel Israels	1
# South Africas	8
# Myanmar	6
# Kuala Lumpur	4
# Malaysia	8
# Indonesias	1
# Jakarta	2
# Johannesburg	4
# Vienna	1
# Amman	6
# Bank Junction	1
# Manchester	1
# India	50
# Hyderabad	1
# Colombos Kollupitiya	1
# Farhana	1
# Khan Younis	24
# Abudaqa	2
# Dahiyeh	6
# Beiruts Shatila	1
# Earth	1
# Lama Khater	1
# Kiryat Arba	2
# Hasharon Prison	1
# Damon Prison	1
# Ofer Prison	1
# Britain	14
# Republic of Yemen	1
# Hodeidah	5
# Saada	3
# Taiz	2
# Hajjah	2
# Europe	30
# Asia	18
# Sudan	3
# Iraq	62
# Syrias Aleppo	1
# Mariupol	1
# Dublin	3
# Moscow	4
# Global South	2
# Beiruts	3
# Hezbollahs	1
# Arura	2
# Deir Qaddis	1
# El Arish	3
# Hostage Square	2
# Hamass	6
# Aizawl	6
# Manipur	8
# Kangpokpi	1
# Mizoram	7
# Mizorams	1
# Kingdom of Judah	1
# Anu Museum	1
# Bnei Menashe	3
# Kolasib	1
# Bethlehem	4
# Nairoukh	1
# Shawawra	1
# Tehran	25
# X
# Spain	1
# Madrid	1
# Oman	1
# Gulf	10
# White House	6
# Bani Suheila	2
# alFukhari	2
# Damascus	17
# alAssad Airbase	3
# Baghdad	8
# Near East	3
# Serbia	3
# BosniaHerzegovina	1
# Srebrenica	1
# Algeria	7
# Frances	1
# State of Israel	7
# Gazas Deir elBalah	3
# Egypts El Arish International Airport	1
# MoTaz	1
# azaizamotaz9	1
# Yugoslavia	2
# Ocean Jazz	1
# Gulf of Aden	27
# Philippines	4
# Bab elMandeb	2
# Cape of Good Hope	12
# Pakistan	24
# Erbil	13
# Pakistans Balochistan province	2
# Irans SistanBaluchestan province	2
# Irans	3
# Rask	1
# SistanBaluchestan	1
# Strait of Hormuz	3
# Persian Gulf	1
# Davos	7
# Balochistan	1
# Netanyahus	7
# Supernova	1
# Houthis	3
# BabelMandeb Strait	1
# Dhamar	1
# alBayda	1
# Arabian Sea	6
# Bab alMandeb Strait	9
# Khan Younis Training Centre	2
# alKarama	1
# Beruit	1
# Lebanons	3
# United Nations	1
# Yemens coast	2
# Maghazi	5
# Manchester City	1
# Barcelona	1
# Chile	4
# Mexico	5
# Chiles	1
# Santiago	1
# Bangladesh	2
# Bolivia	4
# Comoros	2
# Djibouti	4
# Kaplan Square	1
# Haifa	8
# Caesarea	2
# Kefar Sava	1
# Rehovot	1
# Beersheba	1
# AlAmal Hospital	3
# Khan Yunis	1
# Nasser Hospital	10
# Mawasi	1
# Dearborn	12
# Michigan	12
# Chicago	2
# New Delhi	6
# Indias Basmati	1
# North America	2
# North Africa	5
# AlAqsa Martyrs Hospital	4
# alShifa	2
# Welchs	1
# Kampala	5
# Ugandas	1
# Indonesia	2
# Peru	1
# Colombia	1
# South Sudan	1
# Swaziland	1
# Lisbon	1
# Portugal	3
# Meron	2
# Kiryat Shmona	1
# Blue Line	1
# Singapore	2
# Mediterranean	11
# Indian Ocean	2
# Bahaa elDin Abu Ras	1
# Bahaas	1
# Abdullah Azzam Mosque	1
# Marshall Islands	1
# Morocco	13
# Rabat	3
# Western Sahara	4
# Marrakesh	1
# Moroccos	1
# Maghreb	1
# alWalaja	5
# Gilo	1
# Har Gilo	1
# Education City Stadium	1
# Al Rayyan	1
# Qatars	1
# Salah alDin Street	3
# Wadi Gaza	3
# Bosnia	3
# Sri Lanka	2
# Republic of South Africa	1
# AlAqsa Mosque	1
# PA	1
# Oslo	2
# Cairo	6
# New York	4
# Belarus	1
# Ebel elSaqi	1
# Entebbe Uganda	1
# Sierra Leone	1
# DRC	1
# adoniaayebare	1
# Namibia	10
# Shadis	1
# Khreiss	1
# Northern Gaza	1
# Malta	2
# Gulf of Oman	2
# Ankara	7
# Aqaba	1
# California	3
# Panjgur	1
# SistanBaluchestan province	1
# Islamabad	3
# Islamic Republic of Iran	1
# RepJayapal	1
# RepCori	1
# BasedMikeLee	1
# Texas	3
# Republic of Korea	1
# Libya	3
# Kosovo	1
# Sabra	1
# Shatila	3
# Kyiv	5
# alShifa Hospital	3
# Somalia	1
# Yemens Red Sea	1
# Washingtons	2
# Rawaas	1
# alMawasi district	2
# El Amal City Hospital	2
# Ibn Sina Hospital	2
# alAhli Arab Hospital	1
# Cameroon	1
# Iron Dome	1
# alAhli	1
# Egypts Sinai Peninsula	1
# Philadelphi	1
# Karem Abu Salem	3
# Kerem Shalom	4
# Greece	8
# Dubai	1
# Bab alMandeb	4
# Yemens southern coast	1
# Riyadh	5
# Yaroun	3
# Lebanons Nabatieh	1
# Yiron	1
# Avivim	1
# Israels Goren	1
# Palestine Martyrs Cemetery	1
# Herzegovina	1
# Montenegro	1
# Silicon Valley	3
# Beit Shemesh	1
# Santa Clara	1
# West Banks	2
# Moldova	1
# Bern	1
# Zurich	1
# Netivot	1
# IsraelPalestine	2
# alDabshah	1
# Khirbet Selm	1
# Bint Jbeil	1
# Ibil El Saqi	1
# alTawils	1
# alKhader	1
# Bekaa Valley	1
# Litani River	1
# alMazraa Asharqiya	2
# Masjid Omar mosque	1
# Harvey	1
# Tawfiq	1
# Road 60	1
# New York City	1
# Middle East Eye	1
# Al Maniya	1
# WestBank	2
# Thameen Darby	1
# Nakba Layer	1
# Mercator	1
# Alaska	1
# South America	2
# AsiaPacific	1
# Golan Heights	3
# Crimea	4
# South China Sea	2
# Vietnam	1
# Kashmir	4
# Darbys Nakba	1
# Gaza strip	1
# Gaza Strips	3
# NaksBilal	1
# Beit Lahiya	2
# alMazraa	1
# Mediterranean Sea	2
# Ajaq	1
# Silwad	1
# Ras Issa	1
# Hodeidah province	1
# Rohtak	6
# Haryana	3
# Uttar Pradesh	1
# Lucknow	1
# UP	1
# Bihar	4
# West Bengal	1
# Benarasiyaa	1
# Haryanas Panipat	1
# Thailand	2
# Middle Eastern	3
# Haryanas Jind	1
# Palestinian Territories	1
# Ansarallah	1
# Tel Avivs Hostage Square	1
# majedalansari	1
# Kan	1
# West Jerusalem	1
# Egypts	1
# Bab al	1
# Mandeb Strait	1
# Lod Airport	1
# Ben Gurion International Airport	1
# Munich	2
# Sidon	3
# Salamehs	1
# alMajzoubs	1
# Tunisia	2
# Bir anNaaja	1
# Zawayda	1
# Beit Hanoon	1
# Kamal Adwan Hospital	2
# La France	1
# At Tur EastJerusalem	1
# Mediterraneans	1
# Eurasia	1
# Via Maris	3
# Heliopolis	1
# Gazas Great Omari Mosque	1
# Jalaa Street	1
# alFawakhir	1
# Rafah Museum	1
# Al Qarara Museum	1
# Khan Younis Museum	1
# Levant	1
# Mathaf alFunduq	1
# Mathaf Hotel	1
# Qasr AlBasha	1
# Pashas Palace	1
# Rashad El Shawa Cultural Center	1
# Library of the Great Omari Mosque	1
# Omari Mosque	1
# HMML Reading Room	1
# Othman bin Qashqar Mosque	1
# Gaza Citys Zeitoun	1
# Sayed alHashim Mosque	1
# Old City of Gaza	1
# Mecca	1
# Gazas Daraj	1
# Great Omari Mosque	1
# AlMasjid alOmari alKabir	1
# St John the Baptist Cathedral	1
# Byzantine Church of Jabalia	1
# Byzantium	1
# Monastery of Saint Hilarion	1
# Tell Umm Amer	1
# Zeitoun	4
# Saint Porphyrius	1
# Katib alWilaya Mosque	1
# Holy Family Church	1
# ArdalMoharbeen	1
# Roman Necropolis	1
# Anthedon	1
# Balakhiyah	1
# Tida	1
# Hammam alSammara	1
# Samaritan Bathhouse	1
# Israel Museum	1
# Tell elAjjul	1
# Calves Hill	1
# Gizas Great Pyramid	1
# Cyprus	9
# Khan Younis caravanserai	1
# Deir elBalah Cemetery	1
# Daraj	1
# Ahmadiyyah Zawiya	1
# alSabeen Square	1
# Seychelles	1
# Bab alMandeb strait	3
# Maldives	1
# Columbia	3
# Istanbul	2
# Crete	2
# Vahdettin Mansion	1
# Bureij	2
# alMahatta	1
# Mozambique	1
# Bulgaria	1
# Al Jazeeras	1
# alMawasi	3
# Iraqs	2
# Idlib	3
# Detroit	1
# Southeast Michigan	1
# Arab America	1
# Jarrah	1
# Wayne County	1
# Minnesota	1
# Des Moines	7
# Iowa	12
# Cedar Rapids	5
# Iowa City	5
# South Asia	1
# Florida	1
# New Yorks Ellis Island	1
# Ohio	1
# Shujayea	3
# Dahiyeb	1
# alArouris	1
# Aroura	2
# alArouri	2
# alAqsa Martyrs Hospital	3
# alMughraqa	1
# alMaghazi	1
# Maghazi Roads	1
# Deir alBalah	1
# Houthi	3
# Tower 22	5
# Jordans	1
# alTanf	1
# BaghdadDamascus highway	1
# Hashemite Kingdom of Jordan	1
# Ain alAssad	1
# Dahiya	1
# Jamaa Islamiya	2
# Westminster Bridge	1
# Gazas AlAqsa Hospital	1
# Geneva	2
# Gaza city	1
# Ashdod	2
# Karem Abu Salem crossing	1
# Hebrew	1
# Mackinac Island	1
# Great Lakes	1
# Lake Michigan	1
# Beit Nabala	1
# Syrias Damascus	1
# Syrias	1
# Mazzeh	2
# Borj el Barajneh	1
# Ain alAsad	1
# West Beirut	9
# Beiruts Hamra	1
# Hamras	1
# Hamra	2
# West Beirutis	1
# Dabbouch	1
# East Beirut	1
# Israels Haifa	1
# Estonia	1
# Bab elMandeb strait	1
# Maersk Hangzhou	1
# Southern Red Sea	1
# Africas Cape of Good Hope	1
# Eastern Mediterranean	1
# BabelMandeb strait	1
# Red Sea Port	1
# Eilat	2
# Dead Sea	1
# Eastern Mediterranean region	1
# Hamoud	1
# Burj alBarajneh	1
# Taalbaya	1
# Rashidiya	1
# Erbil Airport	1
# Maroun El Ras	1
# Rmeish	1
# Port of Ashdod	1
# Miraj	1
# Tal alHawa	1
# zarahsultana	1
# Gisha	1
# Bani Naim	1
# Raanana	1
# Sderot	2
# Nir Am	1
# Mefalsim	1
# Hanita	1
# Mattat	1
# Margaliot	1
# Adamit	1
# Zarit	1
# Malkia	1
# Yassins house	1
# Daouds house	1
# Pentagon	1
# Jordan River	1
# Alborz	4
# Bab alMandab	1
# Southern Africa	2
# Venezuela	1
# Hormuz	1
# Arabian Gulf	1
# Kanaker	1
# Sarit	1
# Aleppo	2
# TomWhiteGaza	1
# Nasser Medical Complex	4
# El Amal Hospital	2
# Entebbe	1
# Central Gaza Strip	2
# European Gaza Hospital	1
# AlAqsa	1
# Al Aqsa Hospital	1
# Syrias Golan Heights	1
# Kurdistan	1
# Panjgur Pakistans Balochistan province	1
# RedSea	1
# Chinas	2
# Walla	2
# Rwanda	1
# East Timor	1
# Kabul	1
# azZahra	1
# alRashid road	1
# Hamad	1
# State of Qatar	1
# QFFD	1
# Melbourne Australia	1
# Port of Melbourne	1
# Victorian International Container Terminal	1
# Melbourne	5
# Sandridge Beach	1
# ZIM Ganges	5
# Australias	1
# Port Melbourne	1
# Sydney	1
# Brisbane	1
# northGaza	1
# Palestine_UN	1
# Taiz province	1
# AlBayda	1
# Dena	1
# Oakland	1
# Akrotiri	12
# Limassol	1
# Pashias	1
# Israels Nevatim airbase	1
# Anadolu	1
# Nevatim	1
# Ben Gurion airport	1
# Republic of Cyprus	2
# Dhekelia	1
# USA	2
# League of Arab States	1
# Palestine Mosque Square	1
# Abu Youssef Al Najjar Hospital	1
# alSaftawi	1
# AlFukhari	1
# alAmal	4
# alNasser	1
# alKatiba	1
# Harun arRashid school	1
# Block 109	1
# Cape Town	2
# South Africansfrom	1
# Africa4Palestine	1
# Western Cape province	1
# Paltel	1
# Jawwal	1
# Salem	1
# Copenhagen	1

# %% [markdown]
# Ex 3

# %%
# !pip install stanza
# Out:
# Requirement already satisfied: stanza in /usr/local/lib/python3.11/dist-packages (1.10.1)
# Requirement already satisfied: emoji in /usr/local/lib/python3.11/dist-packages (from stanza) (2.14.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (5.29.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.4.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)

# %%
import requests
import time

geonames_username = "zainab128"

def get_coordinates(place, username=geonames_username, fuzzy=0, timeout=1):

  # wait a short while, so that we don't overload the server:
  time.sleep(timeout)
  # make the API call:
  url = "http://api.geonames.org/searchJSON?"
  params = {"q": place, "username": username, "fuzzy": fuzzy, "maxRows": 1, "isNameRequired": True}
  response = requests.get(url, params=params)
  # convert the response into a dictionary:
  results = response.json()
  print(results)
  # get the first result:
  try:
    result = results["geonames"][0]
    return {"latitude": result["lat"], "longitude": result["lng"]}
  except (IndexError, KeyError):
    print("No results found for your API call", response.request.url)

import csv

filename = "ner_gazetteer.tsv"

with open(filename, mode="w", encoding="utf-8") as file:
  header = "place\tlatitude\tlongitude\n"
  file.write(header)
  with open("ner_counts.tsv", encoding="utf-8") as infile:
    reader = csv.DictReader(infile, delimiter='\t')
    for row in reader:
      place_name = row['place']
      coordinates = get_coordinates(place_name)
      if coordinates:
        latitude = coordinates["latitude"]
        longitude = coordinates["longitude"]
        row_data = f"{place_name}\t{latitude}\t{longitude}\n"
        file.write(row_data)
      else:
           row_data = f"{place_name}\tNA\tNA\n"
      file.write(row_data)
# Out:
# {'totalResultsCount': 2604, 'geonames': [{'adminCode1': '10375968', 'lng': '-81.39281', 'geonameId': 3580477, 'toponymName': 'West Bay', 'countryId': '3580718', 'fcl': 'P', 'population': 15335, 'countryCode': 'KY', 'name': 'West Bay', 'fclName': 'city, village,...', 'countryName': 'Cayman Islands', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'West Bay', 'lat': '19.38197', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 34, 'geonames': [{'adminCode1': '00', 'lng': '49.23333', 'geonameId': 285645, 'toponymName': 'Durrah', 'countryId': '285570', 'fcl': 'L', 'population': 0, 'countryCode': 'KW', 'name': 'Durrah', 'fclName': 'parks,area, ...', 'countryName': 'Kuwait', 'fcodeName': 'oilfield', 'adminName1': '', 'lat': '28.8', 'fcode': 'OILF'}]}
# {'totalResultsCount': 100, 'geonames': [{'adminCode1': 'WE', 'lng': '35.0938', 'geonameId': 285066, 'toponymName': 'Hebron', 'countryId': '6254930', 'fcl': 'P', 'population': 160470, 'countryCode': 'PS', 'name': 'Hebron', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'West Bank', 'lat': '31.52935', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': 'WE', 'lng': '35.0269', 'geonameId': 281577, 'toponymName': 'Ţūlkarm', 'countryId': '6254930', 'fcl': 'P', 'population': 44169, 'countryCode': 'PS', 'name': 'Tulkarm', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'West Bank', 'lat': '32.31156', 'fcode': 'PPL'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.46672', 'geonameId': 281133, 'toponymName': 'Gaza', 'countryId': '6254930', 'fcl': 'P', 'population': 410000, 'countryCode': 'PS', 'name': 'Gaza', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.50161', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 33, 'geonames': [{'adminCode1': '00', 'lng': '34.75', 'geonameId': 294640, 'toponymName': 'State of Israel', 'countryId': '294640', 'fcl': 'A', 'population': 8883800, 'countryCode': 'IL', 'name': 'Israel', 'fclName': 'country, state, region,...', 'countryName': 'Israel', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '31.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 13, 'geonames': [{'adminCode1': 'WE', 'lng': '35.25444', 'geonameId': 282615, 'toponymName': 'Nablus', 'countryId': '6254930', 'fcl': 'P', 'population': 130326, 'countryCode': 'PS', 'name': 'Nablus', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'West Bank', 'lat': '32.22111', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 1970, 'geonames': [{'adminCode1': '01', 'lng': '-113.802', 'geonameId': 6118158, 'toponymName': 'Red Deer', 'countryId': '6251999', 'fcl': 'P', 'population': 73593, 'countryCode': 'CA', 'name': 'Red Deer', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'AB'}, 'countryName': 'Canada', 'fcodeName': 'populated place', 'adminName1': 'Alberta', 'lat': '52.26682', 'fcode': 'PPL'}]}
# {'totalResultsCount': 209, 'geonames': [{'adminCode1': '00', 'lng': '-98.5', 'geonameId': 6252001, 'toponymName': 'United States', 'countryId': '6252001', 'fcl': 'A', 'population': 327167434, 'countryCode': 'US', 'name': 'United States', 'fclName': 'country, state, region,...', 'countryName': 'United States', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '39.76', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 181, 'geonames': [{'adminCode1': '00', 'lng': '-2.69531', 'geonameId': 2635167, 'toponymName': 'United Kingdom of Great Britain and Northern Ireland', 'countryId': '2635167', 'fcl': 'A', 'population': 66488991, 'countryCode': 'GB', 'name': 'United Kingdom', 'fclName': 'country, state, region,...', 'countryName': 'United Kingdom', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '54.75844', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '00', 'lng': '47.5', 'geonameId': 69543, 'toponymName': 'Republic of Yemen', 'countryId': '69543', 'fcl': 'A', 'population': 28498687, 'countryCode': 'YE', 'name': 'Yemen', 'fclName': 'country, state, region,...', 'countryName': 'Yemen', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '15.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '00', 'lng': '53', 'geonameId': 130758, 'toponymName': 'Islamic Republic of Iran', 'countryId': '130758', 'fcl': 'A', 'population': 81800269, 'countryCode': 'IR', 'name': 'Iran', 'fclName': 'country, state, region,...', 'countryName': 'Iran', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '32', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 40, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.46672', 'geonameId': 281133, 'toponymName': 'Gaza', 'countryId': '6254930', 'fcl': 'P', 'population': 410000, 'countryCode': 'PS', 'name': 'Gaza', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.50161', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '11', 'lng': '1.96667', 'geonameId': 2971316, 'toponymName': 'Us', 'countryId': '3017382', 'fcl': 'P', 'population': 1248, 'countryCode': 'FR', 'name': 'Us', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'IDF'}, 'countryName': 'France', 'fcodeName': 'populated place', 'adminName1': 'Île-de-France', 'lat': '49.1', 'fcode': 'PPL'}]}
# {'totalResultsCount': 5, 'geonames': [{'adminCode1': '26', 'lng': '44.20667', 'geonameId': 71137, 'toponymName': 'Sanaa', 'countryId': '69543', 'fcl': 'P', 'population': 1937451, 'countryCode': 'YE', 'name': 'Sanaa', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'SA'}, 'countryName': 'Yemen', 'fcodeName': 'capital of a political entity', 'adminName1': 'Amanat Alasimah', 'lat': '15.35472', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '00', 'lng': '45', 'geonameId': 102358, 'toponymName': 'Kingdom of Saudi Arabia', 'countryId': '102358', 'fcl': 'A', 'population': 33699947, 'countryCode': 'SA', 'name': 'Saudi Arabia', 'fclName': 'country, state, region,...', 'countryName': 'Saudi Arabia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 27, 'geonames': [{'adminCode1': '02', 'lng': '45.03667', 'geonameId': 415189, 'toponymName': 'Aden', 'countryId': '69543', 'fcl': 'P', 'population': 863000, 'countryCode': 'YE', 'name': 'Aden', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'AD'}, 'countryName': 'Yemen', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Aden', 'lat': '12.77944', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 325, 'geonames': [{'adminCode1': '05', 'lng': '34.78057', 'geonameId': 293397, 'toponymName': 'Tel Aviv', 'countryId': '294640', 'fcl': 'P', 'population': 432892, 'countryCode': 'IL', 'name': 'Tel Aviv', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'TA'}, 'countryName': 'Israel', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Tel Aviv', 'lat': '32.08088', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 8, 'geonames': [{'adminCode1': '00', 'lng': '-2.69531', 'geonameId': 2635167, 'toponymName': 'United Kingdom of Great Britain and Northern Ireland', 'countryId': '2635167', 'fcl': 'A', 'population': 66488991, 'countryCode': 'GB', 'name': 'United Kingdom', 'fclName': 'country, state, region,...', 'countryName': 'United Kingdom', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '54.75844', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 49, 'geonames': [{'adminCode1': '00', 'lng': '35.20329', 'geonameId': 6254930, 'toponymName': 'Palestine', 'countryId': '6254930', 'fcl': 'A', 'population': 4569087, 'countryCode': 'PS', 'name': 'Palestine', 'fclName': 'country, state, region,...', 'countryName': 'Palestine', 'fcodeName': 'semi-independent political entity', 'adminName1': '', 'lat': '31.92157', 'fcode': 'PCLS'}]}
# {'totalResultsCount': 23, 'geonames': [{'adminCode1': '15', 'lng': '32.56278', 'geonameId': 347712, 'toponymName': 'Suez Canal', 'countryId': '357994', 'fcl': 'H', 'population': 0, 'countryCode': 'EG', 'name': 'Suez Canal', 'fclName': 'stream, lake, ...', 'adminCodes1': {'ISO3166_2': 'SUZ'}, 'countryName': 'Egypt', 'fcodeName': 'canal', 'adminName1': 'Suez', 'lat': '29.93139', 'fcode': 'CNL'}]}
# {'totalResultsCount': 29, 'geonames': [{'lng': '21.09375', 'geonameId': 6255146, 'name': 'Africa', 'fclName': 'parks,area, ...', 'toponymName': 'Africa', 'fcodeName': 'continent', 'adminName1': '', 'lat': '7.1881', 'fcl': 'L', 'fcode': 'CONT', 'population': 1031833000}]}
# {'totalResultsCount': 17, 'geonames': [{'adminCode1': '14', 'lng': '46.0111', 'geonameId': 6940835, 'toponymName': 'Marib', 'countryId': '69543', 'fcl': 'A', 'population': 0, 'countryCode': 'YE', 'name': 'Marib District', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'MA'}, 'countryName': 'Yemen', 'fcodeName': 'second-order administrative division', 'adminName1': 'Ma’rib', 'lat': '15.6213', 'fcode': 'ADM2'}]}
# {'totalResultsCount': 2622, 'geonames': [{'lng': '35.85869', 'geonameId': 6269133, 'name': 'Middle East', 'fclName': 'parks,area, ...', 'toponymName': 'Middle East', 'fcodeName': 'region', 'adminName1': '', 'lat': '33.13906', 'fcl': 'L', 'fcode': 'RGN', 'population': 371400000}]}
# {'totalResultsCount': 531, 'geonames': [{'adminCode1': '00', 'lng': '54.5', 'geonameId': 290557, 'toponymName': 'United Arab Emirates', 'countryId': '290557', 'fcl': 'A', 'population': 9630959, 'countryCode': 'AE', 'name': 'United Arab Emirates', 'fclName': 'country, state, region,...', 'countryName': 'United Arab Emirates', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '23.75', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 23, 'geonames': [{'adminCode1': '00', 'lng': '35', 'geonameId': 298795, 'toponymName': 'Republic of Turkey', 'countryId': '298795', 'fcl': 'A', 'population': 82319724, 'countryCode': 'TR', 'name': 'Türkiye', 'fclName': 'country, state, region,...', 'countryName': 'Türkiye', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '39', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 110, 'geonames': [{'adminCode1': '00', 'lng': '36', 'geonameId': 248816, 'toponymName': 'Hashemite Kingdom of Jordan', 'countryId': '248816', 'fcl': 'A', 'population': 9956011, 'countryCode': 'JO', 'name': 'Jordan', 'fclName': 'country, state, region,...', 'countryName': 'Jordan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '31', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 22, 'geonames': [{'adminCode1': '00', 'lng': '51.25', 'geonameId': 289688, 'toponymName': 'State of Qatar', 'countryId': '289688', 'fcl': 'A', 'population': 2781677, 'countryCode': 'QA', 'name': 'Qatar', 'fclName': 'country, state, region,...', 'countryName': 'Qatar', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 4, 'geonames': [{'adminCode1': '00', 'lng': '-14.7', 'geonameId': 2368892, 'toponymName': 'Uaè', 'countryId': '2372248', 'fcl': 'P', 'population': 0, 'countryCode': 'GW', 'name': 'Uaè', 'fclName': 'city, village,...', 'countryName': 'Guinea-Bissau', 'fcodeName': 'populated place', 'adminName1': '', 'lat': '12.26667', 'fcode': 'PPL'}]}
# {'totalResultsCount': 65, 'geonames': [{'adminCode1': 'SC', 'lng': '-79.93275', 'geonameId': 4574324, 'toponymName': 'Charleston', 'countryId': '6252001', 'fcl': 'P', 'population': 132609, 'countryCode': 'US', 'name': 'Charleston', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'SC'}, 'countryName': 'United States', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'South Carolina', 'lat': '32.77632', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 1751, 'geonames': [{'adminCode1': 'SC', 'lng': '-81.00009', 'geonameId': 4597040, 'toponymName': 'South Carolina', 'countryId': '6252001', 'fcl': 'A', 'population': 4229842, 'countryCode': 'US', 'name': 'South Carolina', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'SC'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'South Carolina', 'lat': '34.00043', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 78, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.46672', 'geonameId': 281133, 'toponymName': 'Gaza', 'countryId': '6254930', 'fcl': 'P', 'population': 410000, 'countryCode': 'PS', 'name': 'Gaza', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.50161', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '01', 'lng': '51.53096', 'geonameId': 290030, 'toponymName': 'Doha', 'countryId': '289688', 'fcl': 'P', 'population': 344939, 'countryCode': 'QA', 'name': 'Doha', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'DA'}, 'countryName': 'Qatar', 'fcodeName': 'capital of a political entity', 'adminName1': 'Baladīyat ad Dawḩah', 'lat': '25.28545', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 1713, 'geonames': [{'lng': '114.17469', 'geonameId': 1819729, 'toponymName': 'Hong Kong', 'countryId': '1819730', 'fcl': 'P', 'population': 7491609, 'countryCode': 'HK', 'name': 'Hong Kong', 'fclName': 'city, village,...', 'countryName': 'Hong Kong', 'fcodeName': 'capital of a political entity', 'adminName1': '', 'lat': '22.27832', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 93, 'geonames': [{'adminCode1': '05', 'lng': '29.9336', 'geonameId': 177893, 'toponymName': 'Abdullah bin Selemani', 'countryId': '895949', 'fcl': 'P', 'population': 0, 'countryCode': 'ZM', 'name': 'Abdullah bin Selemani', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '05'}, 'countryName': 'Zambia', 'fcodeName': 'populated place', 'adminName1': 'Northern Province', 'lat': '-8.9221', 'fcode': 'PPL'}]}
# {'totalResultsCount': 2643, 'geonames': [{'adminCode1': 'FL', 'lng': '-81', 'geonameId': 12217087, 'toponymName': 'South Florida', 'countryId': '6252001', 'fcl': 'L', 'population': 8260000, 'countryCode': 'US', 'name': 'South Florida', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'FL'}, 'countryName': 'United States', 'fcodeName': 'economic region', 'adminName1': 'Florida', 'lat': '26.5', 'fcode': 'RGNE'}]}
# {'totalResultsCount': 215, 'geonames': [{'adminCode1': '39', 'lng': '79.25', 'geonameId': 1444366, 'toponymName': 'State of Uttarākhand', 'countryId': '1269750', 'fcl': 'A', 'population': 10086292, 'countryCode': 'IN', 'name': 'Uttarakhand', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'UK'}, 'countryName': 'India', 'fcodeName': 'first-order administrative division', 'adminName1': 'Uttarakhand', 'lat': '30.25', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 76, 'geonames': [{'adminCode1': '00', 'lng': '35.83333', 'geonameId': 272103, 'toponymName': 'Lebanon', 'countryId': '272103', 'fcl': 'A', 'population': 6848925, 'countryCode': 'LB', 'name': 'Lebanon', 'fclName': 'country, state, region,...', 'countryName': 'Lebanon', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '33.83333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '11', 'lng': '-106.41859', 'geonameId': 12822709, 'toponymName': 'Hague', 'countryId': '6251999', 'fcl': 'A', 'population': 0, 'countryCode': 'CA', 'name': 'Hague', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'SK'}, 'countryName': 'Canada', 'fcodeName': 'second-order administrative division', 'adminName1': 'Saskatchewan', 'lat': '52.51118', 'fcode': 'ADM2'}]}
# {'totalResultsCount': 29, 'geonames': [{'adminCode1': '06', 'lng': '28.18783', 'geonameId': 964137, 'toponymName': 'Pretoria', 'countryId': '953987', 'fcl': 'P', 'population': 2112693, 'countryCode': 'ZA', 'name': 'Pretoria', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'GP'}, 'countryName': 'South Africa', 'fcodeName': 'capital of a political entity', 'adminName1': 'Gauteng', 'lat': '-25.74486', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '32.5', 'geonameId': 226074, 'toponymName': 'Republic of Uganda', 'countryId': '226074', 'fcl': 'A', 'population': 42723139, 'countryCode': 'UG', 'name': 'Uganda', 'fclName': 'country, state, region,...', 'countryName': 'Uganda', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '1.25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 123, 'geonames': [{'adminCode1': '00', 'lng': '105', 'geonameId': 1814991, 'toponymName': 'People’s Republic of China', 'countryId': '1814991', 'fcl': 'A', 'population': 1411778724, 'countryCode': 'CN', 'name': 'China', 'fclName': 'country, state, region,...', 'countryName': 'China', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '35', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '100', 'geonameId': 2017370, 'toponymName': 'Russian Federation', 'countryId': '2017370', 'fcl': 'A', 'population': 144478050, 'countryCode': 'RU', 'name': 'Russia', 'fclName': 'country, state, region,...', 'countryName': 'Russia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '60', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': '00', 'lng': '47.75', 'geonameId': 285570, 'toponymName': 'State of Kuwait', 'countryId': '285570', 'fcl': 'A', 'population': 4137309, 'countryCode': 'KW', 'name': 'Kuwait', 'fclName': 'country, state, region,...', 'countryName': 'Kuwait', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '29.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '02', 'lng': '33', 'geonameId': 1046058, 'toponymName': 'Gaza Province', 'countryId': '1036973', 'fcl': 'A', 'population': 1422460, 'countryCode': 'MZ', 'name': 'Gaza Province', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'G'}, 'countryName': 'Mozambique', 'fcodeName': 'first-order administrative division', 'adminName1': 'Gaza Province', 'lat': '-23.5', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '00', 'lng': '32', 'geonameId': 690791, 'toponymName': 'Ukraine', 'countryId': '690791', 'fcl': 'A', 'population': 44622516, 'countryCode': 'UA', 'name': 'Ukraine', 'fclName': 'country, state, region,...', 'countryName': 'Ukraine', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '49', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 160, 'geonames': [{'adminCode1': '00', 'lng': '-113.64258', 'geonameId': 6251999, 'toponymName': 'Canada', 'countryId': '6251999', 'fcl': 'A', 'population': 37058856, 'countryCode': 'CA', 'name': 'Canada', 'fclName': 'country, state, region,...', 'countryName': 'Canada', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '60.10867', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 40, 'geonames': [{'adminCode1': '10', 'lng': '-73.58781', 'geonameId': 6077243, 'toponymName': 'Montréal', 'countryId': '6251999', 'fcl': 'P', 'population': 1762949, 'countryCode': 'CA', 'name': 'Montreal', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'QC'}, 'countryName': 'Canada', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'Quebec', 'lat': '45.50884', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 304, 'geonames': [{'adminCode1': 'ENG', 'lng': '-0.75583', 'geonameId': 2642465, 'toponymName': 'Milton Keynes', 'countryId': '2635167', 'fcl': 'P', 'population': 256385, 'countryCode': 'GB', 'name': 'Milton Keynes', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'ENG'}, 'countryName': 'United Kingdom', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'England', 'lat': '52.04172', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.48347', 'geonameId': 281129, 'toponymName': 'Jabālyā', 'countryId': '6254930', 'fcl': 'P', 'population': 168568, 'countryCode': 'PS', 'name': 'Jabalia', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'Gaza Strip', 'lat': '31.5272', 'fcode': 'PPL'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': 'VA', 'lng': '-78.69724', 'geonameId': 4766212, 'toponymName': 'Israel Gap', 'countryId': '6252001', 'fcl': 'T', 'population': 0, 'countryCode': 'US', 'name': 'Israel Gap', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'VA'}, 'countryName': 'United States', 'fcodeName': 'gap', 'adminName1': 'Virginia', 'lat': '37.97986', 'fcode': 'GAP'}]}
# {'totalResultsCount': 30, 'geonames': [{'adminCode1': '08', 'lng': '-75.69812', 'geonameId': 6094817, 'toponymName': 'Ottawa', 'countryId': '6251999', 'fcl': 'P', 'population': 812129, 'countryCode': 'CA', 'name': 'Ottawa', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'ON'}, 'countryName': 'Canada', 'fcodeName': 'capital of a political entity', 'adminName1': 'Ontario', 'lat': '45.41117', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 57, 'geonames': [{'adminCode1': '00', 'lng': '30', 'geonameId': 357994, 'toponymName': 'Arab Republic of Egypt', 'countryId': '357994', 'fcl': 'A', 'population': 98423595, 'countryCode': 'EG', 'name': 'Egypt', 'fclName': 'country, state, region,...', 'countryName': 'Egypt', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '27', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.24357', 'geonameId': 281102, 'toponymName': 'Rafaḩ', 'countryId': '6254930', 'fcl': 'P', 'population': 126305, 'countryCode': 'PS', 'name': 'Rafah', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.29722', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 33, 'geonames': [{'adminCode1': '08', 'lng': '-79.39864', 'geonameId': 6167865, 'toponymName': 'Toronto', 'countryId': '6251999', 'fcl': 'P', 'population': 2600000, 'countryCode': 'CA', 'name': 'Toronto', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'ON'}, 'countryName': 'Canada', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Ontario', 'lat': '43.70643', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '01', 'lng': '-114.08529', 'geonameId': 5913490, 'toponymName': 'Calgary', 'countryId': '6251999', 'fcl': 'P', 'population': 1019942, 'countryCode': 'CA', 'name': 'Calgary', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'AB'}, 'countryName': 'Canada', 'fcodeName': 'populated place', 'adminName1': 'Alberta', 'lat': '51.05011', 'fcode': 'PPL'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '00', 'lng': '66', 'geonameId': 1149361, 'toponymName': 'Islamic Republic of Afghanistan', 'countryId': '1149361', 'fcl': 'A', 'population': 37172386, 'countryCode': 'AF', 'name': 'Afghanistan', 'fclName': 'country, state, region,...', 'countryName': 'Afghanistan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '33', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '13.33333', 'geonameId': 2782113, 'toponymName': 'Republic of Austria', 'countryId': '2782113', 'fcl': 'A', 'population': 8847037, 'countryCode': 'AT', 'name': 'Austria', 'fclName': 'country, state, region,...', 'countryName': 'Austria', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '47.33333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 27, 'geonames': [{'adminCode1': '00', 'lng': '135', 'geonameId': 2077456, 'toponymName': 'Commonwealth of Australia', 'countryId': '2077456', 'fcl': 'A', 'population': 24992369, 'countryCode': 'AU', 'name': 'Australia', 'fclName': 'country, state, region,...', 'countryName': 'Australia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '-25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '00', 'lng': '26', 'geonameId': 660013, 'toponymName': 'Republic of Finland', 'countryId': '660013', 'fcl': 'A', 'population': 5518050, 'countryCode': 'FI', 'name': 'Finland', 'fclName': 'country, state, region,...', 'countryName': 'Finland', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '64', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 19, 'geonames': [{'adminCode1': '00', 'lng': '10.5', 'geonameId': 2921044, 'toponymName': 'Federal Republic of Germany', 'countryId': '2921044', 'fcl': 'A', 'population': 82927922, 'countryCode': 'DE', 'name': 'Germany', 'fclName': 'country, state, region,...', 'countryName': 'Germany', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '51.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '00', 'lng': '12.83333', 'geonameId': 3175395, 'toponymName': 'Italian Republic', 'countryId': '3175395', 'fcl': 'A', 'population': 60431283, 'countryCode': 'IT', 'name': 'Italy', 'fclName': 'country, state, region,...', 'countryName': 'Italy', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '42.83333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 19, 'geonames': [{'adminCode1': '00', 'lng': '139.75309', 'geonameId': 1861060, 'toponymName': 'Japan', 'countryId': '1861060', 'fcl': 'A', 'population': 126529100, 'countryCode': 'JP', 'name': 'Japan', 'fclName': 'country, state, region,...', 'countryName': 'Japan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '35.68536', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 8, 'geonames': [{'adminCode1': '00', 'lng': '5.75', 'geonameId': 2750405, 'toponymName': 'Kingdom of the Netherlands', 'countryId': '2750405', 'fcl': 'A', 'population': 17231017, 'countryCode': 'NL', 'name': 'The Netherlands', 'fclName': 'country, state, region,...', 'countryName': 'The Netherlands', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '52.25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 13, 'geonames': [{'adminCode1': '00', 'lng': '-18', 'geonameId': 2629691, 'toponymName': 'Iceland', 'countryId': '2629691', 'fcl': 'A', 'population': 353574, 'countryCode': 'IS', 'name': 'Iceland', 'fclName': 'country, state, region,...', 'countryName': 'Iceland', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '65', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 18, 'geonames': [{'adminCode1': '00', 'lng': '15', 'geonameId': 2661886, 'toponymName': 'Kingdom of Sweden', 'countryId': '2661886', 'fcl': 'A', 'population': 10183175, 'countryCode': 'SE', 'name': 'Sweden', 'fclName': 'country, state, region,...', 'countryName': 'Sweden', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '62', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 15, 'geonames': [{'adminCode1': '00', 'lng': '8.01427', 'geonameId': 2658434, 'toponymName': 'Switzerland', 'countryId': '2658434', 'fcl': 'A', 'population': 8516543, 'countryCode': 'CH', 'name': 'Switzerland', 'fclName': 'country, state, region,...', 'countryName': 'Switzerland', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '47.00016', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 8, 'geonames': [{'adminCode1': '00', 'lng': '25', 'geonameId': 798549, 'toponymName': 'România', 'countryId': '798549', 'fcl': 'A', 'population': 19473936, 'countryCode': 'RO', 'name': 'Romania', 'fclName': 'country, state, region,...', 'countryName': 'Romania', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '46', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 1582, 'geonames': [{'adminCode1': 'WA', 'lng': '-120.50147', 'geonameId': 5815135, 'toponymName': 'Washington', 'countryId': '6252001', 'fcl': 'A', 'population': 6271775, 'countryCode': 'US', 'name': 'Washington', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'WA'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Washington', 'lat': '47.50012', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 108, 'geonames': [{'adminCode1': '06', 'lng': '35.21633', 'geonameId': 281184, 'toponymName': 'Jerusalem', 'countryId': '294640', 'fcl': 'P', 'population': 971800, 'countryCode': 'IL', 'name': 'Jerusalem', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'JM'}, 'countryName': 'Israel', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Jerusalem', 'lat': '31.76904', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 19, 'geonames': [{'adminCode1': 'NE', 'lng': '-96.23974', 'geonameId': 5069480, 'toponymName': 'Gretna', 'countryId': '6252001', 'fcl': 'P', 'population': 5046, 'countryCode': 'US', 'name': 'Gretna', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'NE'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'Nebraska', 'lat': '41.14083', 'fcode': 'PPL'}]}
# {'totalResultsCount': 20, 'geonames': [{'adminCode1': 'LA', 'lng': '-92.0004', 'geonameId': 4331987, 'toponymName': 'Louisiana', 'countryId': '6252001', 'fcl': 'A', 'population': 4515939, 'countryCode': 'US', 'name': 'Louisiana', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'LA'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Louisiana', 'lat': '31.00047', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 1043, 'geonames': [{'adminCode1': 'LA', 'lng': '-90.07507', 'geonameId': 4335045, 'toponymName': 'New Orleans', 'countryId': '6252001', 'fcl': 'P', 'population': 389617, 'countryCode': 'US', 'name': 'New Orleans', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'LA'}, 'countryName': 'United States', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'Louisiana', 'lat': '29.95465', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 153, 'geonames': [{'adminCode1': 'IL', 'lng': '-87.73915', 'geonameId': 4895914, 'toponymName': 'Highway Pond', 'countryId': '6252001', 'fcl': 'H', 'population': 0, 'countryCode': 'US', 'name': 'Highway Pond', 'fclName': 'stream, lake, ...', 'adminCodes1': {'ISO3166_2': 'IL'}, 'countryName': 'United States', 'fcodeName': 'lake', 'adminName1': 'Illinois', 'lat': '40.11189', 'fcode': 'LK'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=MirandaCleland&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 1332, 'geonames': [{'adminCode1': 'WE', 'lng': '35.23388', 'geonameId': 7303419, 'toponymName': 'East Jerusalem', 'countryId': '6254930', 'fcl': 'P', 'population': 428304, 'countryCode': 'PS', 'name': 'East Jerusalem', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'section of populated place', 'adminName1': 'West Bank', 'lat': '31.78336', 'fcode': 'PPLX'}]}
# {'totalResultsCount': 66, 'geonames': [{'adminCode1': 'SCT', 'lng': '-4', 'geonameId': 2638360, 'toponymName': 'Scotland', 'countryId': '2635167', 'fcl': 'A', 'population': 5436600, 'countryCode': 'GB', 'name': 'Scotland', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'SCT'}, 'countryName': 'United Kingdom', 'fcodeName': 'first-order administrative division', 'adminName1': 'Scotland', 'lat': '56', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 45, 'geonames': [{'adminCode1': '00', 'lng': '-8', 'geonameId': 2963597, 'toponymName': 'Ireland', 'countryId': '2963597', 'fcl': 'A', 'population': 4853506, 'countryCode': 'IE', 'name': 'Ireland', 'fclName': 'country, state, region,...', 'countryName': 'Ireland', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '53', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 27, 'geonames': [{'adminCode1': '00', 'lng': '10', 'geonameId': 3144096, 'toponymName': 'Kingdom of Norway', 'countryId': '3144096', 'fcl': 'A', 'population': 5314336, 'countryCode': 'NO', 'name': 'Norway', 'fclName': 'country, state, region,...', 'countryName': 'Norway', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '62', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=October7&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '00', 'lng': '38', 'geonameId': 163843, 'toponymName': 'Syrian Arab Republic', 'countryId': '163843', 'fcl': 'A', 'population': 16906283, 'countryCode': 'SY', 'name': 'Syria', 'fclName': 'country, state, region,...', 'countryName': 'Syria', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '35', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': 'WE', 'lng': '35.30086', 'geonameId': 283506, 'toponymName': 'Janīn', 'countryId': '6254930', 'fcl': 'P', 'population': 34730, 'countryCode': 'PS', 'name': 'Jenin', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'West Bank', 'lat': '32.45943', 'fcode': 'PPL'}]}
# {'totalResultsCount': 210, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.49514', 'geonameId': 281145, 'toponymName': 'Bayt Lāhyā', 'countryId': '6254930', 'fcl': 'P', 'population': 56919, 'countryCode': 'PS', 'name': 'Beit Lahia', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'Gaza Strip', 'lat': '31.5464', 'fcode': 'PPL'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': 'WE', 'lng': '35.20422', 'geonameId': 282239, 'toponymName': 'Ramallah', 'countryId': '6254930', 'fcl': 'P', 'population': 24599, 'countryCode': 'PS', 'name': 'Ramallah', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'West Bank', 'lat': '31.89964', 'fcode': 'PPL'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': 'WE', 'lng': '35.19992', 'geonameId': 285161, 'toponymName': '‘Ibwayn', 'countryId': '6254930', 'fcl': 'P', 'population': 3077, 'countryCode': 'PS', 'name': '‘Ibwayn', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'West Bank', 'lat': '32.03144', 'fcode': 'PPL'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': 'WE', 'lng': '35.06583', 'geonameId': 7870649, 'toponymName': 'Qalqilya', 'countryId': '6254930', 'fcl': 'A', 'population': 110800, 'countryCode': 'PS', 'name': 'Qalqilya Governorate', 'fclName': 'country, state, region,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'second-order administrative division', 'adminName1': 'West Bank', 'lat': '32.18583', 'fcode': 'ADM2'}]}
# {'totalResultsCount': 74, 'geonames': [{'adminCode1': 'WE', 'lng': '35.45', 'geonameId': 284899, 'toponymName': 'Jericho', 'countryId': '6254930', 'fcl': 'P', 'population': 19783, 'countryCode': 'PS', 'name': 'Jericho', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'West Bank', 'lat': '31.86667', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Yemens&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': '00', 'lng': '50.55', 'geonameId': 290291, 'toponymName': 'Kingdom of Bahrain', 'countryId': '290291', 'fcl': 'A', 'population': 1569439, 'countryCode': 'BH', 'name': 'Bahrain', 'fclName': 'country, state, region,...', 'countryName': 'Bahrain', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '26.03333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 30, 'geonames': [{'adminCode1': '00', 'lng': '10', 'geonameId': 2623032, 'toponymName': 'Kingdom of Denmark', 'countryId': '2623032', 'fcl': 'A', 'population': 5797446, 'countryCode': 'DK', 'name': 'Denmark', 'fclName': 'country, state, region,...', 'countryName': 'Denmark', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '56', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 940, 'geonames': [{'adminCode1': '00', 'lng': '174', 'geonameId': 2186224, 'toponymName': 'New Zealand', 'countryId': '2186224', 'fcl': 'A', 'population': 4885500, 'countryCode': 'NZ', 'name': 'New Zealand', 'fclName': 'country, state, region,...', 'countryName': 'New Zealand', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '-42', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 2780, 'geonames': [{'adminCode1': '00', 'lng': '127.75', 'geonameId': 1835841, 'toponymName': 'Republic of Korea', 'countryId': '1835841', 'fcl': 'A', 'population': 51635256, 'countryCode': 'KR', 'name': 'South Korea', 'fclName': 'country, state, region,...', 'countryName': 'South Korea', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '36.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '-4', 'geonameId': 2510769, 'toponymName': 'Kingdom of Spain', 'countryId': '2510769', 'fcl': 'A', 'population': 46723749, 'countryCode': 'ES', 'name': 'Spain', 'fclName': 'country, state, region,...', 'countryName': 'Spain', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '40', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '00', 'lng': '2', 'geonameId': 3017382, 'toponymName': 'Republic of France', 'countryId': '3017382', 'fcl': 'A', 'population': 66987244, 'countryCode': 'FR', 'name': 'France', 'fclName': 'country, state, region,...', 'countryName': 'France', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '46', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '00', 'lng': '4.5', 'geonameId': 2802361, 'toponymName': 'Kingdom of Belgium', 'countryId': '2802361', 'fcl': 'A', 'population': 11422068, 'countryCode': 'BE', 'name': 'Belgium', 'fclName': 'country, state, region,...', 'countryName': 'Belgium', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '50.75', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 15, 'geonames': [{'adminCode1': '00', 'lng': '15', 'geonameId': 3077311, 'toponymName': 'Czechia', 'countryId': '3077311', 'fcl': 'A', 'population': 10625695, 'countryCode': 'CZ', 'name': 'Czechia', 'fclName': 'country, state, region,...', 'countryName': 'Czechia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '49.75', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 4, 'geonames': [{'adminCode1': '00', 'lng': '20', 'geonameId': 719819, 'toponymName': 'Hungary', 'countryId': '719819', 'fcl': 'A', 'population': 9768785, 'countryCode': 'HU', 'name': 'Hungary', 'fclName': 'country, state, region,...', 'countryName': 'Hungary', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '47', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 210, 'geonames': [{'adminCode1': '16', 'lng': '13.41053', 'geonameId': 2950159, 'toponymName': 'Berlin', 'countryId': '2921044', 'fcl': 'P', 'population': 3426354, 'countryCode': 'DE', 'name': 'Berlin', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'BE'}, 'countryName': 'Germany', 'fcodeName': 'capital of a political entity', 'adminName1': 'State of Berlin', 'lat': '52.52437', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 109, 'geonames': [{'adminCode1': '11', 'lng': '2.3488', 'geonameId': 2988507, 'toponymName': 'Paris', 'countryId': '3017382', 'fcl': 'P', 'population': 2138551, 'countryCode': 'FR', 'name': 'Paris', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'IDF'}, 'countryName': 'France', 'fcodeName': 'capital of a political entity', 'adminName1': 'Île-de-France', 'lat': '48.85341', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '00', 'lng': '15', 'geonameId': 3190538, 'toponymName': 'Republic of Slovenia', 'countryId': '3190538', 'fcl': 'A', 'population': 2067372, 'countryCode': 'SI', 'name': 'Slovenia', 'fclName': 'country, state, region,...', 'countryName': 'Slovenia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '46.08333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 17, 'geonames': [{'adminCode1': 'BRU', 'lng': '4.34878', 'geonameId': 2800866, 'toponymName': 'Brussels', 'countryId': '2802361', 'fcl': 'P', 'population': 1019022, 'countryCode': 'BE', 'name': 'Brussels', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'BRU'}, 'countryName': 'Belgium', 'fcodeName': 'capital of a political entity', 'adminName1': 'Brussels Capital', 'lat': '50.85045', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=carogennez&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Belgiums&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 34, 'geonames': [{'adminCode1': 'VLG', 'lng': '4.5', 'geonameId': 3337388, 'toponymName': 'Flanders', 'countryId': '2802361', 'fcl': 'A', 'population': 6821770, 'countryCode': 'BE', 'name': 'Flanders', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'VLG'}, 'countryName': 'Belgium', 'fcodeName': 'first-order administrative division', 'adminName1': 'Flanders', 'lat': '51', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': 'WAL', 'lng': '4.75', 'geonameId': 3337387, 'toponymName': 'Wallonia', 'countryId': '2802361', 'fcl': 'A', 'population': 3692283, 'countryCode': 'BE', 'name': 'Wallonia', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'WAL'}, 'countryName': 'Belgium', 'fcodeName': 'first-order administrative division', 'adminName1': 'Wallonia', 'lat': '50.5', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 123, 'geonames': [{'adminCode1': '04', 'lng': '34.94483', 'geonameId': 295225, 'toponymName': '‘En Ayyala', 'countryId': '294640', 'fcl': 'P', 'population': 1150, 'countryCode': 'IL', 'name': 'Ein Ayala', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'HA'}, 'countryName': 'Israel', 'fcodeName': 'populated place', 'adminName1': 'Haifa', 'lat': '32.62899', 'fcode': 'PPL'}]}
# {'totalResultsCount': 13, 'geonames': [{'adminCode1': 'BS', 'lng': '7.57327', 'geonameId': 2661604, 'toponymName': 'Basel', 'countryId': '2658434', 'fcl': 'P', 'population': 164488, 'countryCode': 'CH', 'name': 'Basel', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'BS'}, 'countryName': 'Switzerland', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Basel-City', 'lat': '47.55839', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': '04', 'lng': '34.98302', 'geonameId': 293988, 'toponymName': '‘Ofer', 'countryId': '294640', 'fcl': 'P', 'population': 0, 'countryCode': 'IL', 'name': 'Ofer', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'HA'}, 'countryName': 'Israel', 'fcodeName': 'populated place', 'adminName1': 'Haifa', 'lat': '32.62257', 'fcode': 'PPL'}]}
# {'totalResultsCount': 730, 'geonames': [{'adminCode1': 'OR', 'lng': '-117.0543', 'geonameId': 5734089, 'toponymName': 'Jordan Valley', 'countryId': '6252001', 'fcl': 'P', 'population': 174, 'countryCode': 'US', 'name': 'Jordan Valley', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'OR'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'Oregon', 'lat': '42.97404', 'fcode': 'PPL'}]}
# {'totalResultsCount': 57, 'geonames': [{'adminCode1': '01', 'lng': '-54.61622', 'geonameId': 11849285, 'toponymName': 'Area 5', 'countryId': '3437598', 'fcl': 'A', 'population': 0, 'countryCode': 'PY', 'name': 'Area 5', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': '10'}, 'countryName': 'Paraguay', 'fcodeName': 'third-order administrative division', 'adminName1': 'Alto Paraná Department', 'lat': '-25.55132', 'fcode': 'ADM3'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Kadris&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=alJiftlik&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '15', 'lng': '42.96643', 'geonameId': 96761, 'toponymName': 'Al Fārisīyah', 'countryId': '99237', 'fcl': 'P', 'population': 0, 'countryCode': 'IQ', 'name': 'Al Fārisīyah', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'NI'}, 'countryName': 'Iraq', 'fcodeName': 'populated place', 'adminName1': 'Nineveh', 'lat': '35.95584', 'fcode': 'PPL'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': '08', 'lng': '37.3558', 'geonameId': 167422, 'toponymName': 'Tall Makḩūl', 'countryId': '163843', 'fcl': 'T', 'population': 0, 'countryCode': 'SY', 'name': 'Tall Makḩūl', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'RD'}, 'countryName': 'Syria', 'fcodeName': 'hill', 'adminName1': 'Rif-dimashq', 'lat': '33.40788', 'fcode': 'HLL'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': 'WE', 'lng': '35.36989', 'geonameId': 281581, 'toponymName': 'Ţūbās', 'countryId': '6254930', 'fcl': 'P', 'population': 15591, 'countryCode': 'PS', 'name': 'Ţūbās', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'West Bank', 'lat': '32.32091', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 873, 'geonames': [{'adminCode1': 'WE', 'lng': '35.51239', 'geonameId': 281421, 'toponymName': 'Umm Zūqah', 'countryId': '6254930', 'fcl': 'T', 'population': 0, 'countryCode': 'PS', 'name': 'Umm Zūqah', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'hill', 'adminName1': 'West Bank', 'lat': '32.27071', 'fcode': 'HLL'}]}
# {'totalResultsCount': 79, 'geonames': [{'adminCode1': '04', 'lng': '-71.535', 'geonameId': 3947322, 'toponymName': 'Arequipa', 'countryId': '3932488', 'fcl': 'P', 'population': 1008290, 'countryCode': 'PE', 'name': 'Arequipa', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'ARE'}, 'countryName': 'Peru', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Arequipa', 'lat': '-16.39889', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '04', 'lng': '35.50157', 'geonameId': 276781, 'toponymName': 'Beirut', 'countryId': '272103', 'fcl': 'P', 'population': 1916100, 'countryCode': 'LB', 'name': 'Beirut', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'BA'}, 'countryName': 'Lebanon', 'fcodeName': 'capital of a political entity', 'adminName1': 'Beyrouth', 'lat': '33.89332', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 425, 'geonames': [{'adminCode1': 'WA', 'lng': '-120.50147', 'geonameId': 5815135, 'toponymName': 'Washington', 'countryId': '6252001', 'fcl': 'A', 'population': 6271775, 'countryCode': 'US', 'name': 'Washington', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'WA'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Washington', 'lat': '47.50012', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 16, 'geonames': [{'adminCode1': '29', 'lng': '57.07879', 'geonameId': 128234, 'toponymName': 'Kerman', 'countryId': '130758', 'fcl': 'P', 'population': 577514, 'countryCode': 'IR', 'name': 'Kerman', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '08'}, 'countryName': 'Iran', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Kerman', 'lat': '30.28321', 'fcode': 'PPLA'}]}
# ...
# {'totalResultsCount': 488, 'geonames': [{'adminCode1': '05', 'lng': '-61.51889', 'geonameId': 3573890, 'toponymName': 'Port of Spain', 'countryId': '3573591', 'fcl': 'P', 'population': 49031, 'countryCode': 'TT', 'name': 'Port of Spain', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'POS'}, 'countryName': 'Trinidad and Tobago', 'fcodeName': 'capital of a political entity', 'adminName1': 'Port of Spain', 'lat': '10.66668', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 32, 'geonames': [{'adminCode1': '02', 'lng': '-123.42716', 'geonameId': 6296331, 'toponymName': 'Victoria International Airport', 'countryId': '6251999', 'fcl': 'S', 'population': 0, 'countryCode': 'CA', 'name': 'Victoria International Airport', 'fclName': 'spot, building, farm', 'adminCodes1': {'ISO3166_2': 'BC'}, 'countryName': 'Canada', 'fcodeName': 'airport', 'adminName1': 'British Columbia', 'lat': '48.64721', 'fcode': 'AIRP'}]}
# {'totalResultsCount': 48, 'geonames': [{'adminCode1': '07', 'lng': '144.96332', 'geonameId': 2158177, 'toponymName': 'Melbourne', 'countryId': '2077456', 'fcl': 'P', 'population': 4917750, 'countryCode': 'AU', 'name': 'Melbourne', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'VIC'}, 'countryName': 'Australia', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Victoria', 'lat': '-37.814', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 298, 'geonames': [{'adminCode1': '07', 'lng': '144.91747', 'geonameId': 8215787, 'toponymName': 'Sandridge Beach', 'countryId': '2077456', 'fcl': 'T', 'population': 0, 'countryCode': 'AU', 'name': 'Sandridge Beach', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'VIC'}, 'countryName': 'Australia', 'fcodeName': 'beach', 'adminName1': 'Victoria', 'lat': '-37.83931', 'fcode': 'BCH'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': 'MI', 'lng': '-83.54131', 'geonameId': 5015721, 'toponymName': 'Zim Lake', 'countryId': '6252001', 'fcl': 'H', 'population': 0, 'countryCode': 'US', 'name': 'Zim Lake', 'fclName': 'stream, lake, ...', 'adminCodes1': {'ISO3166_2': 'MI'}, 'countryName': 'United States', 'fcodeName': 'lake', 'adminName1': 'Michigan', 'lat': '45.06873', 'fcode': 'LK'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Australias&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 499, 'geonames': [{'adminCode1': '50', 'lng': '7.0134', 'geonameId': 2324774, 'toponymName': 'Port Harcourt', 'countryId': '2328926', 'fcl': 'P', 'population': 2120000, 'countryCode': 'NG', 'name': 'Port Harcourt', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'RI'}, 'countryName': 'Nigeria', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Rivers State', 'lat': '4.77742', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 24, 'geonames': [{'adminCode1': '02', 'lng': '151.20732', 'geonameId': 2147714, 'toponymName': 'Sydney', 'countryId': '2077456', 'fcl': 'P', 'population': 5231147, 'countryCode': 'AU', 'name': 'Sydney', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'NSW'}, 'countryName': 'Australia', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'New South Wales', 'lat': '-33.86785', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '04', 'lng': '153.02809', 'geonameId': 2174003, 'toponymName': 'Brisbane', 'countryId': '2077456', 'fcl': 'P', 'population': 2582007, 'countryCode': 'AU', 'name': 'Brisbane', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'QLD'}, 'countryName': 'Australia', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Queensland', 'lat': '-27.46794', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=northGaza&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Palestine_UN&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 28, 'geonames': [{'adminCode1': '25', 'lng': '44', 'geonameId': 70222, 'toponymName': 'Muḩāfaz̧at Ta‘izz', 'countryId': '69543', 'fcl': 'A', 'population': 2613947, 'countryCode': 'YE', 'name': 'Ta‘izz', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'TA'}, 'countryName': 'Yemen', 'fcodeName': 'first-order administrative division', 'adminName1': 'Ta‘izz', 'lat': '13.5', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '11', 'lng': '42.07078', 'geonameId': 12546159, 'toponymName': 'Al Bayḑā’', 'countryId': '102358', 'fcl': 'P', 'population': 0, 'countryCode': 'SA', 'name': 'Al Bayḑā’', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '14'}, 'countryName': 'Saudi Arabia', 'fcodeName': 'populated place', 'adminName1': "'Asir Region", 'lat': '18.86139', 'fcode': 'PPL'}]}
# {'totalResultsCount': 19, 'geonames': [{'adminCode1': '14', 'lng': '90.28327', 'geonameId': 10274676, 'toponymName': 'Dena', 'countryId': '1814991', 'fcl': 'L', 'population': 0, 'countryCode': 'CN', 'name': 'Dena', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'XZ'}, 'countryName': 'China', 'fcodeName': 'grazing area', 'adminName1': 'Tibet', 'lat': '28.44289', 'fcode': 'GRAZ'}]}
# {'totalResultsCount': 233, 'geonames': [{'adminCode1': 'CA', 'lng': '-122.2708', 'geonameId': 5378538, 'toponymName': 'Oakland', 'countryId': '6252001', 'fcl': 'P', 'population': 419267, 'countryCode': 'US', 'name': 'Oakland', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'CA'}, 'countryName': 'United States', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'California', 'lat': '37.80437', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 31, 'geonames': [{'adminCode1': 'ESYE42', 'lng': '25.3976', 'geonameId': 265396, 'toponymName': 'Akrotíri', 'countryId': '390903', 'fcl': 'P', 'population': 0, 'countryCode': 'GR', 'name': 'Akrotíri', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'L'}, 'countryName': 'Greece', 'fcodeName': 'populated place', 'adminName1': 'South Aegean', 'lat': '36.35796', 'fcode': 'PPL'}]}
# {'totalResultsCount': 4, 'geonames': [{'adminCode1': '05', 'lng': '33.03794', 'geonameId': 146384, 'toponymName': 'Limassol', 'countryId': '146669', 'fcl': 'P', 'population': 154000, 'countryCode': 'CY', 'name': 'Limassol', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '02'}, 'countryName': 'Cyprus', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Limassol', 'lat': '34.68406', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Pashias&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': 'MD', 'lng': '-77.33137', 'geonameId': 4359245, 'toponymName': 'Israel Creek Cemetery', 'countryId': '6252001', 'fcl': 'S', 'population': 0, 'countryCode': 'US', 'name': 'Israel Creek Cemetery', 'fclName': 'spot, building, farm', 'adminCodes1': {'ISO3166_2': 'MD'}, 'countryName': 'United States', 'fcodeName': 'cemetery', 'adminName1': 'Maryland', 'lat': '39.49343', 'fcode': 'CMTY'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '00', 'lng': '35', 'geonameId': 323835, 'toponymName': 'Anatolia', 'countryId': '298795', 'fcl': 'L', 'population': 0, 'countryCode': 'TR', 'name': 'Anatolia', 'fclName': 'parks,area, ...', 'countryName': 'Türkiye', 'fcodeName': 'region', 'adminName1': '', 'lat': '39', 'fcode': 'RGN'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': '01', 'lng': '34.88098', 'geonameId': 294063, 'toponymName': 'Nevatim', 'countryId': '294640', 'fcl': 'P', 'population': 996, 'countryCode': 'IL', 'name': 'Nevatim', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'D'}, 'countryName': 'Israel', 'fcodeName': 'populated place', 'adminName1': 'Southern District', 'lat': '31.22417', 'fcode': 'PPL'}]}
# {'totalResultsCount': 467, 'geonames': [{'adminCode1': '02', 'lng': '34.88657', 'geonameId': 390285, 'toponymName': 'Ben Gurion Airport', 'countryId': '294640', 'fcl': 'S', 'population': 0, 'countryCode': 'IL', 'name': 'Ben Gurion Airport', 'fclName': 'spot, building, farm', 'adminCodes1': {'ISO3166_2': 'M'}, 'countryName': 'Israel', 'fcodeName': 'airport', 'adminName1': 'Central District', 'lat': '32.01361', 'fcode': 'AIRP'}]}
# {'totalResultsCount': 233, 'geonames': [{'adminCode1': '00', 'lng': '121', 'geonameId': 1668284, 'toponymName': 'Taiwan', 'countryId': '1668284', 'fcl': 'A', 'population': 23451837, 'countryCode': 'TW', 'name': 'Taiwan', 'fclName': 'country, state, region,...', 'countryName': 'Taiwan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '24', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': '00', 'lng': '33.775', 'geonameId': 8306814, 'toponymName': 'Dhekelia', 'countryId': '2635167', 'fcl': 'A', 'population': 0, 'countryCode': 'GB', 'name': 'Dhekelia', 'fclName': 'country, state, region,...', 'countryName': 'United Kingdom', 'fcodeName': 'zone', 'adminName1': '', 'lat': '35.01667', 'fcode': 'ZN'}]}
# {'totalResultsCount': 53, 'geonames': [{'adminCode1': '00', 'lng': '-98.5', 'geonameId': 6252001, 'toponymName': 'United States', 'countryId': '6252001', 'fcl': 'A', 'population': 327167434, 'countryCode': 'US', 'name': 'United States', 'fclName': 'country, state, region,...', 'countryName': 'United States', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '39.76', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 26, 'geonames': [{'adminCode1': 'TX', 'lng': '-94.97187', 'geonameId': 4705700, 'toponymName': 'League of Women Voters Park', 'countryId': '6252001', 'fcl': 'L', 'population': 0, 'countryCode': 'US', 'name': 'League of Women Voters Park', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'TX'}, 'countryName': 'United States', 'fcodeName': 'park', 'adminName1': 'Texas', 'lat': '29.75634', 'fcode': 'PRK'}]}
# {'totalResultsCount': 168, 'geonames': [{'adminCode1': 'TX', 'lng': '-95.65255', 'geonameId': 12213829, 'toponymName': 'Palestine, TX Micro Area', 'countryId': '6252001', 'fcl': 'L', 'population': 60000, 'countryCode': 'US', 'name': 'Palestine, TX', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'TX'}, 'countryName': 'United States', 'fcodeName': 'economic region', 'adminName1': 'Texas', 'lat': '31.81333', 'fcode': 'RGNE'}]}
# {'totalResultsCount': 170, 'geonames': [{'adminCode1': '01', 'lng': '54.65114', 'geonameId': 6300092, 'toponymName': 'Abu Dhabi International Airport', 'countryId': '290557', 'fcl': 'S', 'population': 0, 'countryCode': 'AE', 'name': 'Abu Dhabi International Airport', 'fclName': 'spot, building, farm', 'adminCodes1': {'ISO3166_2': 'AZ'}, 'countryName': 'United Arab Emirates', 'fcodeName': 'airport', 'adminName1': 'Abu Dhabi', 'lat': '24.43297', 'fcode': 'AIRP'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=alSaftawi&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=AlFukhari&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '20', 'lng': '37.3146', 'geonameId': 12603577, 'toponymName': 'Al Amal', 'countryId': '102358', 'fcl': 'L', 'population': 0, 'countryCode': 'SA', 'name': 'Al Amal', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': '12'}, 'countryName': 'Saudi Arabia', 'fcodeName': 'locality', 'adminName1': 'Al Jawf Region', 'lat': '31.39064', 'fcode': 'LCTY'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=alNasser&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=alKatiba&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 1342, 'geonames': [{'adminCode1': '08', 'lng': '112.67913', 'geonameId': 11184549, 'toponymName': 'Harun Thohir Airport', 'countryId': '1643084', 'fcl': 'S', 'population': 0, 'countryCode': 'ID', 'name': 'Harun Thohir Airport', 'fclName': 'spot, building, farm', 'adminCodes1': {'ISO3166_2': 'JI'}, 'countryName': 'Indonesia', 'fcodeName': 'airport', 'adminName1': 'East Java', 'lat': '-5.72373', 'fcode': 'AIRP'}]}
# {'totalResultsCount': 114, 'geonames': [{'adminCode1': '17', 'lng': '96.24285', 'geonameId': 1312305, 'toponymName': 'Mahuya Reserved Forest', 'countryId': '1327865', 'fcl': 'L', 'population': 0, 'countryCode': 'MM', 'name': 'Mahuya Reserved Forest', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': '06'}, 'countryName': 'Myanmar', 'fcodeName': 'forest reserve', 'adminName1': 'Yangon', 'lat': '17.41642', 'fcode': 'RESF'}]}
# {'totalResultsCount': 976, 'geonames': [{'adminCode1': '11', 'lng': '18.42322', 'geonameId': 3369157, 'toponymName': 'Cape Town', 'countryId': '953987', 'fcl': 'P', 'population': 4710000, 'countryCode': 'ZA', 'name': 'Cape Town', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'WC'}, 'countryName': 'South Africa', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Western Cape', 'lat': '-33.92584', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 1310, 'geonames': [{'adminCode1': 'KS', 'lng': '-97.94033', 'geonameId': 4279645, 'toponymName': 'South Hutchinson', 'countryId': '6252001', 'fcl': 'P', 'population': 2556, 'countryCode': 'US', 'name': 'South Hutchinson', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'KS'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'Kansas', 'lat': '38.02807', 'fcode': 'PPL'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Africa4Palestine&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 471, 'geonames': [{'adminCode1': 'PA', 'lng': '-79.91382', 'geonameId': 12217723, 'toponymName': 'Western Pennsylvania', 'countryId': '6252001', 'fcl': 'L', 'population': 3810000, 'countryCode': 'US', 'name': 'Western Pennsylvania', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'PA'}, 'countryName': 'United States', 'fcodeName': 'region', 'adminName1': 'Pennsylvania', 'lat': '40.64575', 'fcode': 'RGN'}]}
# {'totalResultsCount': 5, 'geonames': [{'adminCode1': '00', 'lng': '35.18388', 'geonameId': 8068847, 'toponymName': 'Al Ittişālāt', 'countryId': '6254930', 'fcl': 'S', 'population': 0, 'countryCode': 'PS', 'name': 'Al Ittişālāt', 'fclName': 'spot, building, farm', 'countryName': 'Palestine', 'fcodeName': 'building(s)', 'adminName1': '', 'lat': '32.08712', 'fcode': 'BLDG'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Jawwal&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 202, 'geonames': [{'adminCode1': 'OR', 'lng': '-123.0351', 'geonameId': 5750162, 'toponymName': 'Salem', 'countryId': '6252001', 'fcl': 'P', 'population': 164549, 'countryCode': 'US', 'name': 'Salem', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'OR'}, 'countryName': 'United States', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Oregon', 'lat': '44.9429', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 28, 'geonames': [{'adminCode1': '17', 'lng': '12.56553', 'geonameId': 2618425, 'toponymName': 'Copenhagen', 'countryId': '2623032', 'fcl': 'P', 'population': 1153615, 'countryCode': 'DK', 'name': 'Copenhagen', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '84'}, 'countryName': 'Denmark', 'fcodeName': 'capital of a political entity', 'adminName1': 'Capital Region', 'lat': '55.67594', 'fcode': 'PPLC'}]}

# %% [markdown]
# Ex 4a

# %%
# Importing the necessary library
import plotly.express as px
import pandas as pd

# Load frequency data
freq_df = pd.read_csv("regex_counts.tsv", sep="\t")

# Load geocoded coordinates
geo_df = pd.read_csv("ner_gazetteer.tsv", sep="\t")

# The expected merge column is 'place'
# Check if geo_df has 'name' instead of 'place'
if 'name' in geo_df.columns and 'place' not in geo_df.columns:
    geo_df.rename(columns={'name': 'place'}, inplace=True)

# merge the two tables, using the common column “asciiname”
merged_df = pd.merge(geo_df, freq_df, on="place")


# Plotly animated geo map
fig = px.scatter_geo(
    merged_df,
    lat="latitude",
    lon="longitude",
    size="count",
    color="place",
    hover_name="place",
    animation_frame="month",
    projection="natural earth",
    size_max=20
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="846ad736-0abe-4eb3-9f86-01a3a5f7b68b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("846ad736-0abe-4eb3-9f86-01a3a5f7b68b")) {                    Plotly.newPlot(                        "846ad736-0abe-4eb3-9f86-01a3a5f7b68b",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Gaza Strip\u003cbr\u003emonth=2024-02\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Gaza Strip","Gaza Strip"],"lat":[31.50161,31.50161],"legendgroup":"Gaza Strip","lon":[34.46672,34.46672],"marker":{"color":"#636efa","size":[1896,1896],"sizemode":"area","sizeref":11.42,"symbol":"circle"},"mode":"markers","name":"Gaza Strip","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Gaza\u003cbr\u003emonth=2024-02\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Gaza","Gaza"],"lat":[31.50161,31.50161],"legendgroup":"Gaza","lon":[34.46672,34.46672],"marker":{"color":"#EF553B","size":[1896,1896],"sizemode":"area","sizeref":11.42,"symbol":"circle"},"mode":"markers","name":"Gaza","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Gaza City\u003cbr\u003emonth=2024-02\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Gaza City","Gaza City"],"lat":[31.50161,31.50161],"legendgroup":"Gaza City","lon":[34.46672,34.46672],"marker":{"color":"#00cc96","size":[1904,1904],"sizemode":"area","sizeref":11.42,"symbol":"circle"},"mode":"markers","name":"Gaza City","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Jabalia\u003cbr\u003emonth=2024-02\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Jabalia","Jabalia"],"lat":[31.5272,31.5272],"legendgroup":"Jabalia","lon":[34.48347,34.48347],"marker":{"color":"#ab63fa","size":[7,7],"sizemode":"area","sizeref":11.42,"symbol":"circle"},"mode":"markers","name":"Jabalia","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Rafah\u003cbr\u003emonth=2024-02\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Rafah","Rafah"],"lat":[31.29722,31.29722],"legendgroup":"Rafah","lon":[34.24357,34.24357],"marker":{"color":"#FFA15A","size":[498,498],"sizemode":"area","sizeref":11.42,"symbol":"circle"},"mode":"markers","name":"Rafah","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Nuseirat\u003cbr\u003emonth=2024-02\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Nuseirat","Nuseirat"],"lat":[31.44861,31.44861],"legendgroup":"Nuseirat","lon":[34.3925,34.3925],"marker":{"color":"#19d3f3","size":[6,6],"sizemode":"area","sizeref":11.42,"symbol":"circle"},"mode":"markers","name":"Nuseirat","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\ ...

# %% [markdown]
# Ex 4b

# %%
# Load NER frequency data (January 2024 only)
ner_df = pd.read_csv("ner_counts.tsv", sep="\t")

# Load geocoded coordinates
geo_df = pd.read_csv("ner_gazetteer.tsv", sep="\t")

# Merge the two tables using the common column "place"
merged_df = pd.merge(ner_df, geo_df, on="place")

merged_df['count'] = pd.to_numeric(merged_df['count'], errors='coerce')

# Drop rows with NaN values in 'count', 'latitude', or 'longitude'
merged_df = merged_df.dropna(subset=['count', 'latitude', 'longitude'])

# Create static and interactive maps
fig = px.scatter_geo(
    merged_df,
    lat="latitude",
    lon="longitude",
    size="count",
    color="place",
    hover_name="place",
    projection="natural earth",
    size_max=20,
    title="NER Place Frequencies - January 2024"
)

# Save interactive HTML map
fig.write_html("ner_map.html")

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="149e90af-4d17-48fb-9aba-74ec4f0c11f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("149e90af-4d17-48fb-9aba-74ec4f0c11f9")) {                    Plotly.newPlot(                        "149e90af-4d17-48fb-9aba-74ec4f0c11f9",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=West Bank\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["West Bank","West Bank"],"lat":[19.38197,19.38197],"legendgroup":"West Bank","lon":[-81.39281,-81.39281],"marker":{"color":"#636efa","size":[160.0,160.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"West Bank","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Dura\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Dura","Dura"],"lat":[28.8,28.8],"legendgroup":"Dura","lon":[49.23333,49.23333],"marker":{"color":"#EF553B","size":[2.0,2.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"Dura","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Hebron\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Hebron","Hebron"],"lat":[31.52935,31.52935],"legendgroup":"Hebron","lon":[35.0938,35.0938],"marker":{"color":"#00cc96","size":[10.0,10.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"Hebron","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Tulkarem\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Tulkarem","Tulkarem"],"lat":[32.31156,32.31156],"legendgroup":"Tulkarem","lon":[35.0269,35.0269],"marker":{"color":"#ab63fa","size":[2.0,2.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"Tulkarem","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Gaza Strip\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Gaza Strip","Gaza Strip"],"lat":[31.50161,31.50161],"legendgroup":"Gaza Strip","lon":[34.46672,34.46672],"marker":{"color":"#FFA15A","size":[156.0,156.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"Gaza Strip","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Israel\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Israel","Israel"],"lat":[31.5,31.5],"legendgroup":"Israel","lon":[34.75,34.75],"marker":{"color":"#19d3f3","size":[1594.0,1594.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"Israel","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Nablus\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e ...
