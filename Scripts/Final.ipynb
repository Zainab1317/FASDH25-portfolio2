# %% [markdown]
# Ex 2A

# %%
# !git clone https://github.com/Zainab1317/FASDH25-portfolio2.git
# Out:
# Cloning into 'FASDH25-portfolio2'...
# remote: Enumerating objects: 4409, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 4409 (delta 12), reused 7 (delta 3), pack-reused 4379 (from 2)
# Receiving objects: 100% (4409/4409), 19.31 MiB | 18.17 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
import re #imports regular expression to find text patterns
import os # imports to enable interaction with file system
import pandas as pd #imports to hadle tabular data and export tsv file

def write_tsv(rows, column_list, path): # function writes a list of data rows intotsv file using panadas
    df = pd.DataFrame(rows, columns=column_list) #list of rows is converted into panads DataFrame
    df.to_csv(path, sep="\t", index=False) #DataFrame is written into tsv

#Setup paths
repo_path = "FASDH25-portfolio2" #define path to repository
folder = "FASDH25-portfolio2/articles" #defining folder where articles are present
gazetteer_path = "FASDH25-portfolio2/gazetteers/geonames_gaza_selection.tsv" #define path and load gazetteer from the tsv file having place names and alternate names

#Read Gazetteer File
with open(gazetteer_path, encoding="utf-8") as file:
    data = file.read()

patterns = {} #an empty dictionary is created for each place names and a count for matches
rows = data.split("\n") #split gazetteer data in new lines to get eeach row on file

for row in rows[1:]:  # Skip header because the pattern starts from next row
    columns = row.split("\t") #seprates each column in tsv by tabs
    asciiname = columns[0] #ensures that first column has names for the place
    name_variants = [asciiname] #lists name variants consisting of the standard name
    alternate_names = columns[5].strip() #gets the alternate names from the 6th column which is counted as the 5th column, if present

    if alternate_names:
      alternate_list = alternate_names.split(",") #splits the alternate names with comma and gets list of other names
      for name in alternate_list: #loops through each alternate name in the list
        name_variants.append(name.strip()) #.strip will remove whitespace from alternate names and .append will add alternate names to the list if prenest

# build a regex pattern that will work to find all names and match diffrent varianats of the place names aswell
    regex_pattern = "|".join (re.escape(name) for name in name_variants) #using re.escape to escape any special characters in place names and "|" is used for alternation
    patterns[asciiname] = {"pattern": regex_pattern, "count": 0} #includes all names and their variants with numbers

mentions_per_month = {} #dictionary stores how many times each name was mentioned
war_start_date = "2023-10-07" #set the date to filt

for filename in os.listdir(folder):
    date_str = filename.split("_")[0]
    if date_str < war_start_date:
        continue

    file_path = f"{folder}/{filename}"
    with open(file_path, encoding="utf-8") as file:
        text = file.read()

    for place in patterns:
        pattern = patterns[place]["pattern"]
        matches = re.findall(pattern, text, re.IGNORECASE)
        count = len(matches)
        patterns[place]["count"] += count

        month_str = date_str[:7]

        if place not in mentions_per_month:
            mentions_per_month[place] = {}
        if month_str not in mentions_per_month[place]:
            mentions_per_month[place][month_str] = 0

        mentions_per_month[place][month_str] += count

#Print Output
for place in mentions_per_month:
    print(f'"{place}": {{')
    month_list = list(mentions_per_month[place].keys())
    for month in month_list:
        count = mentions_per_month[place][month]
        if month != month_list[-1]:
            print(f'    "{month}": {count},')
        else:
            print(f'    "{month}": {count}')
    print("},")

#Prepare Rows and Write TSV
output_rows = []
for place in mentions_per_month:
    for month in mentions_per_month[place]:
        count = mentions_per_month[place][month]
        output_rows.append((place, month, count))

write_tsv(output_rows, ["place", "month", "count"], "regex_counts.tsv")
# Out:
# "Jabalya": {
#     "2023-10": 37,
#     "2023-12": 46,
#     "2024-02": 7,
#     "2024-04": 3,
#     "2024-03": 8,
#     "2024-01": 12,
#     "2023-11": 103
# },
# "Bayt Lahya": {
#     "2023-10": 11,
#     "2023-12": 8,
#     "2024-02": 3,
#     "2024-04": 2,
#     "2024-03": 1,
#     "2024-01": 2,
#     "2023-11": 14
# },
# "Jabalia": {
#     "2023-10": 33,
#     "2023-12": 44,
#     "2024-02": 7,
#     "2024-04": 2,
#     "2024-03": 8,
#     "2024-01": 12,
#     "2023-11": 102
# },
# "Bayt Hanun": {
#     "2023-10": 19,
#     "2023-12": 4,
#     "2024-02": 3,
#     "2024-04": 10,
#     "2024-03": 7,
#     "2024-01": 1,
#     "2023-11": 17
# },
# "Khan Younis": {
#     "2023-10": 74,
#     "2023-12": 173,
#     "2024-02": 63,
#     "2024-04": 25,
#     "2024-03": 40,
#     "2024-01": 74,
#     "2023-11": 132
# },
# "An Nusayrat": {
#     "2023-10": 22,
#     "2023-12": 26,
#     "2024-02": 6,
#     "2024-04": 8,
#     "2024-03": 9,
#     "2024-01": 11,
#     "2023-11": 16
# },
# "Al Burayj": {
#     "2023-10": 3,
#     "2023-12": 17,
#     "2024-02": 2,
#     "2024-04": 0,
#     "2024-03": 5,
#     "2024-01": 5,
#     "2023-11": 15
# },
# "Rafah": {
#     "2023-10": 182,
#     "2023-12": 201,
#     "2024-02": 498,
#     "2024-04": 81,
#     "2024-03": 253,
#     "2024-01": 41,
#     "2023-11": 150
# },
# "Bani Suhayla": {
#     "2023-10": 1,
#     "2023-12": 1,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 2,
#     "2023-11": 1
# },
# "Nuseirat": {
#     "2023-10": 22,
#     "2023-12": 26,
#     "2024-02": 6,
#     "2024-04": 8,
#     "2024-03": 9,
#     "2024-01": 11,
#     "2023-11": 16
# },
# "Bureij": {
#     "2023-10": 3,
#     "2023-12": 17,
#     "2024-02": 2,
#     "2024-04": 0,
#     "2024-03": 5,
#     "2024-01": 5,
#     "2023-11": 15
# },
# "Al Qararah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 1,
#     "2024-01": 1,
#     "2023-11": 1
# },
# "Abasan al Kabirah": {
#     "2023-10": 4,
#     "2023-12": 4,
#     "2024-02": 1,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 5
# },
# "Az Zuwaydah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Maghazi": {
#     "2023-10": 15,
#     "2023-12": 49,
#     "2024-02": 2,
#     "2024-04": 0,
#     "2024-03": 3,
#     "2024-01": 9,
#     "2023-11": 28
# },
# "Shukat as Sufi": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Khuza'ah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Mughraqah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Deir El-Balah": {
#     "2023-10": 38,
#     "2023-12": 45,
#     "2024-02": 31,
#     "2024-04": 12,
#     "2024-03": 30,
#     "2024-01": 19,
#     "2023-11": 51
# },
# "An Nasr": {
#     "2023-10": 12,
#     "2023-12": 3,
#     "2024-02": 6,
#     "2024-04": 3,
#     "2024-03": 3,
#     "2024-01": 14,
#     "2023-11": 25
# },
# "Abasan al Jadidah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Fukhkhari": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Wadi as Salqa": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Juhr ad Dik": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Umm an Nasr": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Musaddar": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Mawasi": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 1,
#     "2024-01": 1,
#     "2023-11": 0
# },
# "Al-Shifa Hospital": {
#     "2023-10": 31,
#     "2023-12": 23,
#     "2024-02": 15,
#     "2024-04": 13,
#     "2024-03": 32,
#     "2024-01": 3,
#     "2023-11": 245
# },
# "Umm Jarrah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Musabbih": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Ard Rafah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Qubbah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Junaynah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Ghabah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Filahah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Abu Himar": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Abu 'Awdah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Arab al Qila'i": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Abu Mu'ammar": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Umm al Kilab": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Saknat az Zarqa'": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Rafiah Yam": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Qizan an Najjar": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Qa' al Qurayn": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Nahal Qatif": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Umm Kamil": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "An Nazlah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Mashahirah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Qa' al Kharabah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Daribat ash Shaykh Hammuda": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Izbat Bayt Hanun": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Arab Maslakh Bayt Lahya": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Madinat al 'Awdah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "As Surayij": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Az-Zawayda": {
#     "2023-10": 1,
#     "2023-12": 1,
#     "2024-02": 1,
#     "2024-04": 1,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Khuza'a": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "al Fukhari": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Shokat as-Sufi": {
#     "2023-10": 1,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al-Mughraqa": {
#     "2023-10": 1,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 1,
#     "2023-11": 0
# },
# "Bani Suhela": {
#     "2023-10": 3,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 2,
#     "2024-01": 0,
#     "2023-11": 5
# },
# "Abasan al-Saghira": {
#     "2023-10": 1,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 2
# },
# "Al-Zahra'": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 1
# },
# "Khirbat al-Adas": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Qaryah as Suwaydiyah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Katibah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Amal": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 1,
#     "2024-01": 1,
#     "2023-11": 0
# },
# "Atatra": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Remal": {
#     "2023-10": 14,
#     "2023-12": 5,
#     "2024-02": 0,
#     "2024-04": 2,
#     "2024-03": 3,
#     "2024-01": 0,
#     "2023-11": 3
# },
# "At Turkman": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Az Zaytun": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "As Sabra": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Fawayidah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Ash Shaykh 'Ijlin": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Midan Filastin": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Ar Rimal al Janubi": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Ar Rimal ash Shamali": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "An Nasr ash Sharqi": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "An Nasr al Gharbi": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Ash Shaykh Radwan": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Ad Daraj": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "At Tuffah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Jadidah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Maydan ash Shuja'iyah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Madinah al Qadimah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Mu'tarid": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Mintaqah as Sina'iyah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Ar Rasm": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Mattayin": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Harah ash Sharqiyah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Abu Asad": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Abu Sittah": {
#     "2023-10": 1,
#     "2023-12": 4,
#     "2024-02": 0,
#     "2024-04": 4,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Hamadah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 1,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Tunis": {
#     "2023-10": 14,
#     "2023-12": 6,
#     "2024-02": 2,
#     "2024-04": 19,
#     "2024-03": 2,
#     "2024-01": 5,
#     "2023-11": 41
# },
# "Al Masihi": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al 'Amrah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Brawk": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Abu Fayyad": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Umran": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Qata'ah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Hakar": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Hadabah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Farsh": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Umm al 'Azban": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Abu 'Arif": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Bisharah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Qa'ud": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Baldah al Qadimah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Mu'askar": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 1,
#     "2023-11": 0
# },
# "Ash Shaykh Nasir": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Markaz al Madinah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 1,
#     "2023-11": 0
# },
# "Batn as Samin": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Jurat al Lut": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Ma'n": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Qa' al Qarin": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Manarah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Qizan": {
#     "2023-10": 1,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Abu Rashwan": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Hijazi": {
#     "2023-10": 2,
#     "2023-12": 1,
#     "2024-02": 0,
#     "2024-04": 2,
#     "2024-03": 0,
#     "2024-01": 1,
#     "2023-11": 2
# },
# "Tall az Zu'rub": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Hawd Ji": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Hawd Waw": {
#     "2023-10": 1,
#     "2023-12": 2,
#     "2024-02": 1,
#     "2024-04": 1,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 1
# },
# "Yibna": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Qishtah": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al Barazil": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "As Salam": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Al-Azhar University": {
#     "2023-10": 2,
#     "2023-12": 2,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 1,
#     "2023-11": 1
# },
# "Al-Aqsa University": {
#     "2023-10": 1,
#     "2023-12": 0,
#     "2024-02": 2,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 2,
#     "2023-11": 0
# },
# "Bi'r Zawalan": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Bi'r Abu Thabit": {
#     "2023-10": 0,
#     "2023-12": 0,
#     "2024-02": 0,
#     "2024-04": 0,
#     "2024-03": 0,
#     "2024-01": 0,
#     "2023-11": 0
# },
# "Gaza": {
#     "2023-10": 4208,
#     "2023-12": 2892,
#     "2024-02": 1896,
#     "2024-04": 1002,
#     "2024-03": 2206,
#     "2024-01": 1966,
#     "2023-11": 4552
# },
# "Gaza Strip": {
#     "2023-10": 4208,
#     "2023-12": 2892,
#     "2024-02": 1896,
#     "2024-04": 1002,
#     "2024-03": 2206,
#     "2024-01": 1966,
#     "2023-11": 4552
# },
# "Gaza City": {
#     "2023-10": 4218,
#     "2023-12": 2915,
#     "2024-02": 1904,
#     "2024-04": 1005,
#     "2024-03": 2218,
#     "2024-01": 1973,
#     "2023-11": 4568
# },

# %% [markdown]
# Ex 2B

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.10.1-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (5.29.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.4.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3.0->stanza)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)
# Downloading stanza-1.10.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 118.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.3 MB/s eta 0:00:00
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 45.6 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, emoji, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed emoji-2.14.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stanza-1.10.1

# %%
#import libraries and import language model
import re
import stanza
import os
stanza.download("en")
#create pipeline and specify language
nlp = stanza.Pipeline(lang="en", processors="tokenize,mwt,ner")
#path to the repository
# !git clone https://github.com/Zainab1317/FASDH25-portfolio2.git

corpus = "/content/FASDH25-portfolio2/articles"

files = os.listdir(corpus)

jan_2024_files = []
#loop through the entities putting them in a separate list
for file in files:
    if file.startswith("2024-01"):
       jan_2024_files.append(file)
#opening and reading the file
place_counts = {}
for file in jan_2024_files:
    filepath = f"{corpus}/{file}"
    with open(filepath, encoding="utf8") as file:
        text = file.read()
#isolating required entities (gpes and locs)
# 1) Chatgpt corrected code, varable consistency
    doc = nlp(text)
    for sentence in doc.sentences:
      for entity in sentence.ents:
        if entity.type in ["GPE", "LOC", "FAC"]:
          place = entity.text.strip()
          place_counts[place] = place_counts.get(place, 0) + 1

#cleaning the named entities
# 2) Help taken from Chatgpt to fix error
clean_counts = {}

for place, count in place_counts.items():
    place = re.sub(r"['`]s\b", "", place)

    place = re.sub(r"[^\w\s]", "", place)

    place = re.sub(r"^the\s+", "", place, flags=re.IGNORECASE)

    clean_counts[place] = clean_counts.get(place, 0) + count

# Write cleaned and sorted data to a TSV file
items = [[place, count] for place, count in clean_counts.items()]

with open("ner_counts.tsv", "w", encoding="utf-8") as file:
    file.write("place\tcount\n")
    for item in items:
        file.write(f"{item[0]}\t{item[1]}\n")

# Read and print the TSV file contents
with open("/content/ner_counts.tsv", encoding="utf-8") as file:
    print(file.read())
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: en (English) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.10.0/models/default.zip:   0%|          | …
# INFO:stanza:Downloaded file to /root/stanza_resources/en/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: en (English):
# =========================================
# | Processor | Package                   |
# -----------------------------------------
# | tokenize  | combined                  |
# | mwt       | combined                  |
# | ner       | ontonotes-ww-multi_charlm |
# =========================================
#
# INFO:stanza:Using device: cuda
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!
# fatal: destination path 'FASDH25-portfolio2' already exists and is not an empty directory.
# place	count
# Israel	1594
# Gaza	1605
# Palestine	124
# United States	160
# Welchs	1
# US	717
# Iraq	62
# West	24
# Global South	2
# Qatar	64
# Gulf	10
# Egypt	43
# East Jerusalem	23
# Netanyahus	7
# Gaza Strip	156
# South Africa	200
# Russia	43
# Ukraine	47
# China	28
# South Africas	8
# Malaysia	8
# Turkey	25
# Jordan	42
# Bolivia	4
# Maldives	1
# Namibia	10
# Pakistan	24
# Columbia	3
# Khan Younis	24
# Middle East	102
# Hague	39
# Bangladesh	2
# Comoros	2
# Djibouti	4
# Netherlands	14
# United Kingdom	43
# Myanmar	6
# Beirut	84
# Dahiyeh	6
# Lebanon	175
# Iran	206
# Yemen	182
# Beiruts Shatila	1
# Red Sea	250
# Africa	29
# Suez Canal	26
# Gulf of Aden	27
# Cape of Good Hope	12
# Singapore	2
# Mediterranean	11
# Indian Ocean	2
# Europe	30
# Asia	18
# Spain	7
# Canada	42
# Australia	12
# Britain	14
# Germany	31
# Italy	10
# Switzerland	9
# Finland	3
# Estonia	1
# Japan	9
# Austria	3
# Romania	4
# Israels	31
# West Bank	160
# Syria	83
# October7	2
# Jerusalem	26
# Dearborn	12
# Michigan	12
# Mackinac Island	1
# Great Lakes	1
# Lake Michigan	1
# Afghanistan	7
# Texas	3
# Beit Nabala	1
# Idlib	3
# Hamass	6
# Tel Aviv	49
# Washington	60
# Cairo	6
# Doha	19
# Nuseirat	11
# Central Gaza Strip	2
# Deir elBalah	15
# Rafah	40
# Salah alDin Street	3
# Gaza Strips	3
# India	50
# New Delhi	6
# Indias Basmati	1
# North America	2
# North Africa	5
# Arabian Sea	6
# DC	14
# Pentagon	1
# Karem Abu Salem	3
# Kerem Shalom	4
# Greece	8
# Saudi Arabia	39
# United Arab Emirates	14
# Ramallah	24
# Gazas	19
# UAE	7
# United Nations	1
# Geneva	2
# Gaza city	1
# West Banks	2
# Lod Airport	1
# Ben Gurion International Airport	1
# Munich	2
# Haifa	8
# Sidon	3
# Salamehs	1
# alMajzoubs	1
# Beiruts	3
# Lebanons	3
# Palestine Mosque Square	1
# Detroit	1
# Southeast Michigan	1
# Arab America	1
# Jarrah	1
# Wayne County	1
# White House	6
# Minnesota	1
# Montreal	1
# Milton Ontario	1
# Jabalia	11
# Ottawa	3
# Toronto	1
# Calgary	1
# Gaza City	31
# Nasser Hospital	10
# Morocco	13
# Rabat	3
# Bahrain	11
# Sudan	3
# Western Sahara	4
# Algeria	7
# Marrakesh	1
# Moroccos	1
# Maghreb	1
# Bethlehem	4
# Nairoukh	1
# Shawawra	1
# Marshall Islands	1
# Aden	3
# Bab alMandeb Strait	9
# Hodeidah	5
# UK	95
# Al Maniya	1
# WestBank	2
# Melbourne Australia	1
# Port of Melbourne	1
# Victorian International Container Terminal	1
# Melbourne	5
# Sandridge Beach	1
# ZIM Ganges	5
# Australias	1
# Port Melbourne	1
# Sydney	1
# Brisbane	1
# Yemens coast	2
# Alborz	4
# Bab alMandeb	4
# Damascus	17
# Tehran	25
# Beit Lahiya	2
# Shujayea	3
# Abu Youssef Al Najjar Hospital	1
# alSaftawi	1
# Houthis	3
# BabelMandeb Strait	1
# Sanaa	15
# Taiz	2
# Dhamar	1
# alBayda	1
# Saada	3
# Dublin	3
# Moscow	4
# Bureij	2
# alMahatta	1
# Belgium	15
# Pretoria	8
# Hong Kong	2
# Abdullah bin Khalifa Stadium	1
# State of Palestine	1
# Yemens	6
# Denmark	3
# New Zealand	2
# South Korea	1
# France	13
# alWalaja	5
# Area C	6
# Gilo	1
# Har Gilo	1
# El Arish	3
# Norway	11
# Strip	15
# State of Israel	7
# Supernova	1
# Hostage Square	2
# Mexico	5
# Chile	4
# Tower 22	5
# Jordans	1
# alTanf	1
# Amman	6
# BaghdadDamascus highway	1
# Hashemite Kingdom of Jordan	1
# Ain alAssad	1
# Baghdad	8
# alAssad Airbase	3
# New York	4
# Indonesia	2
# Thailand	2
# Kuala Lumpur	4
# Jakarta	2
# Johannesburg	4
# London	17
# Mozambique	1
# Bulgaria	1
# Philippines	4
# Golan Heights	3
# Kanaker	1
# Yaroun	3
# Sarit	1
# Aleppo	2
# Kyiv	5
# IsraelPalestine	2
# European Gaza Hospital	1
# Nasser Medical Complex	4
# AlAqsa	1
# Al Aqsa Hospital	1
# Rawaas	1
# Khan Younis Training Centre	2
# alKarama	1
# Westminster Bridge	1
# Ras Issa	1
# Hodeidah province	1
# Bab elMandeb	2
# Ebel elSaqi	1
# Egypts	1
# Riyadh	5
# Bab al	1
# Mandeb Strait	1
# Maghazi	5
# Near East	3
# Davos	7
# Al Jazeeras	1
# alMawasi	3
# Istanbul	2
# Crete	2
# Ankara	7
# Washingtons	2
# Vahdettin Mansion	1
# Sweden	3
# Paris	8
# Eastern Mediterranean	1
# Bosnia	3
# Herzegovina	1
# Serbia	3
# Montenegro	1
# Yugoslavia	2
# Salem	1
# Copenhagen	1
# Ansarallah	1
# Washington DC	7
# AlAmal Hospital	3
# Khan Yunis	1
# Mawasi	1
# Shadis	1
# Paltel	1
# Jawwal	1
# Walla	2
# Palestinian Territories	1
# Berlin	5
# Gretna	2
# Louisiana	3
# New Orleans	5
# Highway 60	3
# MirandaCleland	1
# Kaplan Square	1
# Caesarea	2
# Kefar Sava	1
# Rehovot	1
# Beersheba	1
# RepJayapal	1
# RepCori	1
# BasedMikeLee	1
# Republic of Korea	1
# Libya	3
# Kosovo	1
# Brussels	5
# League of Arab States	1
# alAqsa Martyrs Hospital	3
# Gazas Deir elBalah	3
# alMughraqa	1
# alMaghazi	1
# Maghazi Roads	1
# Deir alBalah	1
# South Carolina	4
# New York City	1
# Arura	2
# Beruit	1
# alMazraa	1
# Mediterranean Sea	2
# Ajaq	1
# Silwad	1
# La France	1
# At Tur EastJerusalem	1
# Ocean Jazz	1
# Cape Town	2
# South Africansfrom	1
# Africa4Palestine	1
# Western Cape province	1
# Cyprus	9
# Akrotiri	12
# Limassol	1
# Pashias	1
# Israels Nevatim airbase	1
# Anadolu	1
# Nevatim	1
# Tel Avivs	3
# Ben Gurion airport	1
# Republic of Cyprus	2
# Dhekelia	1
# USA	2
# Jenin	19
# Beit Iksa	1
# Abwein	1
# Nablus	5
# Hebron	10
# Qalqilya	2
# Jericho	1
# AlAqsa Mosque	1
# PA	1
# Oslo	2
# Aqaba	1
# Houthi	3
# majedalansari	1
# Kan	1
# Wadi Gaza	3
# Sri Lanka	2
# Republic of South Africa	1
# alMazraa Asharqiya	2
# Masjid Omar mosque	1
# Harvey	1
# Tawfiq	1
# Road 60	1
# alDabshah	1
# Khirbet Selm	1
# Bint Jbeil	1
# Ibil El Saqi	1
# Meron	2
# alTawils	1
# alKhader	1
# Bekaa Valley	1
# Litani River	1
# Iceland	1
# Czech Republic	1
# Hungary	1
# Slovenia	1
# Ireland	3
# carogennez	1
# Belgiums	1
# Flanders	1
# Wallonia	1
# Tel Israels	1
# Aizawl	6
# Manipur	8
# Kangpokpi	1
# Mizoram	7
# Mizorams	1
# Kingdom of Judah	1
# Anu Museum	1
# Bnei Menashe	3
# Kolasib	1
# Silicon Valley	3
# Beit Shemesh	1
# Santa Clara	1
# California	3
# Moldova	1
# Netivot	1
# Thameen Darby	1
# Nakba Layer	1
# Mercator	1
# Alaska	1
# South America	2
# AsiaPacific	1
# Crimea	4
# South China Sea	2
# Vietnam	1
# Kashmir	4
# Islamabad	3
# Darbys Nakba	1
# Panjgur	1
# Pakistans Balochistan province	2
# SistanBaluchestan province	1
# Islamic Republic of Iran	1
# Kerman	6
# Islamic Republic	5
# Nur Shams	1
# Tulkarem	2
# Naqoura	2
# America	4
# Ein alHilweh	1
# Basel	3
# Ofer	1
# Jordan Valley	5
# Kadris	1
# alJiftlik	1
# Farsiya	1
# Makhoul	1
# Tubas	1
# Umm Zuka	1
# Areas A	1
# Uganda	11
# Kuwait	2
# Chicago	2
# Dena	1
# Oakland	1
# Syrias Aleppo	1
# Mariupol	1
# Ibn Sina Hospital	2
# Zeitoun	4
# alAmal	4
# alNasser	1
# alKatiba	1
# Harun arRashid school	1
# Block 109	1
# NaksBilal	1
# alShifa Hospital	3
# alMawasi district	2
# El Amal City Hospital	2
# Erbil	13
# Irans SistanBaluchestan province	2
# Irans	3
# Rask	1
# SistanBaluchestan	1
# Strait of Hormuz	3
# Persian Gulf	1
# Balochistan	1
# Frances	1
# AlAqsa Martyrs Hospital	4
# Middle East Eye	1
# BabelMandeb strait	1
# Red Sea Port	1
# Eilat	2
# Ashdod	2
# Dead Sea	1
# Eastern Mediterranean region	1
# Farhana	1
# Abudaqa	2
# Dahiyeb	1
# alArouris	1
# Aroura	2
# alArouri	2
# Rohtak	6
# Haryana	3
# Uttar Pradesh	1
# Lucknow	1
# UP	1
# Bihar	4
# West Bengal	1
# Benarasiyaa	1
# Haryanas Panipat	1
# Middle Eastern	3
# Haryanas Jind	1
# Karem Abu Salem crossing	1
# Hebrew	1
# Portugal	3
# Iraqs	2
# Erbil Airport	1
# Maroun El Ras	1
# Rmeish	1
# Port of Ashdod	1
# Miraj	1
# Tal alHawa	1
# zarahsultana	1
# Gisha	1
# Bani Naim	1
# Raanana	1
# Sderot	2
# Nir Am	1
# Mefalsim	1
# Hanita	1
# Mattat	1
# Margaliot	1
# Adamit	1
# Zarit	1
# Malkia	1
# Yassins house	1
# Daouds house	1
# Dubai	1
# Yemens southern coast	1
# Kampala	5
# Bahaa elDin Abu Ras	1
# Dura	2
# Bahaas	1
# Abdullah Azzam Mosque	1
# Manchester City	1
# Barcelona	1
# Syrias Damascus	1
# Syrias	1
# Mazzeh	2
# Borj el Barajneh	1
# Ain alAsad	1
# Palestine_UN	1
# Dahiya	1
# Jamaa Islamiya	2
# Southern Africa	2
# RedSea	1
# Chinas	2
# Bab alMandeb strait	3
# El Amal Hospital	2
# Jordan River	1
# alShifa	2
# Gazas AlAqsa Hospital	1
# Israels Haifa	1
# Hamoud	1
# Burj alBarajneh	1
# Taalbaya	1
# Shatila	3
# Rashidiya	1
# Bab alMandab	1
# Venezuela	1
# Hormuz	1
# Arabian Gulf	1
# Gulf of Oman	2
# Khreiss	1
# Northern Gaza	1
# Lisbon	1
# Des Moines	7
# Iowa	12
# Tunisia	2
# Cedar Rapids	5
# Iowa City	5
# South Asia	1
# Florida	1
# New Yorks Ellis Island	1
# Ohio	1
# Bir anNaaja	1
# Zawayda	1
# Beit Hanoon	1
# Kamal Adwan Hospital	2
# Syrias Golan Heights	1
# Kurdistan	1
# Panjgur Pakistans Balochistan province	1
# Belarus	1
# BosniaHerzegovina	1
# Srebrenica	1
# Mediterraneans	1
# Eurasia	1
# Via Maris	3
# Heliopolis	1
# Gazas Great Omari Mosque	1
# Jalaa Street	1
# alFawakhir	1
# Rafah Museum	1
# Al Qarara Museum	1
# Khan Younis Museum	1
# Levant	1
# Mathaf alFunduq	1
# Mathaf Hotel	1
# Qasr AlBasha	1
# Pashas Palace	1
# Rashad El Shawa Cultural Center	1
# Library of the Great Omari Mosque	1
# Omari Mosque	1
# HMML Reading Room	1
# Othman bin Qashqar Mosque	1
# Gaza Citys Zeitoun	1
# Sayed alHashim Mosque	1
# Old City of Gaza	1
# Mecca	1
# Gazas Daraj	1
# Great Omari Mosque	1
# AlMasjid alOmari alKabir	1
# St John the Baptist Cathedral	1
# Byzantine Church of Jabalia	1
# Byzantium	1
# Monastery of Saint Hilarion	1
# Tell Umm Amer	1
# Saint Porphyrius	1
# Katib alWilaya Mosque	1
# Holy Family Church	1
# ArdalMoharbeen	1
# Roman Necropolis	1
# Anthedon	1
# Balakhiyah	1
# Tida	1
# Hammam alSammara	1
# Samaritan Bathhouse	1
# Israel Museum	1
# Tell elAjjul	1
# Calves Hill	1
# Gizas Great Pyramid	1
# Khan Younis caravanserai	1
# Deir elBalah Cemetery	1
# Daraj	1
# Ahmadiyyah Zawiya	1
# X
# Spain	1
# Madrid	1
# Oman	1
# Indonesias	1
# Vienna	1
# Bank Junction	1
# Manchester	1
# Hyderabad	1
# Colombos Kollupitiya	1
# Bab elMandeb strait	1
# Maersk Hangzhou	1
# Southern Red Sea	1
# Africas Cape of Good Hope	1
# Scotland	2
# Egypts Sinai Peninsula	1
# Philadelphi	1
# Charleston	1
# Tel Avivs Hostage Square	1
# AlFukhari	1
# alFukhari	2
# alAhli Arab Hospital	1
# Cameroon	1
# Iron Dome	1
# alAhli	1
# West Jerusalem	1
# alSabeen Square	1
# Seychelles	1
# Marib	3
# Egypts El Arish International Airport	1
# MoTaz	1
# azaizamotaz9	1
# Sabra	1
# Somalia	1
# Yemens Red Sea	1
# Hajjah	2
# Taiz province	1
# AlBayda	1
# Ugandas	1
# Peru	1
# Colombia	1
# South Sudan	1
# Swaziland	1
# Lama Khater	1
# Kiryat Arba	2
# Hasharon Prison	1
# Damon Prison	1
# Ofer Prison	1
# Malta	2
# northGaza	1
# Earth	1
# Entebbe Uganda	1
# Sierra Leone	1
# DRC	1
# adoniaayebare	1
# Republic of Yemen	1
# West Beirut	9
# Beiruts Hamra	1
# Hamras	1
# Hamra	2
# West Beirutis	1
# Dabbouch	1
# East Beirut	1
# Bani Suheila	2
# Kiryat Shmona	1
# Blue Line	1
# Chiles	1
# Santiago	1
# Hezbollahs	1
# Deir Qaddis	1
# Education City Stadium	1
# Al Rayyan	1
# Qatars	1
# Bern	1
# Zurich	1
# TomWhiteGaza	1
# Entebbe	1
# Gaza strip	1
# Rwanda	1
# East Timor	1
# Kabul	1
# azZahra	1
# alRashid road	1
# Hamad	1
# State of Qatar	1
# QFFD	1
# Lebanons Nabatieh	1
# Yiron	1
# Avivim	1
# Israels Goren	1
# Palestine Martyrs Cemetery	1

# %% [markdown]
# Ex 3

# %%
# !pip install stanza
# Out:
# Requirement already satisfied: stanza in /usr/local/lib/python3.11/dist-packages (1.10.1)
# Requirement already satisfied: emoji in /usr/local/lib/python3.11/dist-packages (from stanza) (2.14.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (5.29.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.4.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)

# %%
import requests
import time

geonames_username = "zainab128"

def get_coordinates(place, username=geonames_username, fuzzy=0, timeout=1):

  # wait a short while, so that we don't overload the server:
  time.sleep(timeout)
  # make the API call:
  url = "http://api.geonames.org/searchJSON?"
  params = {"q": place, "username": username, "fuzzy": fuzzy, "maxRows": 1, "isNameRequired": True}
  response = requests.get(url, params=params)
  # convert the response into a dictionary:
  results = response.json()
  print(results)
  # get the first result:
  try:
    result = results["geonames"][0]
    return {"latitude": result["lat"], "longitude": result["lng"]}
  except (IndexError, KeyError):
    print("No results found for your API call", response.request.url)

import csv

filename = "ner_gazetteer.tsv"

with open(filename, mode="w", encoding="utf-8") as file:
  header = "place\tlatitude\tlongitude\n"
  file.write(header)
  with open("ner_counts.tsv", encoding="utf-8") as infile:
    reader = csv.DictReader(infile, delimiter='\t')
    for row in reader:
      place_name = row['place']
      coordinates = get_coordinates(place_name)
      if coordinates:
        latitude = coordinates["latitude"]
        longitude = coordinates["longitude"]
        row_data = f"{place_name}\t{latitude}\t{longitude}\n"
        file.write(row_data)
      else:
           row_data = f"{place_name}\tNA\tNA\n"
      file.write(row_data)
# Out:
# {'totalResultsCount': 33, 'geonames': [{'adminCode1': '00', 'lng': '34.75', 'geonameId': 294640, 'toponymName': 'State of Israel', 'countryId': '294640', 'fcl': 'A', 'population': 8883800, 'countryCode': 'IL', 'name': 'Israel', 'fclName': 'country, state, region,...', 'countryName': 'Israel', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '31.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 40, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.46672', 'geonameId': 281133, 'toponymName': 'Gaza', 'countryId': '6254930', 'fcl': 'P', 'population': 410000, 'countryCode': 'PS', 'name': 'Gaza', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.50161', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 49, 'geonames': [{'adminCode1': '00', 'lng': '35.20329', 'geonameId': 6254930, 'toponymName': 'Palestine', 'countryId': '6254930', 'fcl': 'A', 'population': 4569087, 'countryCode': 'PS', 'name': 'Palestine', 'fclName': 'country, state, region,...', 'countryName': 'Palestine', 'fcodeName': 'semi-independent political entity', 'adminName1': '', 'lat': '31.92157', 'fcode': 'PCLS'}]}
# {'totalResultsCount': 209, 'geonames': [{'adminCode1': '00', 'lng': '-98.5', 'geonameId': 6252001, 'toponymName': 'United States', 'countryId': '6252001', 'fcl': 'A', 'population': 327167434, 'countryCode': 'US', 'name': 'United States', 'fclName': 'country, state, region,...', 'countryName': 'United States', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '39.76', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': 'LA', 'lng': '-92.82265', 'geonameId': 4345667, 'toponymName': 'Welsh', 'countryId': '6252001', 'fcl': 'P', 'population': 3227, 'countryCode': 'US', 'name': 'Welsh', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'LA'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'Louisiana', 'lat': '30.23604', 'fcode': 'PPL'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '11', 'lng': '1.96667', 'geonameId': 2971316, 'toponymName': 'Us', 'countryId': '3017382', 'fcl': 'P', 'population': 1248, 'countryCode': 'FR', 'name': 'Us', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'IDF'}, 'countryName': 'France', 'fcodeName': 'populated place', 'adminName1': 'Île-de-France', 'lat': '49.1', 'fcode': 'PPL'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': '00', 'lng': '44', 'geonameId': 99237, 'toponymName': 'Republic of Iraq', 'countryId': '99237', 'fcl': 'A', 'population': 38433600, 'countryCode': 'IQ', 'name': 'Iraq', 'fclName': 'country, state, region,...', 'countryName': 'Iraq', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '33', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 54, 'geonames': [{'lng': '-116.9579', 'geonameId': 11887751, 'toponymName': 'West', 'countryId': '6252001', 'fcl': 'L', 'population': 77000000, 'countryCode': 'US', 'name': 'West', 'fclName': 'parks,area, ...', 'countryName': 'United States', 'fcodeName': 'region', 'adminName1': '', 'lat': '42.77268', 'fcode': 'RGN'}]}
# {'totalResultsCount': 17, 'geonames': [{'adminCode1': '05', 'lng': '138.51674', 'geonameId': 9258423, 'toponymName': 'Glenelg, South', 'countryId': '2077456', 'fcl': 'L', 'population': 0, 'countryCode': 'AU', 'name': 'Glenelg, South', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'SA'}, 'countryName': 'Australia', 'fcodeName': 'locality', 'adminName1': 'South Australia', 'lat': '-34.98943', 'fcode': 'LCTY'}]}
# {'totalResultsCount': 22, 'geonames': [{'adminCode1': '00', 'lng': '51.25', 'geonameId': 289688, 'toponymName': 'State of Qatar', 'countryId': '289688', 'fcl': 'A', 'population': 2781677, 'countryCode': 'QA', 'name': 'Qatar', 'fclName': 'country, state, region,...', 'countryName': 'Qatar', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '02', 'lng': '145.08545', 'geonameId': 2096633, 'toponymName': 'Gulf Province', 'countryId': '2088628', 'fcl': 'A', 'population': 158197, 'countryCode': 'PG', 'name': 'Gulf Province', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'GPK'}, 'countryName': 'Papua New Guinea', 'fcodeName': 'first-order administrative division', 'adminName1': 'Gulf Province', 'lat': '-7.7246', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 57, 'geonames': [{'adminCode1': '00', 'lng': '30', 'geonameId': 357994, 'toponymName': 'Arab Republic of Egypt', 'countryId': '357994', 'fcl': 'A', 'population': 98423595, 'countryCode': 'EG', 'name': 'Egypt', 'fclName': 'country, state, region,...', 'countryName': 'Egypt', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '27', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 1332, 'geonames': [{'adminCode1': 'WE', 'lng': '35.23388', 'geonameId': 7303419, 'toponymName': 'East Jerusalem', 'countryId': '6254930', 'fcl': 'P', 'population': 428304, 'countryCode': 'PS', 'name': 'East Jerusalem', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'section of populated place', 'adminName1': 'West Bank', 'lat': '31.78336', 'fcode': 'PPLX'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Netanyahus&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.46672', 'geonameId': 281133, 'toponymName': 'Gaza', 'countryId': '6254930', 'fcl': 'P', 'population': 410000, 'countryCode': 'PS', 'name': 'Gaza', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.50161', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 2643, 'geonames': [{'adminCode1': 'FL', 'lng': '-81', 'geonameId': 12217087, 'toponymName': 'South Florida', 'countryId': '6252001', 'fcl': 'L', 'population': 8260000, 'countryCode': 'US', 'name': 'South Florida', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'FL'}, 'countryName': 'United States', 'fcodeName': 'economic region', 'adminName1': 'Florida', 'lat': '26.5', 'fcode': 'RGNE'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '100', 'geonameId': 2017370, 'toponymName': 'Russian Federation', 'countryId': '2017370', 'fcl': 'A', 'population': 144478050, 'countryCode': 'RU', 'name': 'Russia', 'fclName': 'country, state, region,...', 'countryName': 'Russia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '60', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '00', 'lng': '32', 'geonameId': 690791, 'toponymName': 'Ukraine', 'countryId': '690791', 'fcl': 'A', 'population': 44622516, 'countryCode': 'UA', 'name': 'Ukraine', 'fclName': 'country, state, region,...', 'countryName': 'Ukraine', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '49', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 123, 'geonames': [{'adminCode1': '00', 'lng': '105', 'geonameId': 1814991, 'toponymName': 'People’s Republic of China', 'countryId': '1814991', 'fcl': 'A', 'population': 1411778724, 'countryCode': 'CN', 'name': 'China', 'fclName': 'country, state, region,...', 'countryName': 'China', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '35', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 1666, 'geonames': [{'adminCode1': 'FL', 'lng': '-81', 'geonameId': 12217087, 'toponymName': 'South Florida', 'countryId': '6252001', 'fcl': 'L', 'population': 8260000, 'countryCode': 'US', 'name': 'South Florida', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'FL'}, 'countryName': 'United States', 'fcodeName': 'economic region', 'adminName1': 'Florida', 'lat': '26.5', 'fcode': 'RGNE'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '00', 'lng': '112.5', 'geonameId': 1733045, 'toponymName': 'Malaysia', 'countryId': '1733045', 'fcl': 'A', 'population': 31528585, 'countryCode': 'MY', 'name': 'Malaysia', 'fclName': 'country, state, region,...', 'countryName': 'Malaysia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '2.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 23, 'geonames': [{'adminCode1': '00', 'lng': '35', 'geonameId': 298795, 'toponymName': 'Republic of Turkey', 'countryId': '298795', 'fcl': 'A', 'population': 82319724, 'countryCode': 'TR', 'name': 'Türkiye', 'fclName': 'country, state, region,...', 'countryName': 'Türkiye', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '39', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 110, 'geonames': [{'adminCode1': '00', 'lng': '36', 'geonameId': 248816, 'toponymName': 'Hashemite Kingdom of Jordan', 'countryId': '248816', 'fcl': 'A', 'population': 9956011, 'countryCode': 'JO', 'name': 'Jordan', 'fclName': 'country, state, region,...', 'countryName': 'Jordan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '31', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 41, 'geonames': [{'adminCode1': '00', 'lng': '-65', 'geonameId': 3923057, 'toponymName': 'Plurinational State of Bolivia', 'countryId': '3923057', 'fcl': 'A', 'population': 11353142, 'countryCode': 'BO', 'name': 'Bolivia', 'fclName': 'country, state, region,...', 'countryName': 'Bolivia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '-17', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': '00', 'lng': '73', 'geonameId': 1282028, 'toponymName': 'Republic of Maldives', 'countryId': '1282028', 'fcl': 'A', 'population': 515696, 'countryCode': 'MV', 'name': 'Maldives', 'fclName': 'country, state, region,...', 'countryName': 'Maldives', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '3.2', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': '00', 'lng': '17', 'geonameId': 3355338, 'toponymName': 'Republic of Namibia', 'countryId': '3355338', 'fcl': 'A', 'population': 2448255, 'countryCode': 'NA', 'name': 'Namibia', 'fclName': 'country, state, region,...', 'countryName': 'Namibia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '-22', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 5, 'geonames': [{'adminCode1': '00', 'lng': '70', 'geonameId': 1168579, 'toponymName': 'Islamic Republic of Pakistan', 'countryId': '1168579', 'fcl': 'A', 'population': 212215030, 'countryCode': 'PK', 'name': 'Pakistan', 'fclName': 'country, state, region,...', 'countryName': 'Pakistan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '30', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 126, 'geonames': [{'adminCode1': '00', 'lng': '-73.25', 'geonameId': 3686110, 'toponymName': 'Republic of Colombia', 'countryId': '3686110', 'fcl': 'A', 'population': 49648685, 'countryCode': 'CO', 'name': 'Colombia', 'fclName': 'country, state, region,...', 'countryName': 'Colombia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '4', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 287, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.30627', 'geonameId': 281124, 'toponymName': 'Khān Yūnis', 'countryId': '6254930', 'fcl': 'P', 'population': 173183, 'countryCode': 'PS', 'name': 'Khan Yunis', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.34018', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 2622, 'geonames': [{'lng': '35.85869', 'geonameId': 6269133, 'name': 'Middle East', 'fclName': 'parks,area, ...', 'toponymName': 'Middle East', 'fcodeName': 'region', 'adminName1': '', 'lat': '33.13906', 'fcl': 'L', 'fcode': 'RGN', 'population': 371400000}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '11', 'lng': '-106.41859', 'geonameId': 12822709, 'toponymName': 'Hague', 'countryId': '6251999', 'fcl': 'A', 'population': 0, 'countryCode': 'CA', 'name': 'Hague', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'SK'}, 'countryName': 'Canada', 'fcodeName': 'second-order administrative division', 'adminName1': 'Saskatchewan', 'lat': '52.51118', 'fcode': 'ADM2'}]}
# {'totalResultsCount': 4, 'geonames': [{'adminCode1': '00', 'lng': '90', 'geonameId': 1210997, 'toponymName': 'Bangladesh', 'countryId': '1210997', 'fcl': 'A', 'population': 161356039, 'countryCode': 'BD', 'name': 'Bangladesh', 'fclName': 'country, state, region,...', 'countryName': 'Bangladesh', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '24', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '00', 'lng': '44.44553', 'geonameId': 921929, 'toponymName': 'Union of the Comoros', 'countryId': '921929', 'fcl': 'A', 'population': 832322, 'countryCode': 'KM', 'name': 'Comoros', 'fclName': 'country, state, region,...', 'countryName': 'Comoros', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '-12.23333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '00', 'lng': '42.5', 'geonameId': 223816, 'toponymName': 'Republic of Djibouti', 'countryId': '223816', 'fcl': 'A', 'population': 958920, 'countryCode': 'DJ', 'name': 'Djibouti', 'fclName': 'country, state, region,...', 'countryName': 'Djibouti', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '11.83333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 8, 'geonames': [{'adminCode1': '00', 'lng': '5.75', 'geonameId': 2750405, 'toponymName': 'Kingdom of the Netherlands', 'countryId': '2750405', 'fcl': 'A', 'population': 17231017, 'countryCode': 'NL', 'name': 'The Netherlands', 'fclName': 'country, state, region,...', 'countryName': 'The Netherlands', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '52.25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 181, 'geonames': [{'adminCode1': '00', 'lng': '-2.69531', 'geonameId': 2635167, 'toponymName': 'United Kingdom of Great Britain and Northern Ireland', 'countryId': '2635167', 'fcl': 'A', 'population': 66488991, 'countryCode': 'GB', 'name': 'United Kingdom', 'fclName': 'country, state, region,...', 'countryName': 'United Kingdom', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '54.75844', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '00', 'lng': '96', 'geonameId': 1327865, 'toponymName': 'Union of Burma', 'countryId': '1327865', 'fcl': 'A', 'population': 53708395, 'countryCode': 'MM', 'name': 'Myanmar', 'fclName': 'country, state, region,...', 'countryName': 'Myanmar', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '21', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '04', 'lng': '35.50157', 'geonameId': 276781, 'toponymName': 'Beirut', 'countryId': '272103', 'fcl': 'P', 'population': 1916100, 'countryCode': 'LB', 'name': 'Beirut', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'BA'}, 'countryName': 'Lebanon', 'fcodeName': 'capital of a political entity', 'adminName1': 'Beyrouth', 'lat': '33.89332', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Dahiyeh&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 76, 'geonames': [{'adminCode1': '00', 'lng': '35.83333', 'geonameId': 272103, 'toponymName': 'Lebanon', 'countryId': '272103', 'fcl': 'A', 'population': 6848925, 'countryCode': 'LB', 'name': 'Lebanon', 'fclName': 'country, state, region,...', 'countryName': 'Lebanon', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '33.83333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '00', 'lng': '53', 'geonameId': 130758, 'toponymName': 'Islamic Republic of Iran', 'countryId': '130758', 'fcl': 'A', 'population': 81800269, 'countryCode': 'IR', 'name': 'Iran', 'fclName': 'country, state, region,...', 'countryName': 'Iran', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '32', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '00', 'lng': '47.5', 'geonameId': 69543, 'toponymName': 'Republic of Yemen', 'countryId': '69543', 'fcl': 'A', 'population': 28498687, 'countryCode': 'YE', 'name': 'Yemen', 'fclName': 'country, state, region,...', 'countryName': 'Yemen', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '15.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Beiruts+Shatila&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 1970, 'geonames': [{'adminCode1': '01', 'lng': '-113.802', 'geonameId': 6118158, 'toponymName': 'Red Deer', 'countryId': '6251999', 'fcl': 'P', 'population': 73593, 'countryCode': 'CA', 'name': 'Red Deer', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'AB'}, 'countryName': 'Canada', 'fcodeName': 'populated place', 'adminName1': 'Alberta', 'lat': '52.26682', 'fcode': 'PPL'}]}
# {'totalResultsCount': 29, 'geonames': [{'lng': '21.09375', 'geonameId': 6255146, 'name': 'Africa', 'fclName': 'parks,area, ...', 'toponymName': 'Africa', 'fcodeName': 'continent', 'adminName1': '', 'lat': '7.1881', 'fcl': 'L', 'fcode': 'CONT', 'population': 1031833000}]}
# {'totalResultsCount': 23, 'geonames': [{'adminCode1': '15', 'lng': '32.56278', 'geonameId': 347712, 'toponymName': 'Suez Canal', 'countryId': '357994', 'fcl': 'H', 'population': 0, 'countryCode': 'EG', 'name': 'Suez Canal', 'fclName': 'stream, lake, ...', 'adminCodes1': {'ISO3166_2': 'SUZ'}, 'countryName': 'Egypt', 'fcodeName': 'canal', 'adminName1': 'Suez', 'lat': '29.93139', 'fcode': 'CNL'}]}
# {'totalResultsCount': 234, 'geonames': [{'lng': '48', 'geonameId': 80303, 'name': 'Gulf of Aden', 'fclName': 'stream, lake, ...', 'toponymName': 'Gulf of Aden', 'fcodeName': 'gulf', 'adminName1': '', 'lat': '12', 'fcl': 'H', 'fcode': 'GULF', 'population': 0}]}
# {'totalResultsCount': 418, 'geonames': [{'adminCode1': 'CO', 'lng': '-108.02785', 'geonameId': 5416048, 'toponymName': 'Cape of Good Hope', 'countryId': '6252001', 'fcl': 'T', 'population': 0, 'countryCode': 'US', 'name': 'Cape of Good Hope', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'CO'}, 'countryName': 'United States', 'fcodeName': 'cliff(s)', 'adminName1': 'Colorado', 'lat': '37.52777', 'fcode': 'CLF'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '103.8', 'geonameId': 1880251, 'toponymName': 'Republic of Singapore', 'countryId': '1880251', 'fcl': 'A', 'population': 5638676, 'countryCode': 'SG', 'name': 'Singapore', 'fclName': 'country, state, region,...', 'countryName': 'Singapore', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '1.36667', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 25, 'geonames': [{'lng': '19.33', 'geonameId': 12217088, 'name': 'Mediterranean Basin', 'fclName': 'parks,area, ...', 'toponymName': 'Mediterranean Basin', 'fcodeName': 'economic region', 'adminName1': '', 'lat': '35.78', 'fcl': 'L', 'fcode': 'RGNE', 'population': 506090000}]}
# {'totalResultsCount': 3515, 'geonames': [{'lng': '70', 'geonameId': 1545739, 'name': 'Indian Ocean', 'fclName': 'stream, lake, ...', 'toponymName': 'Indian Ocean', 'fcodeName': 'ocean', 'adminName1': '', 'lat': '-10', 'fcl': 'H', 'fcode': 'OCN', 'population': 0}]}
# {'totalResultsCount': 14, 'geonames': [{'lng': '9.14062', 'geonameId': 6255148, 'name': 'Europe', 'fclName': 'parks,area, ...', 'toponymName': 'Europe', 'fcodeName': 'continent', 'adminName1': '', 'lat': '48.69096', 'fcl': 'L', 'fcode': 'CONT', 'population': 741000000}]}
# {'totalResultsCount': 44, 'geonames': [{'lng': '89.29688', 'geonameId': 6255147, 'name': 'Asia', 'fclName': 'parks,area, ...', 'toponymName': 'Asia', 'fcodeName': 'continent', 'adminName1': '', 'lat': '29.84064', 'fcl': 'L', 'fcode': 'CONT', 'population': 3812366000}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '-4', 'geonameId': 2510769, 'toponymName': 'Kingdom of Spain', 'countryId': '2510769', 'fcl': 'A', 'population': 46723749, 'countryCode': 'ES', 'name': 'Spain', 'fclName': 'country, state, region,...', 'countryName': 'Spain', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '40', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 160, 'geonames': [{'adminCode1': '00', 'lng': '-113.64258', 'geonameId': 6251999, 'toponymName': 'Canada', 'countryId': '6251999', 'fcl': 'A', 'population': 37058856, 'countryCode': 'CA', 'name': 'Canada', 'fclName': 'country, state, region,...', 'countryName': 'Canada', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '60.10867', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 27, 'geonames': [{'adminCode1': '00', 'lng': '135', 'geonameId': 2077456, 'toponymName': 'Commonwealth of Australia', 'countryId': '2077456', 'fcl': 'A', 'population': 24992369, 'countryCode': 'AU', 'name': 'Australia', 'fclName': 'country, state, region,...', 'countryName': 'Australia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '-25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': 'ENG', 'lng': '-2', 'geonameId': 2648147, 'toponymName': 'Great Britain', 'countryId': '2635167', 'fcl': 'T', 'population': 64163534, 'countryCode': 'GB', 'name': 'Great Britain', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'ENG'}, 'countryName': 'United Kingdom', 'fcodeName': 'island', 'adminName1': 'England', 'lat': '54', 'fcode': 'ISL'}]}
# {'totalResultsCount': 19, 'geonames': [{'adminCode1': '00', 'lng': '10.5', 'geonameId': 2921044, 'toponymName': 'Federal Republic of Germany', 'countryId': '2921044', 'fcl': 'A', 'population': 82927922, 'countryCode': 'DE', 'name': 'Germany', 'fclName': 'country, state, region,...', 'countryName': 'Germany', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '51.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '00', 'lng': '12.83333', 'geonameId': 3175395, 'toponymName': 'Italian Republic', 'countryId': '3175395', 'fcl': 'A', 'population': 60431283, 'countryCode': 'IT', 'name': 'Italy', 'fclName': 'country, state, region,...', 'countryName': 'Italy', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '42.83333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 15, 'geonames': [{'adminCode1': '00', 'lng': '8.01427', 'geonameId': 2658434, 'toponymName': 'Switzerland', 'countryId': '2658434', 'fcl': 'A', 'population': 8516543, 'countryCode': 'CH', 'name': 'Switzerland', 'fclName': 'country, state, region,...', 'countryName': 'Switzerland', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '47.00016', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '00', 'lng': '26', 'geonameId': 660013, 'toponymName': 'Republic of Finland', 'countryId': '660013', 'fcl': 'A', 'population': 5518050, 'countryCode': 'FI', 'name': 'Finland', 'fclName': 'country, state, region,...', 'countryName': 'Finland', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '64', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '00', 'lng': '26', 'geonameId': 453733, 'toponymName': 'Republic of Estonia', 'countryId': '453733', 'fcl': 'A', 'population': 1320884, 'countryCode': 'EE', 'name': 'Estonia', 'fclName': 'country, state, region,...', 'countryName': 'Estonia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '59', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 19, 'geonames': [{'adminCode1': '00', 'lng': '139.75309', 'geonameId': 1861060, 'toponymName': 'Japan', 'countryId': '1861060', 'fcl': 'A', 'population': 126529100, 'countryCode': 'JP', 'name': 'Japan', 'fclName': 'country, state, region,...', 'countryName': 'Japan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '35.68536', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '13.33333', 'geonameId': 2782113, 'toponymName': 'Republic of Austria', 'countryId': '2782113', 'fcl': 'A', 'population': 8847037, 'countryCode': 'AT', 'name': 'Austria', 'fclName': 'country, state, region,...', 'countryName': 'Austria', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '47.33333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 8, 'geonames': [{'adminCode1': '00', 'lng': '25', 'geonameId': 798549, 'toponymName': 'România', 'countryId': '798549', 'fcl': 'A', 'population': 19473936, 'countryCode': 'RO', 'name': 'Romania', 'fclName': 'country, state, region,...', 'countryName': 'Romania', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '46', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': 'VA', 'lng': '-78.69724', 'geonameId': 4766212, 'toponymName': 'Israel Gap', 'countryId': '6252001', 'fcl': 'T', 'population': 0, 'countryCode': 'US', 'name': 'Israel Gap', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'VA'}, 'countryName': 'United States', 'fcodeName': 'gap', 'adminName1': 'Virginia', 'lat': '37.97986', 'fcode': 'GAP'}]}
# {'totalResultsCount': 2604, 'geonames': [{'adminCode1': '10375968', 'lng': '-81.39281', 'geonameId': 3580477, 'toponymName': 'West Bay', 'countryId': '3580718', 'fcl': 'P', 'population': 15335, 'countryCode': 'KY', 'name': 'West Bay', 'fclName': 'city, village,...', 'countryName': 'Cayman Islands', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'West Bay', 'lat': '19.38197', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '00', 'lng': '38', 'geonameId': 163843, 'toponymName': 'Syrian Arab Republic', 'countryId': '163843', 'fcl': 'A', 'population': 16906283, 'countryCode': 'SY', 'name': 'Syria', 'fclName': 'country, state, region,...', 'countryName': 'Syria', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '35', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=October7&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 108, 'geonames': [{'adminCode1': '06', 'lng': '35.21633', 'geonameId': 281184, 'toponymName': 'Jerusalem', 'countryId': '294640', 'fcl': 'P', 'population': 971800, 'countryCode': 'IL', 'name': 'Jerusalem', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'JM'}, 'countryName': 'Israel', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Jerusalem', 'lat': '31.76904', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': 'MI', 'lng': '-83.17631', 'geonameId': 4990510, 'toponymName': 'Dearborn', 'countryId': '6252001', 'fcl': 'P', 'population': 95171, 'countryCode': 'US', 'name': 'Dearborn', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'MI'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'Michigan', 'lat': '42.32226', 'fcode': 'PPL'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': 'MI', 'lng': '-85.50033', 'geonameId': 5001836, 'toponymName': 'Michigan', 'countryId': '6252001', 'fcl': 'A', 'population': 9883360, 'countryCode': 'US', 'name': 'Michigan', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'MI'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Michigan', 'lat': '44.25029', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 1158, 'geonames': [{'adminCode1': 'ME', 'lng': '-70.2331', 'geonameId': 4970921, 'toponymName': 'Mackworth Island', 'countryId': '6252001', 'fcl': 'T', 'population': 0, 'countryCode': 'US', 'name': 'Mackworth Island', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'ME'}, 'countryName': 'United States', 'fcodeName': 'island', 'adminName1': 'Maine', 'lat': '43.68897', 'fcode': 'ISL'}]}
# {'totalResultsCount': 1092, 'geonames': [{'adminCode1': '47', 'lng': '127.94581', 'geonameId': 1854346, 'toponymName': 'Okinawa', 'countryId': '1861060', 'fcl': 'T', 'population': 1301000, 'countryCode': 'JP', 'name': 'Okinawa', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': '47'}, 'countryName': 'Japan', 'fcodeName': 'island', 'adminName1': 'Okinawa', 'lat': '26.50687', 'fcode': 'ISL'}]}
# {'totalResultsCount': 1300, 'geonames': [{'adminCode1': 'MI', 'lng': '-86.75698', 'geonameId': 5001835, 'toponymName': 'Lake Michigan', 'countryId': '6252001', 'fcl': 'H', 'population': 0, 'countryCode': 'US', 'name': 'Michigan', 'fclName': 'stream, lake, ...', 'adminCodes1': {'ISO3166_2': 'MI'}, 'countryName': 'United States', 'fcodeName': 'lake', 'adminName1': 'Michigan', 'lat': '44.00778', 'fcode': 'LK'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '00', 'lng': '66', 'geonameId': 1149361, 'toponymName': 'Islamic Republic of Afghanistan', 'countryId': '1149361', 'fcl': 'A', 'population': 37172386, 'countryCode': 'AF', 'name': 'Afghanistan', 'fclName': 'country, state, region,...', 'countryName': 'Afghanistan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '33', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 56, 'geonames': [{'adminCode1': 'TX', 'lng': '-99.25061', 'geonameId': 4736286, 'toponymName': 'Texas', 'countryId': '6252001', 'fcl': 'A', 'population': 22875689, 'countryCode': 'US', 'name': 'Texas', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'TX'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Texas', 'lat': '31.25044', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 235, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.49514', 'geonameId': 281145, 'toponymName': 'Bayt Lāhyā', 'countryId': '6254930', 'fcl': 'P', 'population': 56919, 'countryCode': 'PS', 'name': 'Beit Lahia', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'Gaza Strip', 'lat': '31.5464', 'fcode': 'PPL'}]}
# {'totalResultsCount': 4, 'geonames': [{'adminCode1': '12', 'lng': '36.63393', 'geonameId': 169389, 'toponymName': 'Idlib', 'countryId': '163843', 'fcl': 'P', 'population': 128840, 'countryCode': 'SY', 'name': 'Idlib', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'ID'}, 'countryName': 'Syria', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Idlib', 'lat': '35.93062', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Hamass&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 325, 'geonames': [{'adminCode1': '05', 'lng': '34.78057', 'geonameId': 293397, 'toponymName': 'Tel Aviv', 'countryId': '294640', 'fcl': 'P', 'population': 432892, 'countryCode': 'IL', 'name': 'Tel Aviv', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'TA'}, 'countryName': 'Israel', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Tel Aviv', 'lat': '32.08088', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 425, 'geonames': [{'adminCode1': 'WA', 'lng': '-120.50147', 'geonameId': 5815135, 'toponymName': 'Washington', 'countryId': '6252001', 'fcl': 'A', 'population': 6271775, 'countryCode': 'US', 'name': 'Washington', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'WA'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Washington', 'lat': '47.50012', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 56, 'geonames': [{'adminCode1': '11', 'lng': '31.24967', 'geonameId': 360630, 'toponymName': 'Cairo', 'countryId': '357994', 'fcl': 'P', 'population': 9606916, 'countryCode': 'EG', 'name': 'Cairo', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'C'}, 'countryName': 'Egypt', 'fcodeName': 'capital of a political entity', 'adminName1': 'Cairo', 'lat': '30.06263', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '01', 'lng': '51.53096', 'geonameId': 290030, 'toponymName': 'Doha', 'countryId': '289688', 'fcl': 'P', 'population': 344939, 'countryCode': 'QA', 'name': 'Doha', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'DA'}, 'countryName': 'Qatar', 'fcodeName': 'capital of a political entity', 'adminName1': 'Baladīyat ad Dawḩah', 'lat': '25.28545', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.3925', 'geonameId': 281109, 'toponymName': 'An Nuşayrāt', 'countryId': '6254930', 'fcl': 'P', 'population': 36123, 'countryCode': 'PS', 'name': 'An Nuşayrāt', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'Gaza Strip', 'lat': '31.44861', 'fcode': 'PPL'}]}
# {'totalResultsCount': 1627, 'geonames': [{'lng': '24.69727', 'geonameId': 7729886, 'name': 'Central Africa', 'fclName': 'parks,area, ...', 'toponymName': 'Central Africa', 'fcodeName': 'region', 'adminName1': '', 'lat': '-2.02107', 'fcl': 'L', 'fcode': 'RGN', 'population': 129400000}]}
# {'totalResultsCount': 235, 'geonames': [{'adminCode1': '07', 'lng': '40.14084', 'geonameId': 170794, 'toponymName': 'Deir ez-Zor', 'countryId': '163843', 'fcl': 'P', 'population': 271800, 'countryCode': 'SY', 'name': 'Dayr az Zawr', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'DY'}, 'countryName': 'Syria', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Deir ez-Zor', 'lat': '35.33588', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.24357', 'geonameId': 281102, 'toponymName': 'Rafaḩ', 'countryId': '6254930', 'fcl': 'P', 'population': 126305, 'countryCode': 'PS', 'name': 'Rafah', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.29722', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 68, 'geonames': [{'adminCode1': '18', 'lng': '43.65', 'geonameId': 91695, 'toponymName': 'Muhafazat Salah ad Din', 'countryId': '99237', 'fcl': 'A', 'population': 1032674, 'countryCode': 'IQ', 'name': 'Salah ad Din', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'SD'}, 'countryName': 'Iraq', 'fcodeName': 'first-order administrative division', 'adminName1': 'Salah ad Din', 'lat': '34.5', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.46672', 'geonameId': 281133, 'toponymName': 'Gaza', 'countryId': '6254930', 'fcl': 'P', 'population': 410000, 'countryCode': 'PS', 'name': 'Gaza', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.50161', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 27, 'geonames': [{'adminCode1': '00', 'lng': '79', 'geonameId': 1269750, 'toponymName': 'Republic of India', 'countryId': '1269750', 'fcl': 'A', 'population': 1352617328, 'countryCode': 'IN', 'name': 'India', 'fclName': 'country, state, region,...', 'countryName': 'India', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '22', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 1125, 'geonames': [{'adminCode1': '07', 'lng': '77.2148', 'geonameId': 1261481, 'toponymName': 'New Delhi', 'countryId': '1269750', 'fcl': 'P', 'population': 317797, 'countryCode': 'IN', 'name': 'New Delhi', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'DL'}, 'countryName': 'India', 'fcodeName': 'capital of a political entity', 'adminName1': 'Delhi', 'lat': '28.62137', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '51', 'lng': '-5.99304', 'geonameId': 7603009, 'toponymName': 'Archivo General de Indias', 'countryId': '2510769', 'fcl': 'S', 'population': 0, 'countryCode': 'ES', 'name': 'General Archive of the Indies', 'fclName': 'spot, building, farm', 'adminCodes1': {'ISO3166_2': 'AN'}, 'countryName': 'Spain', 'fcodeName': 'archive', 'adminName1': 'Andalusia', 'lat': '37.38469', 'fcode': 'ARCHV'}]}
# {'totalResultsCount': 1422, 'geonames': [{'lng': '-100.54688', 'geonameId': 6255149, 'name': 'North America', 'fclName': 'parks,area, ...', 'toponymName': 'North America', 'fcodeName': 'continent', 'adminName1': '', 'lat': '46.07323', 'fcl': 'L', 'fcode': 'CONT', 'population': 580000000}]}
# {'totalResultsCount': 2557, 'geonames': [{'lng': '9.97559', 'geonameId': 7729887, 'name': 'Northern Africa', 'fclName': 'parks,area, ...', 'toponymName': 'Northern Africa', 'fcodeName': 'region', 'adminName1': '', 'lat': '32.95337', 'fcl': 'L', 'fcode': 'RGN', 'population': 210800000}]}
# {'totalResultsCount': 24, 'geonames': [{'adminCode1': '00', 'lng': '45', 'geonameId': 102358, 'toponymName': 'Kingdom of Saudi Arabia', 'countryId': '102358', 'fcl': 'A', 'population': 33699947, 'countryCode': 'SA', 'name': 'Saudi Arabia', 'fclName': 'country, state, region,...', 'countryName': 'Saudi Arabia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': 'DC', 'lng': '-77.00025', 'geonameId': 4138106, 'toponymName': 'District of Columbia', 'countryId': '6252001', 'fcl': 'A', 'population': 552433, 'countryCode': 'US', 'name': 'District of Columbia', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'DC'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'District of Columbia', 'lat': '38.91706', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': 'VA', 'lng': '-77.05526', 'geonameId': 4778469, 'toponymName': 'Pentagon', 'countryId': '6252001', 'fcl': 'S', 'population': 0, 'countryCode': 'US', 'name': 'Pentagon', 'fclName': 'spot, building, farm', 'adminCodes1': {'ISO3166_2': 'VA'}, 'countryName': 'United States', 'fcodeName': 'building(s)', 'adminName1': 'Virginia', 'lat': '38.87095', 'fcode': 'BLDG'}]}
# {'totalResultsCount': 138, 'geonames': [{'adminCode1': '14', 'lng': '31.60823', 'geonameId': 354820, 'toponymName': 'Kafr Abū Musallam', 'countryId': '357994', 'fcl': 'P', 'population': 0, 'countryCode': 'EG', 'name': 'Kafr Abū Musallam', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'SHR'}, 'countryName': 'Egypt', 'fcodeName': 'populated place', 'adminName1': 'Sharqia', 'lat': '30.486', 'fcode': 'PPL'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '01', 'lng': '34.28459', 'geonameId': 294481, 'toponymName': 'Kerem Shalom', 'countryId': '294640', 'fcl': 'P', 'population': 183, 'countryCode': 'IL', 'name': 'Kerem Shalom', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'D'}, 'countryName': 'Israel', 'fcodeName': 'populated place', 'adminName1': 'Southern District', 'lat': '31.22777', 'fcode': 'PPL'}]}
# {'totalResultsCount': 5, 'geonames': [{'adminCode1': '00', 'lng': '22', 'geonameId': 390903, 'toponymName': 'Hellenic Republic', 'countryId': '390903', 'fcl': 'A', 'population': 10727668, 'countryCode': 'GR', 'name': 'Greece', 'fclName': 'country, state, region,...', 'countryName': 'Greece', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '39', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '00', 'lng': '45', 'geonameId': 102358, 'toponymName': 'Kingdom of Saudi Arabia', 'countryId': '102358', 'fcl': 'A', 'population': 33699947, 'countryCode': 'SA', 'name': 'Saudi Arabia', 'fclName': 'country, state, region,...', 'countryName': 'Saudi Arabia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 531, 'geonames': [{'adminCode1': '00', 'lng': '54.5', 'geonameId': 290557, 'toponymName': 'United Arab Emirates', 'countryId': '290557', 'fcl': 'A', 'population': 9630959, 'countryCode': 'AE', 'name': 'United Arab Emirates', 'fclName': 'country, state, region,...', 'countryName': 'United Arab Emirates', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '23.75', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': 'WE', 'lng': '35.20422', 'geonameId': 282239, 'toponymName': 'Ramallah', 'countryId': '6254930', 'fcl': 'P', 'population': 24599, 'countryCode': 'PS', 'name': 'Ramallah', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'West Bank', 'lat': '31.89964', 'fcode': 'PPL'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '02', 'lng': '33', 'geonameId': 1046058, 'toponymName': 'Gaza Province', 'countryId': '1036973', 'fcl': 'A', 'population': 1422460, 'countryCode': 'MZ', 'name': 'Gaza Province', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'G'}, 'countryName': 'Mozambique', 'fcodeName': 'first-order administrative division', 'adminName1': 'Gaza Province', 'lat': '-23.5', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 4, 'geonames': [{'adminCode1': '00', 'lng': '-14.7', 'geonameId': 2368892, 'toponymName': 'Uaè', 'countryId': '2372248', 'fcl': 'P', 'population': 0, 'countryCode': 'GW', 'name': 'Uaè', 'fclName': 'city, village,...', 'countryName': 'Guinea-Bissau', 'fcodeName': 'populated place', 'adminName1': '', 'lat': '12.26667', 'fcode': 'PPL'}]}
# {'totalResultsCount': 206, 'geonames': [{'adminCode1': 'WY', 'lng': '-104.75802', 'geonameId': 5841717, 'toponymName': 'United Nations Park', 'countryId': '6252001', 'fcl': 'L', 'population': 0, 'countryCode': 'US', 'name': 'United Nations Park', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'WY'}, 'countryName': 'United States', 'fcodeName': 'park', 'adminName1': 'Wyoming', 'lat': '41.13387', 'fcode': 'PRK'}]}
# {'totalResultsCount': 54, 'geonames': [{'adminCode1': 'GE', 'lng': '6.14569', 'geonameId': 2660646, 'toponymName': 'Genève', 'countryId': '2658434', 'fcl': 'P', 'population': 183981, 'countryCode': 'CH', 'name': 'Geneva', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'GE'}, 'countryName': 'Switzerland', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Geneva', 'lat': '46.20222', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 78, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.46672', 'geonameId': 281133, 'toponymName': 'Gaza', 'countryId': '6254930', 'fcl': 'P', 'population': 410000, 'countryCode': 'PS', 'name': 'Gaza', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.50161', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 2917, 'geonames': [{'lng': '-71.21667', 'geonameId': 3571219, 'name': 'West Indies', 'fclName': 'parks,area, ...', 'toponymName': 'West Indies', 'fcodeName': 'region', 'adminName1': '', 'lat': '19.38333', 'fcl': 'L', 'fcode': 'RGN', 'population': 42450000}]}
# {'totalResultsCount': 64, 'geonames': [{'adminCode1': '27', 'lng': '23.46667', 'geonameId': 6297162, 'toponymName': 'Lodja Airport', 'countryId': '203312', 'fcl': 'S', 'population': 0, 'countryCode': 'CD', 'name': 'Lodja Airport', 'fclName': 'spot, building, farm', 'adminCodes1': {'ISO3166_2': 'SA'}, 'countryName': 'DR Congo', 'fcodeName': 'airport', 'adminName1': 'Sankuru', 'lat': '-3.48333', 'fcode': 'AIRP'}]}
# {'totalResultsCount': 252, 'geonames': [{'adminCode1': '02', 'lng': '34.88657', 'geonameId': 390285, 'toponymName': 'Ben Gurion Airport', 'countryId': '294640', 'fcl': 'S', 'population': 0, 'countryCode': 'IL', 'name': 'Ben Gurion Airport', 'fclName': 'spot, building, farm', 'adminCodes1': {'ISO3166_2': 'M'}, 'countryName': 'Israel', 'fcodeName': 'airport', 'adminName1': 'Central District', 'lat': '32.01361', 'fcode': 'AIRP'}]}
# {'totalResultsCount': 8, 'geonames': [{'adminCode1': '02', 'lng': '11.57549', 'geonameId': 2867714, 'toponymName': 'Munich', 'countryId': '2921044', 'fcl': 'P', 'population': 1260391, 'countryCode': 'DE', 'name': 'Munich', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'BY'}, 'countryName': 'Germany', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Bavaria', 'lat': '48.13743', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '04', 'lng': '34.9885', 'geonameId': 294801, 'toponymName': 'Haifa', 'countryId': '294640', 'fcl': 'P', 'population': 285316, 'countryCode': 'IL', 'name': 'Haifa', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'HA'}, 'countryName': 'Israel', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Haifa', 'lat': '32.81841', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '06', 'lng': '35.37148', 'geonameId': 268064, 'toponymName': 'Sidon', 'countryId': '272103', 'fcl': 'P', 'population': 163554, 'countryCode': 'LB', 'name': 'Sidon', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'JA'}, 'countryName': 'Lebanon', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'South Governorate', 'lat': '33.55751', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Salamehs&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=alMajzoubs&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Beiruts&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Lebanons&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 168, 'geonames': [{'adminCode1': 'TX', 'lng': '-95.65255', 'geonameId': 12213829, 'toponymName': 'Palestine, TX Micro Area', 'countryId': '6252001', 'fcl': 'L', 'population': 60000, 'countryCode': 'US', 'name': 'Palestine, TX', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'TX'}, 'countryName': 'United States', 'fcodeName': 'economic region', 'adminName1': 'Texas', 'lat': '31.81333', 'fcode': 'RGNE'}]}
# {'totalResultsCount': 15, 'geonames': [{'adminCode1': 'MI', 'lng': '-83.04575', 'geonameId': 4990729, 'toponymName': 'Detroit', 'countryId': '6252001', 'fcl': 'P', 'population': 677116, 'countryCode': 'US', 'name': 'Detroit', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'MI'}, 'countryName': 'United States', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'Michigan', 'lat': '42.33143', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 291, 'geonames': [{'adminCode1': 'MI', 'lng': '-83.71087', 'geonameId': 12111046, 'toponymName': 'Southeast Michigan', 'countryId': '6252001', 'fcl': 'L', 'population': 270000, 'countryCode': 'US', 'name': 'Southeast Michigan', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'MI'}, 'countryName': 'United States', 'fcodeName': 'region', 'adminName1': 'Michigan', 'lat': '43.96102', 'fcode': 'RGN'}]}
# {'totalResultsCount': 309, 'geonames': [{'adminCode1': '00', 'lng': '45', 'geonameId': 102358, 'toponymName': 'Kingdom of Saudi Arabia', 'countryId': '102358', 'fcl': 'A', 'population': 33699947, 'countryCode': 'SA', 'name': 'Saudi Arabia', 'fclName': 'country, state, region,...', 'countryName': 'Saudi Arabia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': '01', 'lng': '54.1', 'geonameId': 291804, 'toponymName': 'Jarrah', 'countryId': '290557', 'fcl': 'L', 'population': 0, 'countryCode': 'AE', 'name': 'Jarrah', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'AZ'}, 'countryName': 'United Arab Emirates', 'fcodeName': 'oasis(-es)', 'adminName1': 'Abu Dhabi', 'lat': '24.05', 'fcode': 'OAS'}]}
# ...
# {'totalResultsCount': 13, 'geonames': [{'adminCode1': '51', 'lng': '24.68333', 'geonameId': 730931, 'toponymName': 'Iganovo', 'countryId': '732800', 'fcl': 'P', 'population': 0, 'countryCode': 'BG', 'name': 'Iganovo', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '16'}, 'countryName': 'Bulgaria', 'fcodeName': 'populated place', 'adminName1': 'Plovdiv', 'lat': '42.66667', 'fcode': 'PPL'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '05', 'lng': '34.8338', 'geonameId': 295514, 'toponymName': 'Bnei Brak', 'countryId': '294640', 'fcl': 'P', 'population': 214444, 'countryCode': 'IL', 'name': 'Bnei Brak', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'TA'}, 'countryName': 'Israel', 'fcodeName': 'populated place', 'adminName1': 'Tel Aviv', 'lat': '32.08074', 'fcode': 'PPL'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '31', 'lng': '92.67869', 'geonameId': 1266258, 'toponymName': 'Kolasib', 'countryId': '1269750', 'fcl': 'P', 'population': 25000, 'countryCode': 'IN', 'name': 'Kolasib', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'MZ'}, 'countryName': 'India', 'fcodeName': 'populated place', 'adminName1': 'Mizoram', 'lat': '24.22388', 'fcode': 'PPL'}]}
# {'totalResultsCount': 77, 'geonames': [{'adminCode1': 'CA', 'lng': '-122.04', 'geonameId': 6940309, 'toponymName': 'Silicon Valley', 'countryId': '6252001', 'fcl': 'L', 'population': 0, 'countryCode': 'US', 'name': 'Silicon Valley', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'CA'}, 'countryName': 'United States', 'fcodeName': 'area', 'adminName1': 'California', 'lat': '37.37', 'fcode': 'AREA'}]}
# {'totalResultsCount': 181, 'geonames': [{'adminCode1': '06', 'lng': '34.99293', 'geonameId': 295432, 'toponymName': 'Bet Shemesh', 'countryId': '294640', 'fcl': 'P', 'population': 124957, 'countryCode': 'IL', 'name': 'Bet Shemesh', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'JM'}, 'countryName': 'Israel', 'fcodeName': 'populated place', 'adminName1': 'Jerusalem', 'lat': '31.73072', 'fcode': 'PPL'}]}
# {'totalResultsCount': 13653, 'geonames': [{'adminCode1': '16', 'lng': '-79.96472', 'geonameId': 3537906, 'toponymName': 'Santa Clara', 'countryId': '3562981', 'fcl': 'P', 'population': 250512, 'countryCode': 'CU', 'name': 'Santa Clara', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '05'}, 'countryName': 'Cuba', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Villa Clara Province', 'lat': '22.40694', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 338, 'geonames': [{'adminCode1': 'CA', 'lng': '-119.75126', 'geonameId': 5332921, 'toponymName': 'California', 'countryId': '6252001', 'fcl': 'A', 'population': 39512223, 'countryCode': 'US', 'name': 'California', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'CA'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'California', 'lat': '37.25022', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '00', 'lng': '28.58333', 'geonameId': 617790, 'toponymName': 'Republic of Moldova', 'countryId': '617790', 'fcl': 'A', 'population': 3545883, 'countryCode': 'MD', 'name': 'Moldova', 'fclName': 'country, state, region,...', 'countryName': 'Moldova', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '47.25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '01', 'lng': '34.58911', 'geonameId': 294068, 'toponymName': 'Netivot', 'countryId': '294640', 'fcl': 'P', 'population': 43732, 'countryCode': 'IL', 'name': 'Netivot', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'D'}, 'countryName': 'Israel', 'fcodeName': 'populated place', 'adminName1': 'Southern District', 'lat': '31.42305', 'fcode': 'PPL'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Thameen+Darby&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Nakba+Layer&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Mercator&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 41, 'geonames': [{'adminCode1': 'AK', 'lng': '-150.00028', 'geonameId': 5879092, 'toponymName': 'Alaska', 'countryId': '6252001', 'fcl': 'A', 'population': 660633, 'countryCode': 'US', 'name': 'Alaska', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'AK'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Alaska', 'lat': '64.00028', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 1577, 'geonames': [{'lng': '-57.65625', 'geonameId': 6255150, 'name': 'South America', 'fclName': 'parks,area, ...', 'toponymName': 'South America', 'fcodeName': 'continent', 'adminName1': '', 'lat': '-14.60485', 'fcl': 'L', 'fcode': 'CONT', 'population': 385742554}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=AsiaPacific&username=zainab128&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 12, 'geonames': [{'adminCode1': '11', 'lng': '34', 'geonameId': 703884, 'toponymName': 'Crimea', 'countryId': '690791', 'fcl': 'L', 'population': 0, 'countryCode': 'UA', 'name': 'Crimea', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': '43'}, 'countryName': 'Ukraine', 'fcodeName': 'region', 'adminName1': 'Crimea', 'lat': '45', 'fcode': 'RGN'}]}
# {'totalResultsCount': 1452, 'geonames': [{'adminCode1': 'ENG', 'lng': '0.71433', 'geonameId': 2637433, 'toponymName': 'Southend-on-Sea', 'countryId': '2635167', 'fcl': 'P', 'population': 295310, 'countryCode': 'GB', 'name': 'Southend-on-Sea', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'ENG'}, 'countryName': 'United Kingdom', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'England', 'lat': '51.53782', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 12, 'geonames': [{'adminCode1': '00', 'lng': '107.83333', 'geonameId': 1562822, 'toponymName': 'Socialist Republic of Vietnam', 'countryId': '1562822', 'fcl': 'A', 'population': 95540395, 'countryCode': 'VN', 'name': 'Vietnam', 'fclName': 'country, state, region,...', 'countryName': 'Vietnam', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '16.16667', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 24, 'geonames': [{'adminCode1': '10', 'lng': '63.19089', 'geonameId': 8355037, 'toponymName': 'Kashmīr', 'countryId': '1149361', 'fcl': 'L', 'population': 0, 'countryCode': 'AF', 'name': 'Kashmīr', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'HEL'}, 'countryName': 'Afghanistan', 'fcodeName': 'locality', 'adminName1': 'Helmand', 'lat': '30.33315', 'fcode': 'LCTY'}]}
# {'totalResultsCount': 76, 'geonames': [{'adminCode1': '08', 'lng': '73.04329', 'geonameId': 1176615, 'toponymName': 'Islamabad', 'countryId': '1168579', 'fcl': 'P', 'population': 601600, 'countryCode': 'PK', 'name': 'Islamabad', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'IS'}, 'countryName': 'Pakistan', 'fcodeName': 'capital of a political entity', 'adminName1': 'Islamabad', 'lat': '33.72148', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 17, 'geonames': [{'adminCode1': 'AL', 'lng': '-85.76147', 'geonameId': 4058224, 'toponymName': 'Darbys Lake', 'countryId': '6252001', 'fcl': 'H', 'population': 0, 'countryCode': 'US', 'name': 'Darbys Lake', 'fclName': 'stream, lake, ...', 'adminCodes1': {'ISO3166_2': 'AL'}, 'countryName': 'United States', 'fcodeName': 'lake', 'adminName1': 'Alabama', 'lat': '33.75004', 'fcode': 'LK'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '02', 'lng': '64', 'geonameId': 1168445, 'toponymName': 'Panjgur', 'countryId': '1168579', 'fcl': 'L', 'population': 0, 'countryCode': 'PK', 'name': 'Panjgur', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'BA'}, 'countryName': 'Pakistan', 'fcodeName': 'region', 'adminName1': 'Balochistan', 'lat': '26.75', 'fcode': 'RGN'}]}
# {'totalResultsCount': 15, 'geonames': [{'adminCode1': '68', 'lng': '33.15674', 'geonameId': 8378526, 'toponymName': 'Paphlagonia', 'countryId': '298795', 'fcl': 'A', 'population': 0, 'countryCode': 'TR', 'name': 'Paphlagonia (Roman province)', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': '06'}, 'countryName': 'Türkiye', 'fcodeName': 'historical first-order administrative division', 'adminName1': 'Ankara', 'lat': '41.22825', 'fcode': 'ADM1H'}]}
# {'totalResultsCount': 15, 'geonames': [{'adminCode1': '04', 'lng': '60.5', 'geonameId': 1159456, 'toponymName': 'Sistan and Baluchestan Province', 'countryId': '130758', 'fcl': 'A', 'population': 2775014, 'countryCode': 'IR', 'name': 'Sistan and Baluchestan', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': '11'}, 'countryName': 'Iran', 'fcodeName': 'first-order administrative division', 'adminName1': 'Sistan and Baluchestan', 'lat': '28.5', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 131, 'geonames': [{'adminCode1': '00', 'lng': '53', 'geonameId': 130758, 'toponymName': 'Islamic Republic of Iran', 'countryId': '130758', 'fcl': 'A', 'population': 81800269, 'countryCode': 'IR', 'name': 'Iran', 'fclName': 'country, state, region,...', 'countryName': 'Iran', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '32', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 16, 'geonames': [{'adminCode1': '29', 'lng': '57.07879', 'geonameId': 128234, 'toponymName': 'Kerman', 'countryId': '130758', 'fcl': 'P', 'population': 577514, 'countryCode': 'IR', 'name': 'Kerman', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '08'}, 'countryName': 'Iran', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Kerman', 'lat': '30.28321', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 30, 'geonames': [{'adminCode1': '00', 'lng': '53', 'geonameId': 130758, 'toponymName': 'Islamic Republic of Iran', 'countryId': '130758', 'fcl': 'A', 'population': 81800269, 'countryCode': 'IR', 'name': 'Iran', 'fclName': 'country, state, region,...', 'countryName': 'Iran', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '32', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 200, 'geonames': [{'adminCode1': '05', 'lng': '71.44598', 'geonameId': 1526273, 'toponymName': 'Astana', 'countryId': '1522867', 'fcl': 'P', 'population': 345604, 'countryCode': 'KZ', 'name': 'Astana', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '71'}, 'countryName': 'Kazakhstan', 'fcodeName': 'capital of a political entity', 'adminName1': 'Astana', 'lat': '51.1801', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': 'WE', 'lng': '35.0269', 'geonameId': 281577, 'toponymName': 'Ţūlkarm', 'countryId': '6254930', 'fcl': 'P', 'population': 44169, 'countryCode': 'PS', 'name': 'Tulkarm', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'West Bank', 'lat': '32.31156', 'fcode': 'PPL'}]}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e2b4f96421a7> in <cell line: 0>()
#      33     for row in reader:
#      34       place_name = row['place']
# ---> 35       coordinates = get_coordinates(place_name)
#      36       if coordinates:
#      37         latitude = coordinates["latitude"]
#
# <ipython-input-5-e2b4f96421a7> in get_coordinates(place, username, fuzzy, timeout)
#      11   url = "http://api.geonames.org/searchJSON?"
#      12   params = {"q": place, "username": username, "fuzzy": fuzzy, "maxRows": 1, "isNameRequired": True}
# ---> 13   response = requests.get(url, params=params)
#      14   # convert the response into a dictionary:
#      15   results = response.json()
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in getresponse(self)
#     514
#     515         # Get the response from http.client.HTTPConnection
# --> 516         httplib_response = super().getresponse()
#     517
#     518         try:
#
# /usr/lib/python3.11/http/client.py in getresponse(self)
#    1393         try:
#    1394             try:
# -> 1395                 response.begin()
#    1396             except ConnectionError:
#    1397                 self.close()
#
# /usr/lib/python3.11/http/client.py in begin(self)
#     323         # read until we get a non-100 response
#     324         while True:
# --> 325             version, status, reason = self._read_status()
#     326             if status != CONTINUE:
#     327                 break
#
# /usr/lib/python3.11/http/client.py in _read_status(self)
#     284
#     285     def _read_status(self):
# --> 286         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287         if len(line) > _MAXLINE:
#     288             raise LineTooLong("status line")
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# Ex 4a

# %%
# Importing the necessary library
import plotly.express as px
import pandas as pd

# Load frequency data
freq_df = pd.read_csv("regex_counts.tsv", sep="\t")

# Load geocoded coordinates
geo_df = pd.read_csv("ner_gazetteer.tsv", sep="\t")

# The expected merge column is 'place'
# Check if geo_df has 'name' instead of 'place'
if 'name' in geo_df.columns and 'place' not in geo_df.columns:
    geo_df.rename(columns={'name': 'place'}, inplace=True)

# merge the two tables, using the common column “asciiname”
merged_df = pd.merge(geo_df, freq_df, on="place")


# Plotly animated geo map
fig = px.scatter_geo(
    merged_df,
    lat="latitude",
    lon="longitude",
    size="count",
    color="place",
    hover_name="place",
    animation_frame="month",
    projection="natural earth",
    size_max=20
)
# Save interactive HTML map
fig.write_html("regex_map.html")
# Show the figure
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-c23b701b813b> in <cell line: 0>()
#       4
#       5 # Load frequency data
# ----> 6 freq_df = pd.read_csv("regex_counts.tsv", sep="\t")
#       7
#       8 # Load geocoded coordinates
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'regex_counts.tsv'

# %% [markdown]
# Ex 4b

# %%
# Load NER frequency data (January 2024 only)
ner_df = pd.read_csv("ner_counts.tsv", sep="\t")

# Load geocoded coordinates
geo_df = pd.read_csv("ner_gazetteer.tsv", sep="\t")

# Merge the two tables using the common column "place"
merged_df = pd.merge(ner_df, geo_df, on="place")

merged_df['count'] = pd.to_numeric(merged_df['count'], errors='coerce')

# Drop rows with NaN values in 'count', 'latitude', or 'longitude'
merged_df = merged_df.dropna(subset=['count', 'latitude', 'longitude'])

# Create static and interactive maps
fig = px.scatter_geo(
    merged_df,
    lat="latitude",
    lon="longitude",
    size="count",
    color="place",
    hover_name="place",
    projection="natural earth",
    size_max=20,
    title="NER Place Frequencies - January 2024"
)

# Save interactive HTML map
fig.write_html("ner_map.html")

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="149e90af-4d17-48fb-9aba-74ec4f0c11f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("149e90af-4d17-48fb-9aba-74ec4f0c11f9")) {                    Plotly.newPlot(                        "149e90af-4d17-48fb-9aba-74ec4f0c11f9",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=West Bank\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["West Bank","West Bank"],"lat":[19.38197,19.38197],"legendgroup":"West Bank","lon":[-81.39281,-81.39281],"marker":{"color":"#636efa","size":[160.0,160.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"West Bank","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Dura\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Dura","Dura"],"lat":[28.8,28.8],"legendgroup":"Dura","lon":[49.23333,49.23333],"marker":{"color":"#EF553B","size":[2.0,2.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"Dura","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Hebron\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Hebron","Hebron"],"lat":[31.52935,31.52935],"legendgroup":"Hebron","lon":[35.0938,35.0938],"marker":{"color":"#00cc96","size":[10.0,10.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"Hebron","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Tulkarem\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Tulkarem","Tulkarem"],"lat":[32.31156,32.31156],"legendgroup":"Tulkarem","lon":[35.0269,35.0269],"marker":{"color":"#ab63fa","size":[2.0,2.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"Tulkarem","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Gaza Strip\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Gaza Strip","Gaza Strip"],"lat":[31.50161,31.50161],"legendgroup":"Gaza Strip","lon":[34.46672,34.46672],"marker":{"color":"#FFA15A","size":[156.0,156.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"Gaza Strip","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Israel\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Israel","Israel"],"lat":[31.5,31.5],"legendgroup":"Israel","lon":[34.75,34.75],"marker":{"color":"#19d3f3","size":[1594.0,1594.0],"sizemode":"area","sizeref":4.0125,"symbol":"circle"},"mode":"markers","name":"Israel","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eplace=Nablus\u003cbr\u003ecount=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e ...
